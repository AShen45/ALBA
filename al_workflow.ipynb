# %%
# !pip install datamol
# !pip install rdkit-pypi
# !pip install pandas
# Out:
# Requirement already satisfied: datamol in /usr/local/lib/python3.10/dist-packages (0.11.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from datamol) (4.65.0)
# Requirement already satisfied: loguru in /usr/local/lib/python3.10/dist-packages (from datamol) (0.7.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from datamol) (1.3.1)
# Requirement already satisfied: fsspec>=2021.9 in /usr/local/lib/python3.10/dist-packages (from datamol) (2023.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datamol) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from datamol) (3.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from datamol) (9.4.0)
# Requirement already satisfied: selfies in /usr/local/lib/python3.10/dist-packages (from datamol) (2.1.1)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from datamol) (3.9.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from datamol) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datamol) (23.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from datamol) (4.7.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from datamol) (6.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datamol) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->datamol) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->datamol) (1.16.0)
# Requirement already satisfied: rdkit-pypi in /usr/local/lib/python3.10/dist-packages (2022.9.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (9.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import os
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import Linear
from torch.utils.data import DataLoader
import tqdm

# %% [markdown]
# # Load data

# %%
def ecfp_from_smiles(smiles,
                     R = 3,
                     L = 2**11,
                     use_features = True,
                     use_chirality = False):
    """
    Inputs:

    - smiles ... SMILES string of input compound
    - R ... maximum radius of circular substructures
    - L ... fingerprint-length
    - use_features ... if false then use standard DAYLIGHT atom features, if true then use pharmacophoric atom features
    - use_chirality ... if true then append tetrahedral chirality flags to atom features

    Outputs:
    - np.array(feature_list) ... ECFP with length L and maximum radius R
    """

    molecule = Chem.MolFromSmiles(smiles)
    if not molecule:
        return np.nan
    feature_list = AllChem.GetMorganFingerprintAsBitVect(molecule,
                                                         radius = R,
                                                         nBits = L,
                                                         useFeatures = use_features,
                                                         useChirality = use_chirality)
    return np.array(feature_list)

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Project/ALVS")
# Out:
# Mounted at /content/drive

# %%
# contains only smile strings --> DUD-E target
df = pd.read_csv("aa2ar_processed.csv", sep="\t")

# %%
# df["ecfp"] = df["smiles"].map(lambda x: ecfp_from_smiles(x))

# %%
# dff = df[~df["ecfp"].isna()]

# %% [markdown]
# # Mol Graph DNN Regressor

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, fps, scores):
        self.fps = fps
        self.scores = scores
        self.dataLen = len(scores)

    def __getitem__(self, index):
        fp = np.array(self.fps[index])
        score = np.array(self.scores[index]).reshape(1,)
        return fp, score

    def __len__(self):
        return self.dataLen

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.fc1 = Linear(2048, 1024)
        self.dropout1 = nn.Dropout(p=0.2)
        self.fc2 = Linear(1024, 516)
        self.dropout2 = nn.Dropout(p=0.2)
        self.fc3 = Linear(516, 256)
        self.dropout3 = nn.Dropout(p=0.2)
        self.fc4 = Linear(256, 128)
        self.dropout4 = nn.Dropout(p=0.2)
        self.fc5 = Linear(128, 1)


    def forward(self, data):
        x = F.relu(self.fc1(data))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = F.relu(self.fc3(x))
        x = self.dropout3(x)
        x = F.relu(self.fc4(x))
        x = self.dropout4(x)
        x = self.fc5(x)
        return x

# %%
def train_epoch(loader, model, optimizer, device):
    model.train()

    loss_all = 0
    i = 0
    for fps, scores in loader:
        fps = fps.float().to(device)
        scores = scores.float().to(device)

        optimizer.zero_grad()
        output = model(fps)
        loss = F.mse_loss(output, scores)
        loss.backward()

        loss_all += loss.item()
        optimizer.step()
        i += 1
    return loss_all / i

# %%
def test_epoch(loader, model,  device):
    model.eval()

    MSE, MAE = 0, 0
    trues, preds = [], []
    with torch.no_grad():
        for fps, scores in loader:
            fps = fps.float().to(device)
            scores = scores.float().to(device)

            output = model(fps)
            pred = output.cpu().squeeze().numpy().tolist()
            true = scores.cpu().squeeze().numpy().tolist()

            trues.extend(true)
            preds.extend(pred)
    MAE = mean_absolute_error(trues, preds)
    RMSE = np.sqrt(mean_squared_error(trues, preds))
    R2 = r2_score(trues, preds)
    return MAE, RMSE, R2

# %%
def init_model(device, lr=0.001):
    model = DNN()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    return model, optimizer

# %%
def prepare_dataloader(dff, batch_size, test_size=0.8):
    train_fps, valid_fps, train_scores, valid_scores = train_test_split(
                                                                        dff["ecfp"],
                                                                        dff["score"],
                                                                        test_size=test_size)
    train_dataset = Dataset(fps=list(train_fps),
                            scores = list(train_scores))
    valid_dataset = Dataset(fps=list(valid_fps),
                            scores = list(valid_scores))
    train_loader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=True)
    valid_loader = DataLoader(valid_dataset,
                              batch_size=batch_size,
                              shuffle=False)
    return train_loader, valid_loader

# %%
def train_step(dff, epochs, batch_size, step_time, device="cuda"):
    model, optimizer = init_model(device=device)
    train_loader, valid_loader = prepare_dataloader(dff,  batch_size=batch_size)

    model_folder = "models/{}".format(step_time)
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)

    hist = {"train-loss":[], "test-mae":[], "test-mse":[], "test-r2":[]}
    for epoch in range(epochs):
        train_loss = train_epoch(train_loader, model, optimizer, device)
        test_mae, test_rmse, test_r2 = test_epoch(valid_loader, model, device)
        hist["train-loss"].append(train_loss)
        hist["test-mae"].append(test_mae)
        hist["test-mse"].append(test_rmse)
        hist["test-r2"].append(test_r2)

        if test_mae <= min(hist["test-mae"]):
            weight_path = os.path.join(model_folder, "weight_{}.pth".format(epoch))
            torch.save(model.state_dict(), weight_path)

        print(f'Epoch: {epoch}, Train loss: {train_loss:.3}, Test mae: {test_mae:.3}, Test rmse: {test_rmse:.3}, Test r2: {test_r2:.3}')
    print("---------------------------------\nmin mae: {}\n---------------------------------\n".format(min(hist["test-mae"])))
    return weight_path

# %%
# train_fps, valid_fps, train_scores, valid_scores = train_test_split(dff["ecfp"], dff["score"], test_size=0.8)

# %%
# train_dataset = Dataset(fps=list(train_fps), scores = list(train_scores))
# valid_dataset = Dataset(fps=list(valid_fps), scores = list(valid_scores))

# %%
# train_dataloader = DataLoader(train_dataset, batch_size=128, shuffle=True)
# valid_dataloader = DataLoader(valid_dataset, batch_size=2, shuffle=True)

# %%
# train_step(train_dataloader, valid_dataloader, epochs=50, step_time=1)

# %%
def random_select(df, n_samples):
    df_select = df.sample(n=n_samples).copy()
    sample_indexs = df_select["name"].tolist()
    df_remaining = df[~df["name"].isin(sample_indexs)].copy()
    return df_select, df_remaining

# %%
# dfs, dfr = random_select(dff, n_samples=50)

# %%
def run_step(dfs, epochs, stime):
    dfs_new = dfs.copy()
    dfs_new["ecfp"] = dfs_new["smiles"].map(lambda x: ecfp_from_smiles(x))
    dffs = dfs_new[~dfs_new["ecfp"].isna()]

    best_model_path = train_step(dffs, epochs, batch_size=32, step_time=stime)
    return best_model_path

# %%
def run_iterations(df, epochs=30, iterations=10, n_samples=500):
    print("len(df):", len(df))
    for stime in range(iterations):
        if stime < 1:
            dfs, dfr = random_select(df, n_samples)
        else:
            df_temp = dfs.copy()
            dfs, dfr = random_select(dfr, n_samples)
            dfs = pd.concat([dfs, df_temp], axis=0)
            dfs = dfs.reset_index(drop=True)
        print("number of mol pool:", len(dfs))
        best_model_path = run_step(dfs, epochs, stime)
        print(best_model_path)

# %%
querry_fcn = {
    'random_sample': random_select,
    'dropout_score': dropout_score,
}

# %%
run_iterations(df)
# Out:
# len(df): 31971
# number of mol pool: 500
# Epoch: 0, Train loss: 73.3, Test mae: 8.23, Test rmse: 8.29, Test r2: -64.7
# Epoch: 1, Train loss: 55.3, Test mae: 4.46, Test rmse: 4.59, Test r2: -19.1
# Epoch: 2, Train loss: 15.6, Test mae: 1.95, Test rmse: 2.43, Test r2: -4.65
# Epoch: 3, Train loss: 7.34, Test mae: 3.6, Test rmse: 3.76, Test r2: -12.5
# Epoch: 4, Train loss: 10.1, Test mae: 2.93, Test rmse: 3.13, Test r2: -8.37
# Epoch: 5, Train loss: 4.3, Test mae: 1.2, Test rmse: 1.54, Test r2: -1.26
# Epoch: 6, Train loss: 6.36, Test mae: 1.63, Test rmse: 1.93, Test r2: -2.57
# Epoch: 7, Train loss: 4.27, Test mae: 2.86, Test rmse: 3.06, Test r2: -7.96
# Epoch: 8, Train loss: 3.96, Test mae: 1.41, Test rmse: 1.73, Test r2: -1.86
# Epoch: 9, Train loss: 2.93, Test mae: 1.14, Test rmse: 1.45, Test r2: -1.02
# Epoch: 10, Train loss: 2.21, Test mae: 1.97, Test rmse: 2.24, Test r2: -3.79
# Epoch: 11, Train loss: 2.3, Test mae: 2.08, Test rmse: 2.34, Test r2: -4.25
# Epoch: 12, Train loss: 1.57, Test mae: 1.19, Test rmse: 1.5, Test r2: -1.16
# Epoch: 13, Train loss: 2.35, Test mae: 1.56, Test rmse: 1.85, Test r2: -2.28
# Epoch: 14, Train loss: 2.5, Test mae: 2.07, Test rmse: 2.32, Test r2: -4.17
# Epoch: 15, Train loss: 2.48, Test mae: 1.24, Test rmse: 1.55, Test r2: -1.31
# Epoch: 16, Train loss: 1.95, Test mae: 1.2, Test rmse: 1.52, Test r2: -1.2
# Epoch: 17, Train loss: 1.83, Test mae: 1.51, Test rmse: 1.81, Test r2: -2.12
# Epoch: 18, Train loss: 2.01, Test mae: 1.58, Test rmse: 1.87, Test r2: -2.35
# Epoch: 19, Train loss: 1.75, Test mae: 1.2, Test rmse: 1.51, Test r2: -1.18
# Epoch: 20, Train loss: 1.88, Test mae: 1.67, Test rmse: 1.96, Test r2: -2.67
# Epoch: 21, Train loss: 2.14, Test mae: 1.61, Test rmse: 1.9, Test r2: -2.44
# Epoch: 22, Train loss: 2.61, Test mae: 1.27, Test rmse: 1.58, Test r2: -1.38
# Epoch: 23, Train loss: 1.64, Test mae: 1.84, Test rmse: 2.1, Test r2: -3.24
# Epoch: 24, Train loss: 1.52, Test mae: 1.15, Test rmse: 1.48, Test r2: -1.08
# Epoch: 25, Train loss: 2.08, Test mae: 1.4, Test rmse: 1.7, Test r2: -1.76
# Epoch: 26, Train loss: 1.32, Test mae: 1.94, Test rmse: 2.2, Test r2: -3.63
# Epoch: 27, Train loss: 2.08, Test mae: 1.3, Test rmse: 1.6, Test r2: -1.46
# Epoch: 28, Train loss: 1.15, Test mae: 1.52, Test rmse: 1.8, Test r2: -2.11
# Epoch: 29, Train loss: 1.69, Test mae: 1.58, Test rmse: 1.86, Test r2: -2.3
# ---------------------------------
# min mae: 1.1378977942466735
# ---------------------------------
#
# models/0/weight_9.pth
# number of mol pool: 1000
# Epoch: 0, Train loss: 62.5, Test mae: 3.78, Test rmse: 3.92, Test r2: -13.6
# Epoch: 1, Train loss: 10.5, Test mae: 3.1, Test rmse: 3.28, Test r2: -9.23
# Epoch: 2, Train loss: 7.02, Test mae: 1.42, Test rmse: 1.79, Test r2: -2.04
# Epoch: 3, Train loss: 4.25, Test mae: 2.36, Test rmse: 2.59, Test r2: -5.4
# Epoch: 4, Train loss: 3.12, Test mae: 1.18, Test rmse: 1.5, Test r2: -1.15
# Epoch: 5, Train loss: 2.51, Test mae: 1.84, Test rmse: 2.09, Test r2: -3.16
# Epoch: 6, Train loss: 1.98, Test mae: 1.03, Test rmse: 1.35, Test r2: -0.723
# Epoch: 7, Train loss: 1.56, Test mae: 1.42, Test rmse: 1.72, Test r2: -1.82
# Epoch: 8, Train loss: 1.63, Test mae: 1.03, Test rmse: 1.34, Test r2: -0.703
# Epoch: 9, Train loss: 1.34, Test mae: 1.23, Test rmse: 1.53, Test r2: -1.24
# Epoch: 10, Train loss: 1.33, Test mae: 1.09, Test rmse: 1.4, Test r2: -0.866
# Epoch: 11, Train loss: 1.26, Test mae: 1.29, Test rmse: 1.59, Test r2: -1.41
# Epoch: 12, Train loss: 1.15, Test mae: 1.09, Test rmse: 1.4, Test r2: -0.864
# Epoch: 13, Train loss: 1.08, Test mae: 1.5, Test rmse: 1.79, Test r2: -2.03
# Epoch: 14, Train loss: 1.78, Test mae: 1.15, Test rmse: 1.46, Test r2: -1.03
# Epoch: 15, Train loss: 1.1, Test mae: 1.04, Test rmse: 1.36, Test r2: -0.76
# Epoch: 16, Train loss: 1.28, Test mae: 1.36, Test rmse: 1.65, Test r2: -1.59
# Epoch: 17, Train loss: 1.17, Test mae: 1.05, Test rmse: 1.36, Test r2: -0.752
# Epoch: 18, Train loss: 1.29, Test mae: 1.19, Test rmse: 1.49, Test r2: -1.1
# Epoch: 19, Train loss: 1.19, Test mae: 1.07, Test rmse: 1.38, Test r2: -0.813
# Epoch: 20, Train loss: 0.972, Test mae: 1.05, Test rmse: 1.38, Test r2: -0.813
# Epoch: 21, Train loss: 1.61, Test mae: 1.25, Test rmse: 1.54, Test r2: -1.27
# Epoch: 22, Train loss: 1.25, Test mae: 1.07, Test rmse: 1.37, Test r2: -0.776
# Epoch: 23, Train loss: 1.16, Test mae: 1.09, Test rmse: 1.38, Test r2: -0.822
# Epoch: 24, Train loss: 1.26, Test mae: 1.03, Test rmse: 1.33, Test r2: -0.692
# Epoch: 25, Train loss: 1.29, Test mae: 1.24, Test rmse: 1.53, Test r2: -1.23
# Epoch: 26, Train loss: 1.01, Test mae: 1.14, Test rmse: 1.45, Test r2: -0.987
# Epoch: 27, Train loss: 0.997, Test mae: 1.3, Test rmse: 1.6, Test r2: -1.43
# Epoch: 28, Train loss: 1.29, Test mae: 1.01, Test rmse: 1.33, Test r2: -0.686
# Epoch: 29, Train loss: 0.94, Test mae: 1.13, Test rmse: 1.44, Test r2: -0.964
# ---------------------------------
# min mae: 1.0086764603853227
# ---------------------------------
#
# models/1/weight_28.pth
# number of mol pool: 1500
# Epoch: 0, Train loss: 50.4, Test mae: 3.16, Test rmse: 3.63, Test r2: -12.4
# Epoch: 1, Train loss: 9.19, Test mae: 1.94, Test rmse: 2.19, Test r2: -3.88
# Epoch: 2, Train loss: 5.04, Test mae: 2.1, Test rmse: 2.34, Test r2: -4.56
# Epoch: 3, Train loss: 3.64, Test mae: 1.07, Test rmse: 1.38, Test r2: -0.94
# Epoch: 4, Train loss: 3.15, Test mae: 1.02, Test rmse: 1.33, Test r2: -0.792
# Epoch: 5, Train loss: 1.92, Test mae: 1.08, Test rmse: 1.37, Test r2: -0.923
# Epoch: 6, Train loss: 1.86, Test mae: 1.1, Test rmse: 1.39, Test r2: -0.975
# Epoch: 7, Train loss: 1.4, Test mae: 1.02, Test rmse: 1.31, Test r2: -0.743
# Epoch: 8, Train loss: 1.51, Test mae: 1.1, Test rmse: 1.39, Test r2: -0.97
# Epoch: 9, Train loss: 1.48, Test mae: 1.26, Test rmse: 1.55, Test r2: -1.43
# Epoch: 10, Train loss: 1.35, Test mae: 1.2, Test rmse: 1.49, Test r2: -1.26
# Epoch: 11, Train loss: 1.43, Test mae: 1.2, Test rmse: 1.49, Test r2: -1.25
# Epoch: 12, Train loss: 1.4, Test mae: 1.02, Test rmse: 1.31, Test r2: -0.756
# Epoch: 13, Train loss: 1.19, Test mae: 1.09, Test rmse: 1.38, Test r2: -0.947
# Epoch: 14, Train loss: 1.17, Test mae: 1.12, Test rmse: 1.41, Test r2: -1.03
# Epoch: 15, Train loss: 1.19, Test mae: 1.22, Test rmse: 1.5, Test r2: -1.28
# Epoch: 16, Train loss: 1.01, Test mae: 1.11, Test rmse: 1.39, Test r2: -0.978
# Epoch: 17, Train loss: 1.03, Test mae: 1.04, Test rmse: 1.33, Test r2: -0.789
# Epoch: 18, Train loss: 0.975, Test mae: 1.01, Test rmse: 1.3, Test r2: -0.731
# Epoch: 19, Train loss: 1.34, Test mae: 1.01, Test rmse: 1.3, Test r2: -0.72
# Epoch: 20, Train loss: 1.11, Test mae: 1.1, Test rmse: 1.39, Test r2: -0.968
# Epoch: 21, Train loss: 1.31, Test mae: 1.18, Test rmse: 1.47, Test r2: -1.21
# Epoch: 22, Train loss: 1.1, Test mae: 1.01, Test rmse: 1.3, Test r2: -0.72
# Epoch: 23, Train loss: 1.1, Test mae: 1.1, Test rmse: 1.39, Test r2: -0.96
# Epoch: 24, Train loss: 1.02, Test mae: 1.11, Test rmse: 1.4, Test r2: -1.0
# Epoch: 25, Train loss: 0.942, Test mae: 1.25, Test rmse: 1.54, Test r2: -1.41
# Epoch: 26, Train loss: 1.03, Test mae: 1.26, Test rmse: 1.54, Test r2: -1.42
# Epoch: 27, Train loss: 1.15, Test mae: 0.996, Test rmse: 1.29, Test r2: -0.692
# Epoch: 28, Train loss: 1.12, Test mae: 1.25, Test rmse: 1.53, Test r2: -1.39
# Epoch: 29, Train loss: 1.16, Test mae: 1.02, Test rmse: 1.31, Test r2: -0.753
# ---------------------------------
# min mae: 0.9955126810073852
# ---------------------------------
#
# models/2/weight_27.pth
# number of mol pool: 2000
# Epoch: 0, Train loss: 44.9, Test mae: 1.78, Test rmse: 2.22, Test r2: -3.64
# Epoch: 1, Train loss: 7.75, Test mae: 1.89, Test rmse: 2.31, Test r2: -4.04
# Epoch: 2, Train loss: 4.55, Test mae: 1.12, Test rmse: 1.41, Test r2: -0.888
# Epoch: 3, Train loss: 2.8, Test mae: 1.15, Test rmse: 1.42, Test r2: -0.909
# Epoch: 4, Train loss: 2.13, Test mae: 1.02, Test rmse: 1.3, Test r2: -0.592
# Epoch: 5, Train loss: 1.76, Test mae: 1.02, Test rmse: 1.3, Test r2: -0.597
# Epoch: 6, Train loss: 1.44, Test mae: 1.03, Test rmse: 1.31, Test r2: -0.616
# Epoch: 7, Train loss: 1.51, Test mae: 1.0, Test rmse: 1.27, Test r2: -0.532
# Epoch: 8, Train loss: 1.53, Test mae: 0.998, Test rmse: 1.27, Test r2: -0.514
# Epoch: 9, Train loss: 1.29, Test mae: 1.13, Test rmse: 1.4, Test r2: -0.854
# Epoch: 10, Train loss: 1.23, Test mae: 1.2, Test rmse: 1.48, Test r2: -1.06
# Epoch: 11, Train loss: 1.28, Test mae: 1.02, Test rmse: 1.29, Test r2: -0.569
# Epoch: 12, Train loss: 1.06, Test mae: 0.993, Test rmse: 1.26, Test r2: -0.503
# Epoch: 13, Train loss: 1.1, Test mae: 1.0, Test rmse: 1.27, Test r2: -0.516
# Epoch: 14, Train loss: 1.08, Test mae: 1.04, Test rmse: 1.31, Test r2: -0.629
# Epoch: 15, Train loss: 0.995, Test mae: 0.996, Test rmse: 1.27, Test r2: -0.518
# Epoch: 16, Train loss: 0.966, Test mae: 1.02, Test rmse: 1.28, Test r2: -0.558
# Epoch: 17, Train loss: 1.01, Test mae: 1.11, Test rmse: 1.38, Test r2: -0.788
# Epoch: 18, Train loss: 1.14, Test mae: 1.09, Test rmse: 1.38, Test r2: -0.803
# Epoch: 19, Train loss: 0.941, Test mae: 0.992, Test rmse: 1.26, Test r2: -0.488
# Epoch: 20, Train loss: 0.99, Test mae: 0.985, Test rmse: 1.25, Test r2: -0.482
# Epoch: 21, Train loss: 1.14, Test mae: 1.29, Test rmse: 1.56, Test r2: -1.29
# Epoch: 22, Train loss: 1.07, Test mae: 1.01, Test rmse: 1.28, Test r2: -0.542
# Epoch: 23, Train loss: 1.06, Test mae: 1.04, Test rmse: 1.32, Test r2: -0.653
# Epoch: 24, Train loss: 0.991, Test mae: 0.989, Test rmse: 1.26, Test r2: -0.491
# Epoch: 25, Train loss: 0.986, Test mae: 0.994, Test rmse: 1.26, Test r2: -0.506
# Epoch: 26, Train loss: 0.897, Test mae: 0.988, Test rmse: 1.25, Test r2: -0.482
# Epoch: 27, Train loss: 0.9, Test mae: 1.05, Test rmse: 1.31, Test r2: -0.624
# Epoch: 28, Train loss: 1.12, Test mae: 1.07, Test rmse: 1.34, Test r2: -0.7
# Epoch: 29, Train loss: 1.31, Test mae: 1.0, Test rmse: 1.28, Test r2: -0.549
# ---------------------------------
# min mae: 0.9846054853498936
# ---------------------------------
#
# models/3/weight_20.pth
# number of mol pool: 2500
# Epoch: 0, Train loss: 33.4, Test mae: 3.1, Test rmse: 3.27, Test r2: -9.1
# Epoch: 1, Train loss: 5.37, Test mae: 1.61, Test rmse: 1.88, Test r2: -2.33
# Epoch: 2, Train loss: 3.07, Test mae: 1.01, Test rmse: 1.29, Test r2: -0.581
# Epoch: 3, Train loss: 2.16, Test mae: 1.04, Test rmse: 1.32, Test r2: -0.653
# Epoch: 4, Train loss: 1.59, Test mae: 1.0, Test rmse: 1.27, Test r2: -0.514
# Epoch: 5, Train loss: 1.59, Test mae: 1.05, Test rmse: 1.31, Test r2: -0.63
# Epoch: 6, Train loss: 1.26, Test mae: 0.983, Test rmse: 1.25, Test r2: -0.477
# Epoch: 7, Train loss: 1.33, Test mae: 1.02, Test rmse: 1.29, Test r2: -0.562
# Epoch: 8, Train loss: 1.26, Test mae: 0.979, Test rmse: 1.25, Test r2: -0.469
# Epoch: 9, Train loss: 1.24, Test mae: 0.984, Test rmse: 1.25, Test r2: -0.477
# Epoch: 10, Train loss: 1.26, Test mae: 1.06, Test rmse: 1.35, Test r2: -0.709
# Epoch: 11, Train loss: 1.07, Test mae: 0.956, Test rmse: 1.22, Test r2: -0.402
# Epoch: 12, Train loss: 1.14, Test mae: 1.11, Test rmse: 1.38, Test r2: -0.802
# Epoch: 13, Train loss: 1.1, Test mae: 1.07, Test rmse: 1.34, Test r2: -0.683
# Epoch: 14, Train loss: 0.943, Test mae: 1.03, Test rmse: 1.29, Test r2: -0.582
# Epoch: 15, Train loss: 1.03, Test mae: 1.08, Test rmse: 1.34, Test r2: -0.706
# Epoch: 16, Train loss: 0.982, Test mae: 0.989, Test rmse: 1.25, Test r2: -0.477
# Epoch: 17, Train loss: 1.01, Test mae: 0.972, Test rmse: 1.24, Test r2: -0.448
# Epoch: 18, Train loss: 0.99, Test mae: 0.957, Test rmse: 1.22, Test r2: -0.406
# Epoch: 19, Train loss: 0.916, Test mae: 0.952, Test rmse: 1.21, Test r2: -0.393
# Epoch: 20, Train loss: 1.06, Test mae: 0.943, Test rmse: 1.21, Test r2: -0.382
# Epoch: 21, Train loss: 1.01, Test mae: 0.928, Test rmse: 1.19, Test r2: -0.331
# Epoch: 22, Train loss: 1.0, Test mae: 0.994, Test rmse: 1.26, Test r2: -0.488
# Epoch: 23, Train loss: 0.971, Test mae: 0.956, Test rmse: 1.21, Test r2: -0.391
# Epoch: 24, Train loss: 0.968, Test mae: 0.959, Test rmse: 1.22, Test r2: -0.412
# Epoch: 25, Train loss: 0.898, Test mae: 0.973, Test rmse: 1.25, Test r2: -0.473
# Epoch: 26, Train loss: 0.896, Test mae: 1.0, Test rmse: 1.27, Test r2: -0.522
# Epoch: 27, Train loss: 1.1, Test mae: 1.33, Test rmse: 1.61, Test r2: -1.45
# Epoch: 28, Train loss: 1.05, Test mae: 1.01, Test rmse: 1.28, Test r2: -0.543
# Epoch: 29, Train loss: 0.902, Test mae: 0.961, Test rmse: 1.23, Test r2: -0.434
# ---------------------------------
# min mae: 0.9277284971475601
# ---------------------------------
#
# models/4/weight_21.pth
# number of mol pool: 3000
# Epoch: 0, Train loss: 28.2, Test mae: 1.4, Test rmse: 1.72, Test r2: -1.75
# Epoch: 1, Train loss: 5.47, Test mae: 1.2, Test rmse: 1.54, Test r2: -1.23
# Epoch: 2, Train loss: 2.76, Test mae: 1.38, Test rmse: 1.65, Test r2: -1.55
# Epoch: 3, Train loss: 1.75, Test mae: 0.98, Test rmse: 1.27, Test r2: -0.498
# Epoch: 4, Train loss: 1.35, Test mae: 1.1, Test rmse: 1.38, Test r2: -0.78
# Epoch: 5, Train loss: 1.1, Test mae: 0.986, Test rmse: 1.27, Test r2: -0.506
# Epoch: 6, Train loss: 0.989, Test mae: 0.987, Test rmse: 1.27, Test r2: -0.508
# Epoch: 7, Train loss: 1.07, Test mae: 0.99, Test rmse: 1.27, Test r2: -0.51
# Epoch: 8, Train loss: 1.01, Test mae: 1.01, Test rmse: 1.29, Test r2: -0.555
# Epoch: 9, Train loss: 0.98, Test mae: 0.98, Test rmse: 1.26, Test r2: -0.479
# Epoch: 10, Train loss: 0.849, Test mae: 1.03, Test rmse: 1.31, Test r2: -0.605
# Epoch: 11, Train loss: 0.843, Test mae: 1.17, Test rmse: 1.45, Test r2: -0.976
# Epoch: 12, Train loss: 1.03, Test mae: 0.982, Test rmse: 1.26, Test r2: -0.486
# Epoch: 13, Train loss: 1.07, Test mae: 0.974, Test rmse: 1.26, Test r2: -0.476
# Epoch: 14, Train loss: 1.0, Test mae: 0.992, Test rmse: 1.27, Test r2: -0.514
# Epoch: 15, Train loss: 0.911, Test mae: 1.01, Test rmse: 1.29, Test r2: -0.558
# Epoch: 16, Train loss: 1.04, Test mae: 1.19, Test rmse: 1.46, Test r2: -0.991
# Epoch: 17, Train loss: 1.02, Test mae: 0.978, Test rmse: 1.26, Test r2: -0.474
# Epoch: 18, Train loss: 0.87, Test mae: 0.991, Test rmse: 1.26, Test r2: -0.493
# Epoch: 19, Train loss: 0.833, Test mae: 1.04, Test rmse: 1.32, Test r2: -0.621
# Epoch: 20, Train loss: 0.915, Test mae: 0.976, Test rmse: 1.26, Test r2: -0.478
# Epoch: 21, Train loss: 0.927, Test mae: 1.13, Test rmse: 1.4, Test r2: -0.82
# Epoch: 22, Train loss: 0.868, Test mae: 0.985, Test rmse: 1.26, Test r2: -0.479
# Epoch: 23, Train loss: 1.0, Test mae: 1.09, Test rmse: 1.35, Test r2: -0.713
# Epoch: 24, Train loss: 0.995, Test mae: 0.981, Test rmse: 1.26, Test r2: -0.483
# Epoch: 25, Train loss: 0.919, Test mae: 1.26, Test rmse: 1.54, Test r2: -1.21
# Epoch: 26, Train loss: 1.01, Test mae: 0.999, Test rmse: 1.29, Test r2: -0.558
# Epoch: 27, Train loss: 0.756, Test mae: 0.991, Test rmse: 1.27, Test r2: -0.501
# Epoch: 28, Train loss: 0.905, Test mae: 0.981, Test rmse: 1.26, Test r2: -0.48
# Epoch: 29, Train loss: 0.925, Test mae: 1.09, Test rmse: 1.36, Test r2: -0.737
# ---------------------------------
# min mae: 0.9743832609057427
# ---------------------------------
#
# models/5/weight_13.pth
# number of mol pool: 3500
# Epoch: 0, Train loss: 28.5, Test mae: 1.23, Test rmse: 1.56, Test r2: -1.34
# Epoch: 1, Train loss: 5.12, Test mae: 1.12, Test rmse: 1.42, Test r2: -0.939
# Epoch: 2, Train loss: 2.29, Test mae: 1.07, Test rmse: 1.36, Test r2: -0.764
# Epoch: 3, Train loss: 1.74, Test mae: 0.985, Test rmse: 1.26, Test r2: -0.522
# Epoch: 4, Train loss: 1.3, Test mae: 1.07, Test rmse: 1.34, Test r2: -0.734
# Epoch: 5, Train loss: 1.24, Test mae: 0.983, Test rmse: 1.25, Test r2: -0.509
# Epoch: 6, Train loss: 1.22, Test mae: 0.979, Test rmse: 1.25, Test r2: -0.501
# Epoch: 7, Train loss: 1.08, Test mae: 0.977, Test rmse: 1.25, Test r2: -0.491
# Epoch: 8, Train loss: 1.06, Test mae: 0.981, Test rmse: 1.25, Test r2: -0.494
# Epoch: 9, Train loss: 1.07, Test mae: 0.98, Test rmse: 1.25, Test r2: -0.499
# Epoch: 10, Train loss: 1.05, Test mae: 1.02, Test rmse: 1.29, Test r2: -0.6
# Epoch: 11, Train loss: 1.14, Test mae: 1.17, Test rmse: 1.45, Test r2: -1.02
# Epoch: 12, Train loss: 1.2, Test mae: 1.01, Test rmse: 1.29, Test r2: -0.592
# Epoch: 13, Train loss: 1.06, Test mae: 0.984, Test rmse: 1.26, Test r2: -0.512
# Epoch: 14, Train loss: 1.02, Test mae: 0.971, Test rmse: 1.24, Test r2: -0.473
# Epoch: 15, Train loss: 1.09, Test mae: 0.976, Test rmse: 1.24, Test r2: -0.487
# Epoch: 16, Train loss: 1.04, Test mae: 1.08, Test rmse: 1.36, Test r2: -0.776
# Epoch: 17, Train loss: 0.932, Test mae: 0.987, Test rmse: 1.26, Test r2: -0.526
# Epoch: 18, Train loss: 0.844, Test mae: 1.02, Test rmse: 1.3, Test r2: -0.62
# Epoch: 19, Train loss: 0.88, Test mae: 0.981, Test rmse: 1.25, Test r2: -0.502
# Epoch: 20, Train loss: 0.975, Test mae: 0.981, Test rmse: 1.26, Test r2: -0.514
# Epoch: 21, Train loss: 1.01, Test mae: 1.01, Test rmse: 1.28, Test r2: -0.567
# Epoch: 22, Train loss: 1.16, Test mae: 1.02, Test rmse: 1.29, Test r2: -0.607
# Epoch: 23, Train loss: 1.02, Test mae: 0.982, Test rmse: 1.25, Test r2: -0.488
# Epoch: 24, Train loss: 0.92, Test mae: 0.972, Test rmse: 1.24, Test r2: -0.464
# Epoch: 25, Train loss: 0.832, Test mae: 0.974, Test rmse: 1.25, Test r2: -0.495
# Epoch: 26, Train loss: 0.946, Test mae: 1.03, Test rmse: 1.31, Test r2: -0.636
# Epoch: 27, Train loss: 0.788, Test mae: 0.996, Test rmse: 1.27, Test r2: -0.541
# Epoch: 28, Train loss: 0.941, Test mae: 1.03, Test rmse: 1.31, Test r2: -0.646
# Epoch: 29, Train loss: 0.842, Test mae: 0.977, Test rmse: 1.24, Test r2: -0.487
# ---------------------------------
# min mae: 0.9707006728649139
# ---------------------------------
#
# models/6/weight_14.pth
# number of mol pool: 4000
# Epoch: 0, Train loss: 22.5, Test mae: 1.15, Test rmse: 1.45, Test r2: -1.03
# Epoch: 1, Train loss: 3.55, Test mae: 0.982, Test rmse: 1.25, Test r2: -0.514
# Epoch: 2, Train loss: 2.04, Test mae: 0.945, Test rmse: 1.19, Test r2: -0.382
# Epoch: 3, Train loss: 1.52, Test mae: 0.907, Test rmse: 1.16, Test r2: -0.303
# Epoch: 4, Train loss: 1.4, Test mae: 1.1, Test rmse: 1.36, Test r2: -0.802
# Epoch: 5, Train loss: 1.27, Test mae: 1.01, Test rmse: 1.27, Test r2: -0.559
# Epoch: 6, Train loss: 1.17, Test mae: 0.927, Test rmse: 1.17, Test r2: -0.338
# Epoch: 7, Train loss: 1.17, Test mae: 0.986, Test rmse: 1.26, Test r2: -0.54
# Epoch: 8, Train loss: 1.12, Test mae: 1.02, Test rmse: 1.27, Test r2: -0.57
# Epoch: 9, Train loss: 1.11, Test mae: 0.951, Test rmse: 1.2, Test r2: -0.406
# Epoch: 10, Train loss: 0.954, Test mae: 0.92, Test rmse: 1.17, Test r2: -0.329
# Epoch: 11, Train loss: 1.08, Test mae: 0.954, Test rmse: 1.21, Test r2: -0.409
# Epoch: 12, Train loss: 1.02, Test mae: 0.939, Test rmse: 1.19, Test r2: -0.383
# Epoch: 13, Train loss: 1.08, Test mae: 0.99, Test rmse: 1.25, Test r2: -0.522
# Epoch: 14, Train loss: 0.954, Test mae: 0.93, Test rmse: 1.18, Test r2: -0.359
# Epoch: 15, Train loss: 1.24, Test mae: 1.16, Test rmse: 1.42, Test r2: -0.957
# Epoch: 16, Train loss: 1.15, Test mae: 0.943, Test rmse: 1.2, Test r2: -0.397
# Epoch: 17, Train loss: 1.0, Test mae: 0.912, Test rmse: 1.17, Test r2: -0.321
# Epoch: 18, Train loss: 1.25, Test mae: 1.09, Test rmse: 1.35, Test r2: -0.762
# Epoch: 19, Train loss: 0.997, Test mae: 0.966, Test rmse: 1.22, Test r2: -0.439
# Epoch: 20, Train loss: 0.984, Test mae: 0.975, Test rmse: 1.22, Test r2: -0.454
# Epoch: 21, Train loss: 0.891, Test mae: 1.04, Test rmse: 1.33, Test r2: -0.706
# Epoch: 22, Train loss: 1.1, Test mae: 1.06, Test rmse: 1.32, Test r2: -0.677
# Epoch: 23, Train loss: 1.01, Test mae: 0.996, Test rmse: 1.25, Test r2: -0.521
# Epoch: 24, Train loss: 0.874, Test mae: 0.919, Test rmse: 1.17, Test r2: -0.323
# Epoch: 25, Train loss: 0.971, Test mae: 1.09, Test rmse: 1.36, Test r2: -0.782
# Epoch: 26, Train loss: 0.917, Test mae: 0.981, Test rmse: 1.23, Test r2: -0.478
# Epoch: 27, Train loss: 0.816, Test mae: 0.967, Test rmse: 1.22, Test r2: -0.444
# Epoch: 28, Train loss: 0.884, Test mae: 0.915, Test rmse: 1.16, Test r2: -0.306
# Epoch: 29, Train loss: 0.943, Test mae: 0.926, Test rmse: 1.18, Test r2: -0.339
# ---------------------------------
# min mae: 0.9074286390095949
# ---------------------------------
#
# models/7/weight_3.pth
# number of mol pool: 4500
# Epoch: 0, Train loss: 23.5, Test mae: 1.39, Test rmse: 1.69, Test r2: -1.77
# Epoch: 1, Train loss: 3.66, Test mae: 1.27, Test rmse: 1.54, Test r2: -1.3
# Epoch: 2, Train loss: 2.59, Test mae: 0.935, Test rmse: 1.2, Test r2: -0.403
# Epoch: 3, Train loss: 1.91, Test mae: 0.947, Test rmse: 1.21, Test r2: -0.417
# Epoch: 4, Train loss: 1.5, Test mae: 0.94, Test rmse: 1.19, Test r2: -0.379
# Epoch: 5, Train loss: 1.46, Test mae: 0.936, Test rmse: 1.2, Test r2: -0.388
# Epoch: 6, Train loss: 1.3, Test mae: 0.969, Test rmse: 1.23, Test r2: -0.474
# Epoch: 7, Train loss: 1.24, Test mae: 0.931, Test rmse: 1.19, Test r2: -0.374
# Epoch: 8, Train loss: 1.29, Test mae: 0.98, Test rmse: 1.24, Test r2: -0.486
# Epoch: 9, Train loss: 1.21, Test mae: 0.965, Test rmse: 1.22, Test r2: -0.452
# Epoch: 10, Train loss: 1.4, Test mae: 0.909, Test rmse: 1.17, Test r2: -0.319
# Epoch: 11, Train loss: 1.67, Test mae: 1.18, Test rmse: 1.44, Test r2: -1.01
# Epoch: 12, Train loss: 1.3, Test mae: 0.927, Test rmse: 1.18, Test r2: -0.36
# Epoch: 13, Train loss: 1.41, Test mae: 0.919, Test rmse: 1.17, Test r2: -0.327
# Epoch: 14, Train loss: 1.28, Test mae: 0.91, Test rmse: 1.17, Test r2: -0.324
# Epoch: 15, Train loss: 1.13, Test mae: 0.93, Test rmse: 1.19, Test r2: -0.383
# Epoch: 16, Train loss: 1.27, Test mae: 0.905, Test rmse: 1.16, Test r2: -0.302
# Epoch: 17, Train loss: 1.26, Test mae: 0.92, Test rmse: 1.17, Test r2: -0.326
# Epoch: 18, Train loss: 1.07, Test mae: 1.1, Test rmse: 1.35, Test r2: -0.771
# Epoch: 19, Train loss: 1.22, Test mae: 1.67, Test rmse: 1.9, Test r2: -2.5
# Epoch: 20, Train loss: 1.66, Test mae: 0.962, Test rmse: 1.21, Test r2: -0.427
# Epoch: 21, Train loss: 1.25, Test mae: 0.915, Test rmse: 1.16, Test r2: -0.296
# Epoch: 22, Train loss: 1.13, Test mae: 0.945, Test rmse: 1.19, Test r2: -0.372
# Epoch: 23, Train loss: 1.1, Test mae: 1.01, Test rmse: 1.29, Test r2: -0.615
# Epoch: 24, Train loss: 1.07, Test mae: 0.925, Test rmse: 1.17, Test r2: -0.329
# Epoch: 25, Train loss: 1.09, Test mae: 0.899, Test rmse: 1.15, Test r2: -0.279
# Epoch: 26, Train loss: 1.38, Test mae: 0.961, Test rmse: 1.23, Test r2: -0.478
# Epoch: 27, Train loss: 1.05, Test mae: 1.21, Test rmse: 1.47, Test r2: -1.09
# Epoch: 28, Train loss: 1.1, Test mae: 0.936, Test rmse: 1.18, Test r2: -0.35
# Epoch: 29, Train loss: 1.01, Test mae: 1.14, Test rmse: 1.4, Test r2: -0.89
# ---------------------------------
# min mae: 0.898861860897806
# ---------------------------------
#
# models/8/weight_25.pth
# number of mol pool: 5000
# Epoch: 0, Train loss: 19.9, Test mae: 1.83, Test rmse: 2.11, Test r2: -3.36
# Epoch: 1, Train loss: 3.15, Test mae: 0.993, Test rmse: 1.27, Test r2: -0.58
# Epoch: 2, Train loss: 2.12, Test mae: 1.05, Test rmse: 1.31, Test r2: -0.675
# Epoch: 3, Train loss: 1.78, Test mae: 0.931, Test rmse: 1.19, Test r2: -0.381
# Epoch: 4, Train loss: 1.45, Test mae: 0.931, Test rmse: 1.19, Test r2: -0.383
# Epoch: 5, Train loss: 1.18, Test mae: 0.932, Test rmse: 1.19, Test r2: -0.389
# Epoch: 6, Train loss: 1.1, Test mae: 0.952, Test rmse: 1.2, Test r2: -0.419
# Epoch: 7, Train loss: 1.15, Test mae: 0.932, Test rmse: 1.19, Test r2: -0.38
# Epoch: 8, Train loss: 1.06, Test mae: 0.906, Test rmse: 1.16, Test r2: -0.325
# Epoch: 9, Train loss: 1.08, Test mae: 0.903, Test rmse: 1.15, Test r2: -0.306
# Epoch: 10, Train loss: 1.08, Test mae: 0.906, Test rmse: 1.16, Test r2: -0.326
# Epoch: 11, Train loss: 1.06, Test mae: 0.921, Test rmse: 1.18, Test r2: -0.376
# Epoch: 12, Train loss: 0.959, Test mae: 0.966, Test rmse: 1.22, Test r2: -0.472
# Epoch: 13, Train loss: 0.932, Test mae: 0.898, Test rmse: 1.15, Test r2: -0.303
# Epoch: 14, Train loss: 1.03, Test mae: 1.39, Test rmse: 1.63, Test r2: -1.6
# Epoch: 15, Train loss: 1.06, Test mae: 0.888, Test rmse: 1.14, Test r2: -0.276
# Epoch: 16, Train loss: 0.974, Test mae: 1.36, Test rmse: 1.6, Test r2: -1.52
# Epoch: 17, Train loss: 1.21, Test mae: 0.899, Test rmse: 1.16, Test r2: -0.315
# Epoch: 18, Train loss: 1.07, Test mae: 0.895, Test rmse: 1.15, Test r2: -0.306
# Epoch: 19, Train loss: 0.982, Test mae: 0.955, Test rmse: 1.21, Test r2: -0.426
# Epoch: 20, Train loss: 0.976, Test mae: 0.926, Test rmse: 1.18, Test r2: -0.356
# Epoch: 21, Train loss: 0.974, Test mae: 1.06, Test rmse: 1.31, Test r2: -0.695
# Epoch: 22, Train loss: 0.981, Test mae: 0.896, Test rmse: 1.15, Test r2: -0.296
# Epoch: 23, Train loss: 0.975, Test mae: 1.05, Test rmse: 1.31, Test r2: -0.674
# Epoch: 24, Train loss: 0.947, Test mae: 1.03, Test rmse: 1.29, Test r2: -0.622
# Epoch: 25, Train loss: 1.04, Test mae: 0.928, Test rmse: 1.19, Test r2: -0.392
# Epoch: 26, Train loss: 1.04, Test mae: 0.885, Test rmse: 1.14, Test r2: -0.27
# Epoch: 27, Train loss: 1.07, Test mae: 0.927, Test rmse: 1.2, Test r2: -0.408
# Epoch: 28, Train loss: 0.957, Test mae: 0.971, Test rmse: 1.22, Test r2: -0.47
# Epoch: 29, Train loss: 0.893, Test mae: 1.01, Test rmse: 1.28, Test r2: -0.615
# ---------------------------------
# min mae: 0.8847856440544128
# ---------------------------------
#
# models/9/weight_26.pth
