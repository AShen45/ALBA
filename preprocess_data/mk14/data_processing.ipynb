# %%
# !pip install datamol
# !pip install rdkit-pypi
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.7/381.7 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 44.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Project/ALVS")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from rdkit import Chem
import glob
import datamol as dm
from sklearn.model_selection import train_test_split

# %%
def load_score(mol_files):
    name_scores = []
    for mol_file in mol_files:
        mols = Chem.SDMolSupplier(mol_file, sanitize=False)
        for m in mols:
            score = m.GetProp("minimizedAffinity")
            name = m.GetProp("_Name")
            try:
                smi = Chem.MolToSmiles(m)
            except:
                print(m)
            smi = smi.replace("/", "").replace("@", "").replace("\\", "")
            name_scores.append([name, smi, float(score)])
    return name_scores

# %%
def ensemble_merge(df):
    name_miniscore = []
    for name, dfg in df.groupby("name"):
        mini_score = dfg["score"].min()
        smis = dfg["smiles"].unique()
        # if len(smis) != 1:
        #     print(name)
        #     raise RuntimeError("smiles is not unique!")
        smi = smis[0]
        name_miniscore.append([name, smi, mini_score])
    df_merge = pd.DataFrame(name_miniscore)
    df_merge.columns = ["name", "smiles", "score"]
    return df_merge

# %%
def fix_smiles(smi):
    mol = dm.to_mol(smi, ordered=True, sanitize=False)
    mol = dm.fix_mol(mol)
    mol = dm.sanitize_mol(mol, sanifix=True, charge_neutral=False)
    if not mol:
        return "error"
    mol = dm.standardize_mol(mol, disconnect_metals=False, normalize=True, reionize=False, uncharge=False)
    smi = dm.standardize_smiles(dm.to_smiles(mol))
    return smi

# %%
mol_files = glob.glob("data/mk14/*.sdf")

# %%
name_scores = load_score(mol_files)
# Out:
# [16:03:34]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [16:03:34]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [16:03:34]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [16:03:34]
#
# ****
# ...

# %%
df = pd.DataFrame(name_scores)
df.columns = ["name", "smiles", "score"]

# %%
df_merge = ensemble_merge(df)

# %%
len(df_merge)
# Out:
# 36379

# %%
df_merge.head()
# Out:
#            name                                             smiles     score
# 0  CHEMBL100847  [H]N(C(=O)N([H])[CH]1CCC2=C1C=CC=C2)C1=CC(C(C)... -8.610486
# 1  CHEMBL101035  [H]N(C(=O)N([H])C1=CC(C(C)(C)C)=NN1C1=CC=C(C)C... -7.983886
# 2  CHEMBL103667  [H]N(C(=O)N([H])C1=CC(C(C)(C)C)=NN1C1=CC=C(C)C... -8.341467
# 3  CHEMBL104749  [H]N(C(=O)N([H])C1=CC(C(C)(C)C)=NN1C)C1=CC=C(O... -7.769324
# 4  CHEMBL104991  [H]N(C(=O)N([H])C1=C2C=CC=CC2=C(OCCN2CCOCC2)C=... -8.328546

# %%
df_merge["smiles"] = df_merge["smiles"].map(lambda x: fix_smiles(x))
# Out:
# Streaming output truncated to the last 5000 lines.
# [16:09:19] Initializing Normalizer
# [16:09:19] Running Normalizer
# [16:09:19] Initializing MetalDisconnector
# [16:09:19] Running MetalDisconnector
# [16:09:19] Initializing Normalizer
# [16:09:19] Running Normalizer
# [16:09:19] WARNING: not removing hydrogen atom without neighbors
# [16:09:19] Initializing Normalizer
# [16:09:19] Running Normalizer
# [16:09:19] Initializing MetalDisconnector
# [16:09:19] Running MetalDisconnector
# [16:09:19] Initializing Normalizer
# [16:09:19] Running Normalizer
# [16:09:19] WARNING: not removing hydrogen atom without neighbors
# [16:09:19] Initializing Normalizer
# [16:09:19] Running Normalizer
# [16:09:19] Initializing MetalDisconnector
# [16:09:19] Running MetalDisconnector
# [16:09:19] Initializing Normalizer
# [16:09:19] Running Normalizer
# [16:09:19] WARNING: not removing hydrogen atom without neighbors
# [16:09:19] Initializing Normalizer
# [16:09:19] Running Normalizer
# ...

# %%
df_merge.head()
# Out:
#            name                                             smiles     score
# 0  CHEMBL100847   CC(C)(C)c1cc(NC(=O)NC2CCc3ccccc32)n(-c2ccccc2)n1 -8.610486
# 1  CHEMBL101035  Cc1ccc(-n2nc(C(C)(C)C)cc2NC(=O)Nc2ccc(OCCN3CCO... -7.983886
# 2  CHEMBL103667  Cc1ccc(-n2nc(C(C)(C)C)cc2NC(=O)Nc2ccc(OCCN3CCO... -8.341467
# 3  CHEMBL104749  Cn1nc(C(C)(C)C)cc1NC(=O)Nc1ccc(OCCN2CCOCC2)c2c... -7.769324
# 4  CHEMBL104991  Cc1ccc(-n2nc(C(C)(C)C)cc2NC(=O)Nc2ccc(OCCN3CCO... -8.328546

# %%
df_train, df_test = train_test_split(df_merge, test_size=0.4)

# %%
df_train.to_csv("preprocess_data/mk14/mk14_train.csv", index=None, sep="\t")
df_test.to_csv("preprocess_data/mk14/mk14_test.csv", index=None, sep="\t")

# %%
df_train.head()
# Out:
#                name                                             smiles  \
# 28235  ZINC41586169  CCOC(=O)C1CCN(Cc2c(O)cc(C)c3c2OC(=Cc2c(F)cccc2...
# 34410  ZINC64006786  Cc1ccccc1C1C2Nc3ccccc3C2CCN1C(=O)C1NN(C)C(=O)c...
# 8755   ZINC09692174  CCC(=O)n1ccc2cc(S(=O)(=O)NC(CC(C)C)C(=O)Nc3ccc...
# 19967  ZINC34747412  NC(=O)CN1CCN(c2nc3sc4c(c3c(=O)n2CCCc2ccccc2)CC...
# 22952  ZINC38119038                CC(CO)(Nc1cccc(F)c1)c1ccc2c(c1)OCO2
#
#           score
# 28235 -9.073838
# 34410 -8.604339
# 8755  -8.434819
# 19967 -7.955853
# 22952 -7.601646

# %%
len(df_train)
# Out:
# 21827

# %%
len(df_test)
# Out:
# 14552

# %%
df_merge.to_csv("preprocess_data/mk14/mk14_processed.csv", index=None, sep="\t")
