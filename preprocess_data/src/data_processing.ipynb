# %%
# !pip install datamol
# !pip install rdkit-pypi
# !pip install pandas
# Out:
# Collecting datamol
#   Downloading datamol-0.11.3-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.7/381.7 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from datamol) (4.66.1)
# Collecting loguru (from datamol)
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from datamol) (1.3.2)
# Requirement already satisfied: fsspec>=2021.9 in /usr/local/lib/python3.10/dist-packages (from datamol) (2023.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datamol) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.11.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from datamol) (3.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from datamol) (9.4.0)
# Collecting selfies (from datamol)
#   Downloading selfies-2.1.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from datamol) (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from datamol) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datamol) (23.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from datamol) (4.5.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from datamol) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datamol) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->datamol) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->datamol) (1.16.0)
# Installing collected packages: selfies, loguru, datamol
# Successfully installed datamol-0.11.3 loguru-0.7.2 selfies-2.1.1
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 62.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (9.4.0)
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Project/ALVS")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from rdkit import Chem
import glob
import datamol as dm
from sklearn.model_selection import train_test_split

# %%
def load_score(mol_files):
    name_scores = []
    for mol_file in mol_files:
        mols = Chem.SDMolSupplier(mol_file, sanitize=False)
        for m in mols:
            score = m.GetProp("minimizedAffinity")
            name = m.GetProp("_Name")
            try:
                smi = Chem.MolToSmiles(m)
            except:
                print(m)
            smi = smi.replace("/", "").replace("@", "").replace("\\", "")
            name_scores.append([name, smi, float(score)])
    return name_scores

# %%
def ensemble_merge(df):
    name_miniscore = []
    for name, dfg in df.groupby("name"):
        mini_score = dfg["score"].min()
        smis = dfg["smiles"].unique()
        # if len(smis) != 1:
        #     print(name)
        #     raise RuntimeError("smiles is not unique!")
        smi = smis[0]
        name_miniscore.append([name, smi, mini_score])
    df_merge = pd.DataFrame(name_miniscore)
    df_merge.columns = ["name", "smiles", "score"]
    return df_merge

# %%
def fix_smiles(smi):
    mol = dm.to_mol(smi, ordered=True, sanitize=False)
    mol = dm.fix_mol(mol)
    mol = dm.sanitize_mol(mol, sanifix=True, charge_neutral=False)
    if not mol:
        return "error"
    mol = dm.standardize_mol(mol, disconnect_metals=False, normalize=True, reionize=False, uncharge=False)
    smi = dm.standardize_smiles(dm.to_smiles(mol))
    return smi

# %%
mol_files = glob.glob("data/src/*.sdf")

# %%
name_scores = load_score(mol_files)
# Out:
# [22:20:30]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [22:20:30]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
# <rdkit.Chem.rdchem.Mol object at 0x7c6d77fdd2a0>
# <rdkit.Chem.rdchem.Mol object at 0x7c6d77fdd460>
# [22:20:31]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
# <rdkit.Chem.rdchem.Mol object at 0x7c6d78016ff0>
# [22:20:39]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [22:20:39]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [22:20:39]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [22:20:39]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
# <rdkit.Chem.rdchem.Mol object at 0x7c6d77a74d60>
# <rdkit.Chem.rdchem.Mol object at 0x7c6d77a751c0>
# <rdkit.Chem.rdchem.Mol object at 0x7c6d77a752a0>
# <rdkit.Chem.rdchem.Mol object at 0x7c6d77a75310>
# [22:20:59]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
# <rdkit.Chem.rdchem.Mol object at 0x7c6d76930900>
# [22:21:06] Conflicting single bond directions around double bond at index 3.
# [22:21:06]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [22:21:14]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [22:21:14]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
# <rdkit.Chem.rdchem.Mol object at 0x7c6d75d92960>
# <rdkit.Chem.rdchem.Mol object at 0x7c6d75d92960>
# [22:21:52]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [22:21:52]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
# <rdkit.Chem.rdchem.Mol object at 0x7c6d73cc30d0>
# <rdkit.Chem.rdchem.Mol object at 0x7c6d73cc30d0>
# [22:22:03]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
# <rdkit.Chem.rdchem.Mol object at 0x7c6d73271700>
# [22:22:04] Conflicting single bond directions around double bond at index 3.
# [22:22:04]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [22:22:05]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
# <rdkit.Chem.rdchem.Mol object at 0x7c6d72e480b0>
# [22:22:14]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
# <rdkit.Chem.rdchem.Mol object at 0x7c6d73272180>
# [22:22:25]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [22:22:25]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
# <rdkit.Chem.rdchem.Mol object at 0x7c6d71ca9b60>
# <rdkit.Chem.rdchem.Mol object at 0x7c6d71ca9c40>
# [22:22:27]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [22:22:27]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [22:22:27]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [22:22:27]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
# <rdkit.Chem.rdchem.Mol object at 0x7c6d71b6b140>
# <rdkit.Chem.rdchem.Mol object at 0x7c6d71b6b6f0>
# <rdkit.Chem.rdchem.Mol object at 0x7c6d71b6b6f0>
# <rdkit.Chem.rdchem.Mol object at 0x7c6d71b6b7d0>
# [22:22:27]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
#
# [22:22:27]
#
# ****
# Invariant Violation
# inconsistent state
# Violation occurred on line 310 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/Canon.cpp
# Failed Expression: ((firstFromAtom2->getBeginAtomIdx() == atom2->getIdx()) ^ (secondFromAtom2->getBeginAtomIdx() == atom2->getIdx()))
# ****
# <rdkit.Chem.rdchem.Mol object at 0x7c6d71bcef80>
# <rdkit.Chem.rdchem.Mol object at 0x7c6d71bcef80>

# %%
df = pd.DataFrame(name_scores)
df.columns = ["name", "smiles", "score"]

# %%
df_merge = ensemble_merge(df)

# %%
len(df_merge)
# Out:
# 34965

# %%
df_merge.head()
# Out:
#            name                                             smiles     score
# 0  CHEMBL100551  [H]N1C2=NC=NC(N([H])C3=C(Cl)C=C(Cl)C(OC)=C3)=C... -8.404626
# 1  CHEMBL100825  [H]N(C1=CC(OC)=C(Cl)C=C1Cl)C1=C(C#N)C=NC2=CC(C... -9.347998
# 2  CHEMBL101081  [H]N(C1=CC(OC)=C(Cl)C=C1Cl)C1=C(C#N)C=NC2=CC(C... -9.123454
# 3  CHEMBL102595  [H]N(C1=CC(OC)=C(Cl)C=C1Cl)C1=C(C#N)C=NC2=CC(C... -9.455883
# 4  CHEMBL103293  [H]N(C1=CC(OC)=C(Cl)C=C1Cl)C1=C2C=CC(C3=CC(CCN... -9.521552

# %%
df_merge["smiles"] = df_merge["smiles"].map(lambda x: fix_smiles(x))
# Out:
# Streaming output truncated to the last 5000 lines.
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Explicit valence for atom # 29 N, 4, is greater than permitted
# [22:26:10] DEBUG: O=C(C[NH]1CCCCC1C1=NC(C2=CC=C(F)C=C2)=NO1)NCC1=CC=C(F)C=C1 failed due to Explicit valence for atom # 29 N, 4, is greater than permitted
#
# [22:26:10] Explicit valence for atom # 17 N, 4, is greater than permitted
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Explicit valence for atom # 29 N, 4, is greater than permitted
# [22:26:10] Explicit valence for atom # 29 N, 4, is greater than permitted
# [22:26:10] INFO: [ValenceValidation] Explicit valence for atom # 29 N, 4, is greater than permitted
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] Initializing MetalDisconnector
# [22:26:10] Running MetalDisconnector
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:10] WARNING: not removing hydrogen atom without neighbors
# [22:26:10] Initializing Normalizer
# [22:26:10] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 29 N, 4, is greater than permitted
# [22:26:11] DEBUG: CC(C)[NH]1CCC(CC(=O)N2CCC3(C2)NCC2=C(C=CC=C2)NC3NC(C)(C)C)CC1 failed due to Explicit valence for atom # 29 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 29 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 29 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 29 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 29 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 30 N, 4, is greater than permitted
# [22:26:11] DEBUG: C[NH](C)CCCNC(=O)C1CCN(C2=NC3=C(N=C(C4=CC=C(F)C=C4)C=C3)S2)CC1 failed due to Explicit valence for atom # 30 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 14 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 30 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 30 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 30 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 24 N, 4, is greater than permitted
# [22:26:11] DEBUG: C[NH]1CNNC1C1CCCN(C(=O)CCC2=CNC3=C2C=CC=C3)C1 failed due to Explicit valence for atom # 24 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 5 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 24 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 24 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 24 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 31 N, 4, is greater than permitted
# [22:26:11] DEBUG: CC(C)CN1C(=O)C2=CC(C(=O)NCCC3CC[NH](C(C)C)CC3)=NN2C2=CC=CC=C21 failed due to Explicit valence for atom # 31 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 31 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 31 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 31 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 31 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 28 N, 4, is greater than permitted
# [22:26:11] DEBUG: COC1=CC=C(C2=NC3(CC[NH](C(C)C)CC3)NC(C3=CC(Br)=CC=C3O)C2)C=C1 failed due to Explicit valence for atom # 28 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 12 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 28 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 28 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 28 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 31 N, 4, is greater than permitted
# [22:26:11] DEBUG: COC1=CC=C(C2=NC3(CC[NH](C(C)C)CC3)NC(C3=CC=CC(OC)=C3O)C2)C=C1OC failed due to Explicit valence for atom # 31 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 12 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 31 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 31 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 31 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 30 N, 4, is greater than permitted
# [22:26:11] DEBUG: COC1=CC=C(C2CC(C3=C(O)C=CC(Cl)=C3)=NC3(CC[NH](C(C)C)CC3)N2)C=C1OC failed due to Explicit valence for atom # 30 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 12 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 30 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 30 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 30 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 23 N, 4, is greater than permitted
# [22:26:11] DEBUG: O=C(CNC(=O)C12CNCC1C[NH](C1CCCC1)C2)NC1=NC=CS1 failed due to Explicit valence for atom # 23 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 23 N, 4, is greater than permitted
# [22:26:11] DEBUG: O=C(CNC(=O)C12CNCC1C[NH](C1CCCC1)C2)NC1=NC=CS1 failed due to Explicit valence for atom # 23 N, 4, is greater than permitted
#
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 23 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 23 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 23 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 16 N, 4, is greater than permitted
# [22:26:11] DEBUG: CC1=C(C2=NOC(C[NH2]CCC3=CNC4=C(C)C=CC=C34)=N2)C=CC=C1 failed due to Explicit valence for atom # 16 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 11 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 16 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 16 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 16 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] DEBUG: CC1=C(C2CC(=O)NC3=C2C=NN3C2CC[NH](C)CC2)SC2=C1C=CC=C2 failed due to Explicit valence for atom # 26 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 6 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:11] DEBUG: CC(C1=CC=C(C2C(C3=CC=CC=C3)NCN2CC2NC=CN2)C=C1)[NH](C)C failed due to Explicit valence for atom # 27 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 10 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 0 N, 4, is greater than permitted
# [22:26:11] DEBUG: [NH3]C1NNC(C(NC(=O)CCC2=CNC3=C2C=CC=C3)C2=CC=CC=C2)S1 failed due to Explicit valence for atom # 0 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 0 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 0 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 0 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 0 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] DEBUG: CCC1NC(C)=C(C2C(C3=CC=CC=C3)NC[NH]2CCC2=CC=NC=C2)N1 failed due to Explicit valence for atom # 26 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 12 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 2 N, 4, is greater than permitted
# [22:26:11] DEBUG: CC1=C(C)C2=C(NC3C[NH]4CCC3CC4)N=C(CC[NH3])N=C2S1 failed due to Explicit valence for atom # 2 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 2 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 2 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 2 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 2 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 21 N, 4, is greater than permitted
# [22:26:11] DEBUG: C1=CC=C(CCC2NN(C3=NC=CC=C3)C(C3=C(C4=NNC=N4)C=CC=C3)[NH2]2)C=C1 failed due to Explicit valence for atom # 21 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 8 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 21 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 21 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 21 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 21 N, 4, is greater than permitted
# [22:26:11] DEBUG: C1=CC=C(CCC2NN(C3=CC=CC=N3)C(C3=C(C4=NNC=N4)C=CC=C3)[NH2]2)C=C1 failed due to Explicit valence for atom # 21 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 8 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 21 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 21 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 21 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 24 N, 4, is greater than permitted
# [22:26:11] DEBUG: CC1=CC=CC2=C1NC(C1CCC[NH]1CC1=C(C(=O)O)C=CC=N1)N2 failed due to Explicit valence for atom # 24 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 14 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 24 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 24 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 24 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] DEBUG: CC1CC[NH](C(C)CNC(=O)NNC(=O)C(C)OC2=C(F)C=CC=C2)CC1 failed due to Explicit valence for atom # 26 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 26 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:11] DEBUG: CC[NH](CC)C(CNC(=O)N1CC=C(C2=CC=C(O)C=C2)CC1)C1=CC=CO1 failed due to Explicit valence for atom # 27 N, 4, is greater than permitted
#
# [22:26:11] Explicit valence for atom # 20 N, 4, is greater than permitted
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:11] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:11] INFO: [ValenceValidation] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] Initializing MetalDisconnector
# [22:26:11] Running MetalDisconnector
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# [22:26:11] WARNING: not removing hydrogen atom without neighbors
# [22:26:11] Initializing Normalizer
# [22:26:11] Running Normalizer
# ...
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Explicit valence for atom # 22 N, 4, is greater than permitted
# [22:26:13] DEBUG: NC(=O)C1CC(O)C[NH]1CC1=NC(CC2=CC=CC(Br)=C2)=NO1 failed due to Explicit valence for atom # 22 N, 4, is greater than permitted
#
# [22:26:13] Explicit valence for atom # 22 N, 4, is greater than permitted
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Explicit valence for atom # 22 N, 4, is greater than permitted
# [22:26:13] Explicit valence for atom # 22 N, 4, is greater than permitted
# [22:26:13] INFO: [ValenceValidation] Explicit valence for atom # 22 N, 4, is greater than permitted
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Explicit valence for atom # 25 N, 4, is greater than permitted
# [22:26:13] DEBUG: CCC[NH]1CC2=CC=CC(NC(=O)C(=O)NCC(CC(C)C)[NH](C)C)=C2C1 failed due to Explicit valence for atom # 25 N, 4, is greater than permitted
#
# [22:26:13] Explicit valence for atom # 25 N, 4, is greater than permitted
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Explicit valence for atom # 25 N, 4, is greater than permitted
# [22:26:13] Explicit valence for atom # 25 N, 4, is greater than permitted
# [22:26:13] INFO: [ValenceValidation] Explicit valence for atom # 25 N, 4, is greater than permitted
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Explicit valence for atom # 1 N, 4, is greater than permitted
# [22:26:13] DEBUG: CC1=CC2=C(OC(C[NH3])C2)C(C2=CC=C(C3=NOC=C3)S2)=C1 failed due to Explicit valence for atom # 1 N, 4, is greater than permitted
#
# [22:26:13] Explicit valence for atom # 1 N, 4, is greater than permitted
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Explicit valence for atom # 1 N, 4, is greater than permitted
# [22:26:13] Explicit valence for atom # 1 N, 4, is greater than permitted
# [22:26:13] INFO: [ValenceValidation] Explicit valence for atom # 1 N, 4, is greater than permitted
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Explicit valence for atom # 15 N, 4, is greater than permitted
# [22:26:13] DEBUG: CCOC(=O)N1CCC([NH2]CCC2=NC3=CC=C(C)C(C)=C3N2)CC1 failed due to Explicit valence for atom # 15 N, 4, is greater than permitted
#
# [22:26:13] Explicit valence for atom # 15 N, 4, is greater than permitted
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Explicit valence for atom # 15 N, 4, is greater than permitted
# [22:26:13] Explicit valence for atom # 15 N, 4, is greater than permitted
# [22:26:13] INFO: [ValenceValidation] Explicit valence for atom # 15 N, 4, is greater than permitted
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Explicit valence for atom # 28 N, 4, is greater than permitted
# [22:26:13] DEBUG: O=C(NCC1=NN=C2CCCCCN21)NCC1CCCC[NH]1CC1=CC=CC=C1 failed due to Explicit valence for atom # 28 N, 4, is greater than permitted
#
# [22:26:13] Explicit valence for atom # 28 N, 4, is greater than permitted
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Explicit valence for atom # 28 N, 4, is greater than permitted
# [22:26:13] Explicit valence for atom # 28 N, 4, is greater than permitted
# [22:26:13] INFO: [ValenceValidation] Explicit valence for atom # 28 N, 4, is greater than permitted
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Explicit valence for atom # 25 N, 4, is greater than permitted
# [22:26:13] DEBUG: CC(=O)NC1=CC(Cl)=C(NC(=O)NCC(C)(C)[NH]2CC(C)CC(C)C2)C=C1 failed due to Explicit valence for atom # 25 N, 4, is greater than permitted
#
# [22:26:13] Explicit valence for atom # 25 N, 4, is greater than permitted
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Explicit valence for atom # 25 N, 4, is greater than permitted
# [22:26:13] Explicit valence for atom # 25 N, 4, is greater than permitted
# [22:26:13] INFO: [ValenceValidation] Explicit valence for atom # 25 N, 4, is greater than permitted
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:13] DEBUG: CCCC(=O)NC1=C(C)C(NC(=O)NC(C)C[NH]2CC(C)CC(C)C2)=CC=C1 failed due to Explicit valence for atom # 27 N, 4, is greater than permitted
#
# [22:26:13] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:13] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:13] INFO: [ValenceValidation] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:13] DEBUG: CCCC(=O)NC1=C(C)C(NC(=O)NC(C)C[NH]2CC(C)CC(C)C2)=CC=C1 failed due to Explicit valence for atom # 27 N, 4, is greater than permitted
#
# [22:26:13] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:13] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:13] INFO: [ValenceValidation] Explicit valence for atom # 27 N, 4, is greater than permitted
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] WARNING: not removing hydrogen atom without neighbors
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer
# [22:26:13] Initializing MetalDisconnector
# [22:26:13] Running MetalDisconnector
# [22:26:13] Initializing Normalizer
# [22:26:13] Running Normalizer

# %%
df_merge.head()
# Out:
#            name                                             smiles     score
# 0  CHEMBL100551  COCCOc1cc2c(cc1OC)Cc1c(Nc3cc(OC)c(Cl)cc3Cl)ncn... -8.404626
# 1  CHEMBL100825  CCN1CCN(Cc2ccc(-c3ccc4c(Nc5cc(OC)c(Cl)cc5Cl)c(... -9.347998
# 2  CHEMBL101081  COc1cc(Nc2c(C#N)cnc3cc(-c4ccc(CCN5CCOCC5)cc4)c... -9.123454
# 3  CHEMBL102595  COc1cc(Nc2c(C#N)cnc3cc(-c4cccc(CN5CCN(C)CC5)c4... -9.455883
# 4  CHEMBL103293  COc1cc(Nc2c(C#N)cnc3cc(-c4cccc(CCN5CCOCC5)c4)c... -9.521552

# %%
df_train, df_test = train_test_split(df_merge, test_size=0.4)

# %%
df_train.to_csv("preprocess_data/src/src_train.csv", index=None, sep="\t")
df_test.to_csv("preprocess_data/src/src_test.csv", index=None, sep="\t")

# %%
df_train.head()
# Out:
#                name                                             smiles  \
# 24521  ZINC39440407  O=C(NCc1cc2cc(Cl)ccc2[nH]1)C1CC2NC(c3ccc4c(c3)...
# 4763   ZINC06749250  CCOC(=O)c1ccccc1NC(=O)c1nc(-c2ccc(C)cc2)n2c1CC...
# 852    ZINC00825728  O=C(NN=Cc1ccc([N+](=O)[O-])cc1)c1ccc(C2SCC(=O)...
# 15036  ZINC20884327  COc1cc(C2CC(=O)C3=C(C2)Nc2ccccc2NC3c2cc(Cl)ccc...
# 12907  ZINC16246313  CCC(C)c1ccc(-n2c(SCc3nc4ccccc4c(=O)[nH]3)nc3cc...
#
#            score
# 24521 -10.125299
# 4763   -8.800572
# 852    -8.178602
# 15036  -8.678500
# 12907  -9.175315

# %%
len(df_train)
# Out:
# 20979

# %%
len(df_test)
# Out:
# 13986

# %%
df_merge.to_csv("preprocess_data/src/src_processed.csv", index=None, sep="\t")
