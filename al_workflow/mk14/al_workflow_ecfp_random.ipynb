# %%
# !pip install datamol
# !pip install rdkit-pypi
# !pip install pandas
# Out:
# Collecting datamol
#   Downloading datamol-0.11.3-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.7/381.7 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from datamol) (4.66.1)
# Collecting loguru (from datamol)
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from datamol) (1.3.2)
# Requirement already satisfied: fsspec>=2021.9 in /usr/local/lib/python3.10/dist-packages (from datamol) (2023.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datamol) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.11.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from datamol) (3.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from datamol) (9.4.0)
# Collecting selfies (from datamol)
#   Downloading selfies-2.1.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from datamol) (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from datamol) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datamol) (23.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from datamol) (4.5.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from datamol) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datamol) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->datamol) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->datamol) (1.16.0)
# Installing collected packages: selfies, loguru, datamol
# Successfully installed datamol-0.11.3 loguru-0.7.2 selfies-2.1.1
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 52.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (9.4.0)
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import os
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import Linear
from torch.utils.data import DataLoader
import tqdm
from scipy.stats import spearmanr

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Project/ALVS")
# Out:
# Mounted at /content/drive

# %%
def ecfp_from_smiles(smiles,
                     R = 2,
                     L = 2**11,
                     use_features = True,
                     use_chirality = False):
    """
    Inputs:

    - smiles ... SMILES string of input compound
    - R ... maximum radius of circular substructures
    - L ... fingerprint-length
    - use_features ... if false then use standard DAYLIGHT atom features, if true then use pharmacophoric atom features
    - use_chirality ... if true then append tetrahedral chirality flags to atom features

    Outputs:
    - np.array(feature_list) ... ECFP with length L and maximum radius R
    """

    molecule = Chem.MolFromSmiles(smiles)
    if not molecule:
        return np.nan
    feature_list = AllChem.GetMorganFingerprintAsBitVect(molecule,
                                                         radius = R,
                                                         nBits = L,
                                                         useFeatures = use_features,
                                                         useChirality = use_chirality)
    return np.array(feature_list)

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, fps, scores):
        self.fps = fps
        self.scores = scores
        self.dataLen = len(scores)

    def __getitem__(self, index):
        fp = np.array(self.fps[index])
        score = np.array(self.scores[index]).reshape(1,)
        return fp, score

    def __len__(self):
        return self.dataLen

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.fc1 = Linear(2048, 1024)
        self.dropout1 = nn.Dropout(p=0.2)
        self.fc2 = Linear(1024, 516)
        self.dropout2 = nn.Dropout(p=0.2)
        self.fc3 = Linear(516, 256)
        self.dropout3 = nn.Dropout(p=0.2)
        self.fc4 = Linear(256, 128)
        self.dropout4 = nn.Dropout(p=0.2)
        self.fc5 = Linear(128, 1)


    def forward(self, data):
        x = F.relu(self.fc1(data))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = F.relu(self.fc3(x))
        x = self.dropout3(x)
        x = F.relu(self.fc4(x))
        x = self.dropout4(x)
        x = self.fc5(x)
        return x

# %%
def train_epoch(loader, model, optimizer, device):
    model.train()

    loss_all = 0
    i = 0
    for fps, scores in loader:
        fps = fps.float().to(device)
        scores = scores.float().to(device)

        optimizer.zero_grad()
        output = model(fps)
        loss = F.mse_loss(output, scores)
        loss.backward()

        loss_all += loss.item()
        optimizer.step()
        i += 1
    return loss_all / i

# %%
def test_epoch(loader, model,  device):
    model.eval()

    MSE, MAE = 0, 0
    trues, preds = [], []
    with torch.no_grad():
        for fps, scores in loader:
            fps = fps.float().to(device)
            scores = scores.float().to(device)

            output = model(fps)
            pred = output.cpu().squeeze().numpy().tolist()
            true = scores.cpu().squeeze().numpy().tolist()

            trues.extend(true)
            preds.extend(pred)
    MAE = mean_absolute_error(trues, preds)
    RMSE = np.sqrt(mean_squared_error(trues, preds))
    R2 = r2_score(trues, preds)
    Sp = spearmanr(trues, preds)[0]
    return MAE, RMSE, R2, Sp

# %%
def init_model(device, lr=0.0001):
    model = DNN()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    return model, optimizer

# %%
def prepare_dataloader(dff, batch_size, test_size=0.8):
    train_fps, valid_fps, train_scores, valid_scores = train_test_split(
                                                                        dff["ecfp"],
                                                                        dff["score"],
                                                                        test_size=test_size)
    train_dataset = Dataset(fps=list(train_fps),
                            scores = list(train_scores))
    valid_dataset = Dataset(fps=list(valid_fps),
                            scores = list(valid_scores))
    train_loader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=True)
    valid_loader = DataLoader(valid_dataset,
                              batch_size=batch_size,
                              shuffle=False)
    return train_loader, valid_loader

# %%
def train_step(dff, epochs, batch_size, step_time, device="cuda"):
    model, optimizer = init_model(device=device)
    train_loader, valid_loader = prepare_dataloader(dff,  batch_size=batch_size)

    model_folder = "models/mk14/ecfp/models_random/{}".format(step_time)
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)

    hist = {"train-loss":[], "test-mae":[], "test-rmse":[], "test-r2":[],"test-sp":[]}
    for epoch in range(epochs):
        train_loss = train_epoch(train_loader, model, optimizer, device)
        test_mae, test_rmse, test_r2, test_sp = test_epoch(valid_loader, model, device)
        hist["train-loss"].append(train_loss)
        hist["test-mae"].append(test_mae)
        hist["test-rmse"].append(test_rmse)
        hist["test-r2"].append(test_r2)
        hist["test-sp"].append(test_sp)

        if test_rmse <= min(hist["test-rmse"]):
            weight_path = os.path.join(model_folder, "weight_{}.pth".format(epoch))
            torch.save(model.state_dict(), weight_path)

        # print(f'Epoch: {epoch}, Train loss: {train_loss:.3}, Test mae: {test_mae:.3}, Test rmse: {test_rmse:.3}, Test r2: {test_r2:.3}')
    print("---------------------------------\nvalidation min rmse: {}\n---------------------------------\n".format(min(hist["test-rmse"])))
    return weight_path

# %%
def random_select(df, n_samples):
    df_select = df.sample(n=n_samples).copy()
    sample_indexs = df_select["name"].tolist()
    df_remaining = df[~df["name"].isin(sample_indexs)].copy()
    return df_select, df_remaining

# %%
def predict(fpnp, model, device):
    fpnp = fpnp.reshape(1, 2048)
    fp = torch.from_numpy(fpnp).float().to(device)
    with torch.no_grad():
        output = model(fp)
        pred = output.cpu().numpy()[0][0]
    return pred

# %%
def load_model(best_model_path, device="cuda", enable_dp=True):
    model= DNN().to(device)
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()
    if enable_dp:
        enable_dropout(model)
    return model

# %%
def eval_model(dff, best_model_path):
    model = load_model(best_model_path, enable_dp=False)
    dff["pred"] = dff["ecfp"].map(lambda x: predict(x,  model, device="cuda"))
    MAE = mean_absolute_error(dff["score"], dff["pred"])
    RMSE = np.sqrt(mean_squared_error(dff["score"], dff["pred"]))
    R2 = r2_score(dff["score"], dff["pred"])
    Sp = spearmanr(dff["score"], dff["pred"])[0]
    return MAE, RMSE, R2, Sp

# %%
def run_step(dfs, epochs, stime):
    dfs_new = dfs.copy()

    best_model_path = train_step(dfs_new, epochs, batch_size=32, step_time=stime)
    return best_model_path

# %%
def run_iterations(df, df_test, epochs=200, iterations=100, n_samples=100):
    results = {"RMSE": [], "R2": [], "Sp": []}

    print("len(df):", len(df))

    df["ecfp"] = df["smiles"].map(lambda x: ecfp_from_smiles(x))
    df = df[~df["ecfp"].isna()]

    for stime in range(iterations):
        if stime < 1:
            dfs, dfr = random_select(df, n_samples)
        else:
            df_temp = dfs.copy()
            dfs, dfr = random_select(dfr, n_samples)
            dfs = pd.concat([dfs, df_temp], axis=0)
            dfs = dfs.reset_index(drop=True)
        print("number of mol pool:", len(dfs))
        best_model_path = run_step(dfs, epochs, stime)
        MAE, RMSE, R2 , Sp = eval_model(df_test, best_model_path)
        print("MAE:{}, RMSE:{}, R2:{}, Sp:{}, step:{}".format(MAE, RMSE, R2, Sp, stime))

        results["RMSE"].append(RMSE)
        results["R2"].append(R2)
        results["Sp"].append(Sp)

    # Convert results dictionary to DataFrame
    results_df = pd.DataFrame(results)

    results_df.to_csv('result/mk14/ecfp_random_results.csv', index=False)

# %%
df = pd.read_csv("preprocess_data/mk14/mk14_train.csv", sep="\t")
df_test = pd.read_csv("preprocess_data/mk14/mk14_test.csv", sep="\t")
df_test["ecfp"] = df_test["smiles"].map(lambda x: ecfp_from_smiles(x))
df_test = df_test[~df_test["ecfp"].isna()]

# %%
run_iterations(df, df_test)
# Out:
# len(df): 21827
# [16:35:30] SMILES Parse Error: syntax error while parsing: error
# [16:35:30] SMILES Parse Error: Failed parsing SMILES 'error' for input: 'error'
# number of mol pool: 100
# ---------------------------------
# validation min rmse: 1.3230654817873109
# ---------------------------------
#
# MAE:1.1343902962950707, RMSE:1.4313367421755887, R2:-1.961833310665714, Sp:0.2118961457208579, step:0
# number of mol pool: 200
# ---------------------------------
# validation min rmse: 1.4866764841470754
# ---------------------------------
#
# MAE:1.0627224852999837, RMSE:1.3490519413291262, R2:-1.6310815929177958, Sp:0.2595412746223465, step:1
# number of mol pool: 300
# ---------------------------------
# validation min rmse: 1.373416748044997
# ---------------------------------
#
# MAE:1.050543540862405, RMSE:1.3285042883139193, R2:-1.5515430195634954, Sp:0.2527381983476286, step:2
# number of mol pool: 400
# ---------------------------------
# validation min rmse: 1.4177795577069363
# ---------------------------------
#
# MAE:1.0653236337968282, RMSE:1.3528114764707222, R2:-1.6457666119471877, Sp:0.25760219373737003, step:3
# number of mol pool: 500
# ---------------------------------
# validation min rmse: 1.2999048707630045
# ---------------------------------
#
# MAE:0.9645512179689539, RMSE:1.2405440802997438, R2:-1.2248532740979434, Sp:0.3144266692115001, step:4
# number of mol pool: 600
# ---------------------------------
# validation min rmse: 1.2276250403594164
# ---------------------------------
#
# MAE:0.998495229345757, RMSE:1.2660432555663026, R2:-1.3172562480354846, Sp:0.3205662429434655, step:5
# number of mol pool: 700
# ---------------------------------
# validation min rmse: 1.163282632707426
# ---------------------------------
#
# MAE:0.9233920455324818, RMSE:1.1726823374281667, R2:-0.9880977865045772, Sp:0.35234149464314135, step:6
# number of mol pool: 800
# ---------------------------------
# validation min rmse: 1.2000998080786738
# ---------------------------------
#
# MAE:0.9393502343499406, RMSE:1.193856747012535, R2:-1.0605417102497952, Sp:0.34868295095407226, step:7
# number of mol pool: 900
# ---------------------------------
# validation min rmse: 1.1301452508757421
# ---------------------------------
#
# MAE:0.905652313262803, RMSE:1.15424832835289, R2:-0.9260851474616156, Sp:0.3702723070421241, step:8
# number of mol pool: 1000
# ---------------------------------
# validation min rmse: 1.1680173966504597
# ---------------------------------
#
# MAE:0.9242635359125039, RMSE:1.174690134146036, R2:-0.9949114192422059, Sp:0.3143691903372078, step:9
# number of mol pool: 1100
# ---------------------------------
# validation min rmse: 1.1446863614779175
# ---------------------------------
#
# MAE:0.8991976055506273, RMSE:1.1401021787378163, R2:-0.8791633126257363, Sp:0.3607563703335471, step:10
# number of mol pool: 1200
# ---------------------------------
# validation min rmse: 1.1349842313853666
# ---------------------------------
#
# MAE:0.8690607508436196, RMSE:1.106463925677669, R2:-0.7699112589758628, Sp:0.37284913551573395, step:11
# number of mol pool: 1300
# ---------------------------------
# validation min rmse: 1.0691004035080223
# ---------------------------------
#
# MAE:0.838984891664954, RMSE:1.0689762016904194, R2:-0.6520114279784233, Sp:0.4143548476326764, step:12
# number of mol pool: 1400
# ---------------------------------
# validation min rmse: 1.1176709170020465
# ---------------------------------
#
# MAE:0.853386343632466, RMSE:1.0918658199558795, R2:-0.7235167786210845, Sp:0.3897043992700071, step:13
# number of mol pool: 1500
# ---------------------------------
# validation min rmse: 1.1316520934526617
# ---------------------------------
#
# MAE:0.8750682622008747, RMSE:1.106590656857231, R2:-0.7703167232334305, Sp:0.3439105741847817, step:14
# number of mol pool: 1600
# ---------------------------------
# validation min rmse: 1.1006577402589228
# ---------------------------------
#
# MAE:0.8410505242876508, RMSE:1.0691995955264617, R2:-0.6527019723166527, Sp:0.38810562855054004, step:15
# number of mol pool: 1700
# ---------------------------------
# validation min rmse: 1.1175809245355386
# ---------------------------------
#
# MAE:0.8405833902339023, RMSE:1.0747344853015919, R2:-0.6698572352349415, Sp:0.38054374771018085, step:16
# number of mol pool: 1800
# ---------------------------------
# validation min rmse: 1.1207723398159122
# ---------------------------------
#
# MAE:0.8734316335303487, RMSE:1.110085337888036, R2:-0.7815159163754448, Sp:0.34078808779425857, step:17
# number of mol pool: 1900
# ---------------------------------
# validation min rmse: 1.1085406989682878
# ---------------------------------
#
# MAE:0.8385870559942092, RMSE:1.069080540255185, R2:-0.6523339363994802, Sp:0.3903083409757438, step:18
# number of mol pool: 2000
# ---------------------------------
# validation min rmse: 1.0652541082150067
# ---------------------------------
#
# MAE:0.825611124418488, RMSE:1.0563142571278585, R2:-0.6131073010003585, Sp:0.3959889840023609, step:19
# number of mol pool: 2100
# ---------------------------------
# validation min rmse: 1.0791619898852431
# ---------------------------------
#
# MAE:0.813749388584298, RMSE:1.036857268888613, R2:-0.5542287100092274, Sp:0.4080188900706843, step:20
# number of mol pool: 2200
# ---------------------------------
# validation min rmse: 1.0490217250966734
# ---------------------------------
#
# MAE:0.8182178992972187, RMSE:1.038856026673623, R2:-0.5602266830474429, Sp:0.4008636991913563, step:21
# number of mol pool: 2300
# ---------------------------------
# validation min rmse: 1.0188503234488802
# ---------------------------------
#
# MAE:0.7831577755029095, RMSE:0.9946558218336489, R2:-0.4302851569458339, Sp:0.41820664157871285, step:22
# number of mol pool: 2400
# ---------------------------------
# validation min rmse: 0.9871979534689834
# ---------------------------------
#
# MAE:0.7762384282868446, RMSE:0.9946674397188824, R2:-0.4303185694800695, Sp:0.4570036884756635, step:23
# number of mol pool: 2500
# ---------------------------------
# validation min rmse: 1.0445240750235012
# ---------------------------------
#
# MAE:0.8066527298590496, RMSE:1.0232742327632314, R2:-0.5137740297935172, Sp:0.42171264948317816, step:24
# number of mol pool: 2600
# ---------------------------------
# validation min rmse: 0.9765573665047889
# ---------------------------------
#
# MAE:0.7676173446033673, RMSE:0.9802054744160282, R2:-0.389028706428558, Sp:0.4408799679091985, step:25
# number of mol pool: 2700
# ---------------------------------
# validation min rmse: 1.0012652577626668
# ---------------------------------
#
# MAE:0.7810422891620902, RMSE:0.9946070623807937, R2:-0.4301449311294796, Sp:0.42622532056732265, step:26
# number of mol pool: 2800
# ---------------------------------
# validation min rmse: 1.035775384304699
# ---------------------------------
#
# MAE:0.782337946456162, RMSE:1.0027109247838522, R2:-0.4535449520330692, Sp:0.4180355468116091, step:27
# number of mol pool: 2900
# ---------------------------------
# validation min rmse: 0.9940914821373007
# ---------------------------------
#
# MAE:0.7831601258155715, RMSE:0.9949684083848795, R2:-0.43118427832419304, Sp:0.4174293860266425, step:28
# number of mol pool: 3000
# ---------------------------------
# validation min rmse: 0.992402280225525
# ---------------------------------
#
# MAE:0.7739076255003235, RMSE:0.9852877685244494, R2:-0.4034700740184207, Sp:0.41876941760309255, step:29
# number of mol pool: 3100
# ---------------------------------
# validation min rmse: 0.992351793775893
# ---------------------------------
#
# MAE:0.7668553730826275, RMSE:0.9788152626588348, R2:-0.3850914204151572, Sp:0.4575235002733892, step:30
# number of mol pool: 3200
# ---------------------------------
# validation min rmse: 0.9778844379066749
# ---------------------------------
#
# MAE:0.7538876331261587, RMSE:0.9597408829706393, R2:-0.33163427290913283, Sp:0.46849438000234306, step:31
# number of mol pool: 3300
# ---------------------------------
# validation min rmse: 0.9976060218247442
# ---------------------------------
#
# MAE:0.7730866987101808, RMSE:0.987751538121688, R2:-0.4104977673657544, Sp:0.4266463498476497, step:32
# number of mol pool: 3400
# ---------------------------------
# validation min rmse: 0.9264753430766335
# ---------------------------------
#
# MAE:0.7307429604687292, RMSE:0.9291516141557066, R2:-0.24810218990364774, Sp:0.4569323914830237, step:33
# number of mol pool: 3500
# ---------------------------------
# validation min rmse: 0.9573460123855181
# ---------------------------------
#
# MAE:0.7452722431657232, RMSE:0.9484625878634039, R2:-0.30052104219870923, Sp:0.4796711230817707, step:34
# number of mol pool: 3600
# ---------------------------------
# validation min rmse: 0.9447754190044093
# ---------------------------------
#
# MAE:0.7281118162781165, RMSE:0.9276052069725333, R2:-0.24395116001734696, Sp:0.4701531397685787, step:35
# number of mol pool: 3700
# ---------------------------------
# validation min rmse: 0.9480977371853807
# ---------------------------------
#
# MAE:0.7399521644466074, RMSE:0.9449789933149952, R2:-0.2909852564153861, Sp:0.4558394698403094, step:36
# number of mol pool: 3800
# ---------------------------------
# validation min rmse: 0.9352286329900955
# ---------------------------------
#
# MAE:0.736549111978997, RMSE:0.9422032245540907, R2:-0.2834121494095747, Sp:0.46542915388191836, step:37
# number of mol pool: 3900
# ---------------------------------
# validation min rmse: 0.9216920438964149
# ---------------------------------
#
# MAE:0.7088386375545958, RMSE:0.9064995881045831, R2:-0.18798838890755798, Sp:0.48017807898623743, step:38
# number of mol pool: 4000
# ---------------------------------
# validation min rmse: 0.9419374412156881
# ---------------------------------
#
# MAE:0.7305187343138307, RMSE:0.9267817006838269, R2:-0.2417434387249604, Sp:0.46958681610342395, step:39
# number of mol pool: 4100
# ---------------------------------
# validation min rmse: 0.9352379602943308
# ---------------------------------
#
# MAE:0.7356460585481192, RMSE:0.9400707769936434, R2:-0.27760934172364826, Sp:0.473869091615805, step:40
# number of mol pool: 4200
# ---------------------------------
# validation min rmse: 0.9666044439789451
# ---------------------------------
#
# MAE:0.742159498977844, RMSE:0.9461338041258905, R2:-0.2941424793453198, Sp:0.46432993294426517, step:41
# number of mol pool: 4300
# ---------------------------------
# validation min rmse: 0.9047535922943365
# ---------------------------------
#
# MAE:0.7105174354556937, RMSE:0.9116218659018687, R2:-0.20145204448941856, Sp:0.4984129381311354, step:42
# number of mol pool: 4400
# ---------------------------------
# validation min rmse: 0.8941183430119071
# ---------------------------------
#
# MAE:0.7021492012176362, RMSE:0.893637328914491, R2:-0.15451499338780827, Sp:0.4790491695686915, step:43
# number of mol pool: 4500
# ---------------------------------
# validation min rmse: 0.9014745546283899
# ---------------------------------
#
# MAE:0.6984839673681781, RMSE:0.8933090334090352, R2:-0.15366688095922854, Sp:0.484827506261436, step:44
# number of mol pool: 4600
# ---------------------------------
# validation min rmse: 0.897489022377083
# ---------------------------------
#
# MAE:0.7031073507084176, RMSE:0.8961353541707471, R2:-0.16097855174171505, Sp:0.47721470463595106, step:45
# number of mol pool: 4700
# ---------------------------------
# validation min rmse: 0.8884706975471083
# ---------------------------------
#
# MAE:0.6968865920932726, RMSE:0.8897000069605766, R2:-0.14436393316674856, Sp:0.49863267673336703, step:46
# number of mol pool: 4800
# ---------------------------------
# validation min rmse: 0.8666579730605595
# ---------------------------------
#
# MAE:0.6793366894643469, RMSE:0.8698795312272645, R2:-0.0939442687169576, Sp:0.5081269095700517, step:47
# number of mol pool: 4900
# ---------------------------------
# validation min rmse: 0.8751261974156986
# ---------------------------------
#
# MAE:0.6807269987584942, RMSE:0.8664568838210956, R2:-0.085352689304514, Sp:0.5107683693597532, step:48
# number of mol pool: 5000
# ---------------------------------
# validation min rmse: 0.8749964971795838
# ---------------------------------
#
# MAE:0.6760589322612685, RMSE:0.8618311535432146, R2:-0.07379493644791135, Sp:0.5054031367829457, step:49
# number of mol pool: 5100
# ---------------------------------
# validation min rmse: 0.8650902581923529
# ---------------------------------
#
# MAE:0.6724073722100922, RMSE:0.8573937950065836, R2:-0.06276598564329539, Sp:0.4998033433571787, step:50
# number of mol pool: 5200
# ---------------------------------
# validation min rmse: 0.8852314944472583
# ---------------------------------
#
# MAE:0.6826271964283953, RMSE:0.8725882708968038, R2:-0.10076779711992123, Sp:0.5115406780415802, step:51
# number of mol pool: 5300
# ---------------------------------
# validation min rmse: 0.8618885353622964
# ---------------------------------
#
# MAE:0.6664609790626655, RMSE:0.8510683821732731, R2:-0.047142741562894, Sp:0.5276553090636179, step:52
# number of mol pool: 5400
# ---------------------------------
# validation min rmse: 0.8721926619516669
# ---------------------------------
#
# MAE:0.6783754686365653, RMSE:0.868492380996854, R2:-0.09045814200649005, Sp:0.5015972699526791, step:53
# number of mol pool: 5500
# ---------------------------------
# validation min rmse: 0.8701954221072262
# ---------------------------------
#
# MAE:0.672972091347867, RMSE:0.862981391554311, R2:-0.07666311769128797, Sp:0.5074195550671607, step:54
# number of mol pool: 5600
# ---------------------------------
# validation min rmse: 0.8475001394540054
# ---------------------------------
#
# MAE:0.6557887327009998, RMSE:0.8343062718666775, R2:-0.006301199971107119, Sp:0.5297262960871947, step:55
# number of mol pool: 5700
# ---------------------------------
# validation min rmse: 0.845575234846714
# ---------------------------------
#
# MAE:0.6582942273509209, RMSE:0.8434686344934214, R2:-0.028524990993652466, Sp:0.5240355198518013, step:56
# number of mol pool: 5800
# ---------------------------------
# validation min rmse: 0.8664019437123255
# ---------------------------------
#
# MAE:0.6682365399816815, RMSE:0.8548820639134289, R2:-0.05654837031914539, Sp:0.5176945479860817, step:57
# number of mol pool: 5900
# ---------------------------------
# validation min rmse: 0.8511185326956862
# ---------------------------------
#
# MAE:0.6564672819666862, RMSE:0.8397731277959184, R2:-0.01953213859698888, Sp:0.5117459650159605, step:58
# number of mol pool: 6000
# ---------------------------------
# validation min rmse: 0.8414793987223677
# ---------------------------------
#
# MAE:0.6619696264015873, RMSE:0.8491193796456206, R2:-0.04235218180589451, Sp:0.5340133475870209, step:59
# number of mol pool: 6100
# ---------------------------------
# validation min rmse: 0.8145925317105205
# ---------------------------------
#
# MAE:0.6382515546269852, RMSE:0.8117112156342503, R2:0.0474669192285716, Sp:0.5401732521481512, step:60
# number of mol pool: 6200
# ---------------------------------
# validation min rmse: 0.862874785782948
# ---------------------------------
#
# MAE:0.6580787026065267, RMSE:0.8393425869832836, R2:-0.01848700471763065, Sp:0.5199228103429503, step:61
# number of mol pool: 6300
# ---------------------------------
# validation min rmse: 0.8243880651126599
# ---------------------------------
#
# MAE:0.6321914177750964, RMSE:0.8096753127363987, R2:0.05223914074606406, Sp:0.5328605092213599, step:62
# number of mol pool: 6400
# ---------------------------------
# validation min rmse: 0.804985007975766
# ---------------------------------
#
# MAE:0.6279097546844218, RMSE:0.8025205052749548, R2:0.06891517257152069, Sp:0.5421648827342173, step:63
# number of mol pool: 6500
# ---------------------------------
# validation min rmse: 0.836104993179037
# ---------------------------------
#
# MAE:0.6431549856814085, RMSE:0.8248329183497805, R2:0.016421688652713207, Sp:0.5335018704058678, step:64
# number of mol pool: 6600
# ---------------------------------
# validation min rmse: 0.8270858273473067
# ---------------------------------
#
# MAE:0.6391742393990721, RMSE:0.8179834202579491, R2:0.0326893355188681, Sp:0.5440198741315058, step:65
# number of mol pool: 6700
# ---------------------------------
# validation min rmse: 0.8093486578303414
# ---------------------------------
#
# MAE:0.6412092614431305, RMSE:0.820572706858168, R2:0.026555693577726025, Sp:0.5390171437529502, step:66
# number of mol pool: 6800
# ---------------------------------
# validation min rmse: 0.8007027550342766
# ---------------------------------
#
# MAE:0.6361907717131504, RMSE:0.8140586418254459, R2:0.04194960159759442, Sp:0.5532148115970287, step:67
# number of mol pool: 6900
# ---------------------------------
# validation min rmse: 0.8217683416521415
# ---------------------------------
#
# MAE:0.6367303775214986, RMSE:0.8145534922955718, R2:0.040784487043770024, Sp:0.539151456183565, step:68
# number of mol pool: 7000
# ---------------------------------
# validation min rmse: 0.824536123691736
# ---------------------------------
#
# MAE:0.6411844235118445, RMSE:0.8180132522009192, R2:0.032618778385148595, Sp:0.5322905557154577, step:69
# number of mol pool: 7100
# ---------------------------------
# validation min rmse: 0.7811939247307367
# ---------------------------------
#
# MAE:0.616587974691128, RMSE:0.7883125363102353, R2:0.1015915253615598, Sp:0.5480699831371934, step:70
# number of mol pool: 7200
# ---------------------------------
# validation min rmse: 0.7868864623411019
# ---------------------------------
#
# MAE:0.6162628290497281, RMSE:0.785351490329202, R2:0.10832802269740138, Sp:0.5600442474821253, step:71
# number of mol pool: 7300
# ---------------------------------
# validation min rmse: 0.8148903231748094
# ---------------------------------
#
# MAE:0.6338893181839246, RMSE:0.8107295327502686, R2:0.04976951147577913, Sp:0.5348684136398425, step:72
# number of mol pool: 7400
# ---------------------------------
# validation min rmse: 0.7940358742016975
# ---------------------------------
#
# MAE:0.6247438995194402, RMSE:0.8005156187573511, R2:0.0735615028549953, Sp:0.5336685189821616, step:73
# number of mol pool: 7500
# ---------------------------------
# validation min rmse: 0.8055178296258909
# ---------------------------------
#
# MAE:0.627854661492163, RMSE:0.8033774524579864, R2:0.06692564952163482, Sp:0.5414729749521169, step:74
# number of mol pool: 7600
# ---------------------------------
# validation min rmse: 0.7805635119021518
# ---------------------------------
#
# MAE:0.6124702116440737, RMSE:0.7826091210223285, R2:0.11454440996071491, Sp:0.5473471579336723, step:75
# number of mol pool: 7700
# ---------------------------------
# validation min rmse: 0.7910732240401869
# ---------------------------------
#
# MAE:0.6173468514560976, RMSE:0.7940587758128856, R2:0.08844626786039889, Sp:0.5455307908208666, step:76
# number of mol pool: 7800
# ---------------------------------
# validation min rmse: 0.7844524327411112
# ---------------------------------
#
# MAE:0.6142379127576433, RMSE:0.7880348435576355, R2:0.10222436467168161, Sp:0.5499864452457708, step:77
# number of mol pool: 7900
# ---------------------------------
# validation min rmse: 0.7706705040856465
# ---------------------------------
#
# MAE:0.599461831214309, RMSE:0.7677859385327941, R2:0.14776908981501113, Sp:0.5519183851153441, step:78
# number of mol pool: 8000
# ---------------------------------
# validation min rmse: 0.7866592670147592
# ---------------------------------
#
# MAE:0.6136052827537869, RMSE:0.784929882572945, R2:0.10928513532196094, Sp:0.5524379882590368, step:79
# number of mol pool: 8100
# ---------------------------------
# validation min rmse: 0.7734020685579696
# ---------------------------------
#
# MAE:0.5996028216551049, RMSE:0.7649821919602479, R2:0.15398195874211396, Sp:0.5617820138754107, step:80
# number of mol pool: 8200
# ---------------------------------
# validation min rmse: 0.7832662222730064
# ---------------------------------
#
# MAE:0.6189452618122622, RMSE:0.7932355656075507, R2:0.09033532540466227, Sp:0.545130092283575, step:81
# number of mol pool: 8300
# ---------------------------------
# validation min rmse: 0.7766526143474828
# ---------------------------------
#
# MAE:0.6059288033381202, RMSE:0.7786348960149185, R2:0.12351457043730385, Sp:0.5506015457618236, step:82
# number of mol pool: 8400
# ---------------------------------
# validation min rmse: 0.789537113657743
# ---------------------------------
#
# MAE:0.619154917336971, RMSE:0.7899588382230112, R2:0.09783515732641013, Sp:0.5299634608197662, step:83
# number of mol pool: 8500
# ---------------------------------
# validation min rmse: 0.7654266240535141
# ---------------------------------
#
# MAE:0.5957326702067252, RMSE:0.7648822515783104, R2:0.1542029987715181, Sp:0.5651927132819884, step:84
# number of mol pool: 8600
# ---------------------------------
# validation min rmse: 0.7631096072241303
# ---------------------------------
#
# MAE:0.5961988758791831, RMSE:0.7657232195890552, R2:0.1523421130167828, Sp:0.5659397247394643, step:85
# number of mol pool: 8700
# ---------------------------------
# validation min rmse: 0.7581667140903553
# ---------------------------------
#
# MAE:0.5893309435321874, RMSE:0.752650631209387, R2:0.1810378429403371, Sp:0.576138811860187, step:86
# number of mol pool: 8800
# ---------------------------------
# validation min rmse: 0.7752826458676075
# ---------------------------------
#
# MAE:0.6160632015393358, RMSE:0.7902021216935661, R2:0.09727939269615438, Sp:0.5482681281298389, step:87
# number of mol pool: 8900
# ---------------------------------
# validation min rmse: 0.7486751693673739
# ---------------------------------
#
# MAE:0.5894214276430839, RMSE:0.7551456386047152, R2:0.17559918837513666, Sp:0.5635619740101095, step:88
# number of mol pool: 9000
# ---------------------------------
# validation min rmse: 0.7603538691090852
# ---------------------------------
#
# MAE:0.5837801073692415, RMSE:0.7492765997624231, R2:0.18836397918882986, Sp:0.5794728068134942, step:89
# number of mol pool: 9100
# ---------------------------------
# validation min rmse: 0.7592296389147828
# ---------------------------------
#
# MAE:0.5935786375037342, RMSE:0.759013919027217, R2:0.1671314668752285, Sp:0.5641237806953094, step:90
# number of mol pool: 9200
# ---------------------------------
# validation min rmse: 0.7538134970510639
# ---------------------------------
#
# MAE:0.5821857684520754, RMSE:0.7476229520455877, R2:0.1919425748227056, Sp:0.5863550223598528, step:91
# number of mol pool: 9300
# ---------------------------------
# validation min rmse: 0.7542180626702581
# ---------------------------------
#
# MAE:0.5909505525320079, RMSE:0.7560187682082838, R2:0.173691675829588, Sp:0.5677554962841884, step:92
# number of mol pool: 9400
# ---------------------------------
# validation min rmse: 0.7570484356685848
# ---------------------------------
#
# MAE:0.5805950752875704, RMSE:0.740995861211088, R2:0.20620467230098294, Sp:0.5810734720536125, step:93
# number of mol pool: 9500
# ---------------------------------
# validation min rmse: 0.7352305066667177
# ---------------------------------
#
# MAE:0.5868594397630428, RMSE:0.7508574658285723, R2:0.18493549521014296, Sp:0.5654220015419601, step:94
# number of mol pool: 9600
# ---------------------------------
# validation min rmse: 0.7724101175485367
# ---------------------------------
#
# MAE:0.5911006973615073, RMSE:0.7570238841974479, R2:0.17149308543437058, Sp:0.5774388595833557, step:95
# number of mol pool: 9700
# ---------------------------------
# validation min rmse: 0.7622553153357741
# ---------------------------------
#
# MAE:0.5894378558810697, RMSE:0.753623003755841, R2:0.17892039112196823, Sp:0.5656747301913179, step:96
# number of mol pool: 9800
# ---------------------------------
# validation min rmse: 0.7554668789294301
# ---------------------------------
#
# MAE:0.5783867636185004, RMSE:0.7462010122756251, R2:0.19501341770846226, Sp:0.5823718464784723, step:97
# number of mol pool: 9900
# ---------------------------------
# validation min rmse: 0.7434812494038683
# ---------------------------------
#
# MAE:0.5780766969370524, RMSE:0.7410260335368919, R2:0.20614002649087404, Sp:0.5788320172454507, step:98
# number of mol pool: 10000
# ---------------------------------
# validation min rmse: 0.7543750451177726
# ---------------------------------
#
# MAE:0.5850127226228965, RMSE:0.7454950759288326, R2:0.19653579700012147, Sp:0.5712514574561485, step:99
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-d7f2db78b0b6> in <cell line: 1>()
# ----> 1 run_iterations(df, df_test)
#
# <ipython-input-17-2fff58f01012> in run_iterations(df, df_test, epochs, iterations, n_samples)
#      27     results_df = pd.DataFrame(results)
#      28
# ---> 29     results_df.to_csv('result/mk14/ecfp_random_results.csv', index=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3718         )
#    3719
# -> 3720         return DataFrameRenderer(formatter).to_csv(
#    3721             path_or_buf,
#    3722             lineterminator=lineterminator,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1187             formatter=self.fmt,
#    1188         )
# -> 1189         csv_formatter.save()
#    1190
#    1191         if created_buffer:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in save(self)
#     239         """
#     240         # apply compression and byte/text conversion
# --> 241         with get_handle(
#     242             self.filepath_or_buffer,
#     243             self.mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732     # Only for write methods
#     733     if "r" not in mode and is_path:
# --> 734         check_parent_directory(str(handle))
#     735
#     736     if compression:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in check_parent_directory(path)
#     595     parent = Path(path).parent
#     596     if not parent.is_dir():
# --> 597         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     598
#     599
#
# OSError: Cannot save file into a non-existent directory: 'result/mk14'
