# %%
# !pip install datamol
# !pip install rdkit-pypi
# !pip install pandas
# Out:
# Collecting datamol
#   Downloading datamol-0.11.3-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.7/381.7 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from datamol) (4.66.1)
# Collecting loguru (from datamol)
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from datamol) (1.3.2)
# Requirement already satisfied: fsspec>=2021.9 in /usr/local/lib/python3.10/dist-packages (from datamol) (2023.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datamol) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.11.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from datamol) (3.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from datamol) (9.4.0)
# Collecting selfies (from datamol)
#   Downloading selfies-2.1.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from datamol) (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from datamol) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datamol) (23.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from datamol) (4.5.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from datamol) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datamol) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->datamol) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->datamol) (1.16.0)
# Installing collected packages: selfies, loguru, datamol
# Successfully installed datamol-0.11.3 loguru-0.7.2 selfies-2.1.1
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 61.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (9.4.0)
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import os
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import Linear
from torch.utils.data import DataLoader
import tqdm
from scipy.stats import spearmanr

# %%
def ecfp_from_smiles(smiles,
                     R = 2,
                     L = 2**11,
                     use_features = True,
                     use_chirality = False):
    """
    Inputs:

    - smiles ... SMILES string of input compound
    - R ... maximum radius of circular substructures
    - L ... fingerprint-length
    - use_features ... if false then use standard DAYLIGHT atom features, if true then use pharmacophoric atom features
    - use_chirality ... if true then append tetrahedral chirality flags to atom features

    Outputs:
    - np.array(feature_list) ... ECFP with length L and maximum radius R
    """

    molecule = Chem.MolFromSmiles(smiles)
    if not molecule:
        return np.nan
    feature_list = AllChem.GetMorganFingerprintAsBitVect(molecule,
                                                         radius = R,
                                                         nBits = L,
                                                         useFeatures = use_features,
                                                         useChirality = use_chirality)
    return np.array(feature_list)

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Project/ALVS")
# Out:
# Mounted at /content/drive

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, fps, scores):
        self.fps = fps
        self.scores = scores
        self.dataLen = len(scores)

    def __getitem__(self, index):
        fp = np.array(self.fps[index])
        score = np.array(self.scores[index]).reshape(1,)
        return fp, score

    def __len__(self):
        return self.dataLen

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.fc1 = Linear(2048, 1024)
        self.dropout1 = nn.Dropout(p=0.5)
        self.fc2 = Linear(1024, 516)
        self.dropout2 = nn.Dropout(p=0.5)
        self.fc3 = Linear(516, 256)
        self.dropout3 = nn.Dropout(p=0.5)
        self.fc4 = Linear(256, 128)
        self.dropout4 = nn.Dropout(p=0.5)
        self.fc5 = Linear(128, 1)


    def forward(self, data):
        x = F.relu(self.fc1(data))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = F.relu(self.fc3(x))
        x = self.dropout3(x)
        x = F.relu(self.fc4(x))
        x = self.dropout4(x)
        x = self.fc5(x)
        return x

# %%
def train_epoch(loader, model, optimizer, device):
    model.train()

    loss_all = 0
    i = 0
    for fps, scores in loader:
        fps = fps.float().to(device)
        scores = scores.float().to(device)

        optimizer.zero_grad()
        output = model(fps)
        loss = F.mse_loss(output, scores)
        loss.backward()

        loss_all += loss.item()
        optimizer.step()
        i += 1
    return loss_all / i

# %%
def test_epoch(loader, model,  device):
    model.eval()

    MSE, MAE = 0, 0
    trues, preds = [], []
    with torch.no_grad():
        for fps, scores in loader:
            fps = fps.float().to(device)
            scores = scores.float().to(device)

            output = model(fps)
            pred = output.cpu().squeeze().numpy().tolist()
            true = scores.cpu().squeeze().numpy().tolist()

            trues.extend(true)
            preds.extend(pred)
    MAE = mean_absolute_error(trues, preds)
    RMSE = np.sqrt(mean_squared_error(trues, preds))
    R2 = r2_score(trues, preds)
    Sp = spearmanr(trues, preds)[0]
    return MAE, RMSE, R2, Sp

# %%
def init_model(device, lr=0.0001):
    model = DNN()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    return model, optimizer

# %%
def prepare_dataloader(dff, batch_size, test_size=0.8):
    train_fps, valid_fps, train_scores, valid_scores = train_test_split(
                                                                        dff["ecfp"],
                                                                        dff["score"],
                                                                        test_size=test_size)
    train_dataset = Dataset(fps=list(train_fps),
                            scores = list(train_scores))
    valid_dataset = Dataset(fps=list(valid_fps),
                            scores = list(valid_scores))
    train_loader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=True)
    valid_loader = DataLoader(valid_dataset,
                              batch_size=batch_size,
                              shuffle=False)
    return train_loader, valid_loader

# %%
def train_step(dff, epochs, batch_size, step_time, device="cuda"):
    model, optimizer = init_model(device=device)
    train_loader, valid_loader = prepare_dataloader(dff,  batch_size=batch_size)

    model_folder = "models/mk14/ecfp/models_dropout/{}".format(step_time)
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)

    hist = {"train-loss":[], "test-mae":[], "test-rmse":[], "test-r2":[], "test-sp":[]}
    for epoch in range(epochs):
        train_loss = train_epoch(train_loader, model, optimizer, device)
        test_mae, test_rmse, test_r2, test_sp = test_epoch(valid_loader, model, device)
        hist["train-loss"].append(train_loss)
        hist["test-mae"].append(test_mae)
        hist["test-rmse"].append(test_rmse)
        hist["test-r2"].append(test_r2)
        hist["test-sp"].append(test_sp)

        if test_rmse <= min(hist["test-rmse"]):
            weight_path = os.path.join(model_folder, "weight_{}.pth".format(epoch))
            torch.save(model.state_dict(), weight_path)

        # print(f'Epoch: {epoch}, Train loss: {train_loss:.3}, Test mae: {test_mae:.3}, Test rmse: {test_rmse:.3}, Test r2: {test_r2:.3}')
    print("---------------------------------\nvalidation min rmse: {}\n---------------------------------\n".format(min(hist["test-rmse"])))
    return weight_path

# %%
def random_select(df, n_samples):
    df_select = df.sample(n=n_samples).copy()
    sample_indexs = df_select["name"].tolist()
    df_remaining = df[~df["name"].isin(sample_indexs)].copy()
    return df_select, df_remaining

# %%
def enable_dropout(model):
    """ Function to enable the dropout layers during test-time """
    for m in model.modules():
        if m.__class__.__name__.startswith('Dropout'):
            m.train()

# %%
def load_model(best_model_path, device="cuda", enable_dp=True):
    model= DNN().to(device)
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()
    if enable_dp:
        enable_dropout(model)
    return model

# %%
def predict_with_uncertainty(fpnp, model, device, times=5):
    fpnp = fpnp.reshape(1, 2048)
    fp = torch.from_numpy(fpnp).float().to(device)
    dropout_predictions = []
    with torch.no_grad():
        for _ in range(times):
            output = model(fp)
            pred = output.cpu().numpy()[0][0]
            dropout_predictions.append(pred)
    mean = np.mean(dropout_predictions)
    variance = np.var(dropout_predictions)
    return [mean, variance]

# %%
def uncertainty_select(dff, best_model_path, n_samples):
    model = load_model(best_model_path, enable_dp=True)
    dff["mean_var"] = dff["ecfp"].map(lambda x: predict_with_uncertainty(x,  model, device="cuda"))
    dff["mean"] = dff["mean_var"].map(lambda x: x[0])
    dff["var"] = dff["mean_var"].map(lambda x: x[1])
    dff_sort = dff.sort_values(by="var", ascending=False)
    dff_select = dff_sort.iloc[:n_samples, :4].copy()
    sample_indexs = dff_select["name"].tolist()
    dff_remaining = dff_sort[~dff_sort["name"].isin(sample_indexs)].copy()
    return dff_select, dff_remaining

# %%
def predict(fpnp, model, device):
    fpnp = fpnp.reshape(1, 2048)
    fp = torch.from_numpy(fpnp).float().to(device)
    with torch.no_grad():
        output = model(fp)
        pred = output.cpu().numpy()[0][0]
    return pred

# %%
def eval_model(dff, best_model_path):
    model = load_model(best_model_path, enable_dp=False)
    dff["pred"] = dff["ecfp"].map(lambda x: predict(x,  model, device="cuda"))
    MAE = mean_absolute_error(dff["score"], dff["pred"])
    RMSE = np.sqrt(mean_squared_error(dff["score"], dff["pred"]))
    R2 = r2_score(dff["score"], dff["pred"])
    Sp = spearmanr(dff["score"], dff["pred"])[0]
    return MAE, RMSE, R2, Sp

# %%
def run_step(dfs, epochs, stime):
    dfs_new = dfs.copy()

    best_model_path = train_step(dfs_new, epochs, batch_size=32, step_time=stime)
    return best_model_path

# %%
def run_iterations(df, df_test, epochs=200, iterations=100, n_samples=100):
    results = {"RMSE": [], "R2": [], "Sp": []}

    print("len(df):", len(df))

    df["ecfp"] = df["smiles"].map(lambda x: ecfp_from_smiles(x))
    df = df[~df["ecfp"].isna()]

    for stime in range(iterations):
        if stime < 1:
            dfs, dfr = random_select(df, n_samples)
        else:
            df_temp = dfs.copy()
            dfs, dfr = uncertainty_select(dfr, best_model_path, n_samples)
            dfs = pd.concat([dfs, df_temp], axis=0)
            dfs = dfs.reset_index(drop=True)
        print("number of mol pool:", len(dfs))
        best_model_path = run_step(dfs, epochs, stime)
        MAE, RMSE, R2, Sp = eval_model(df_test, best_model_path)
        print("MAE:{}, RMSE:{}, R2:{}, Sp:{}, step:{}".format(MAE, RMSE, R2, Sp, stime))

        results["RMSE"].append(RMSE)
        results["R2"].append(R2)
        results["Sp"].append(Sp)

    # Convert results dictionary to DataFrame
    results_df = pd.DataFrame(results)

    results_df.to_csv('ecfp_dropout_results.csv', index=False)

# %%
df = pd.read_csv("preprocess_data/mk14/mk14_train.csv", sep="\t")
df_test = pd.read_csv("preprocess_data/mk14/mk14_test.csv", sep="\t")
df_test["ecfp"] = df_test["smiles"].map(lambda x: ecfp_from_smiles(x))
df_test = df_test[~df_test["ecfp"].isna()]

# %%
run_iterations(df, df_test)
# Out:
# len(df): 21827
# [16:36:26] SMILES Parse Error: syntax error while parsing: error
# [16:36:26] SMILES Parse Error: Failed parsing SMILES 'error' for input: 'error'
# number of mol pool: 100
# ---------------------------------
# validation min rmse: 1.342027013657887
# ---------------------------------
#
# MAE:1.132809520361995, RMSE:1.442298249505377, R2:-2.0073718247698125, Sp:0.22407276409330748, step:0
# number of mol pool: 200
# ---------------------------------
# validation min rmse: 1.2736794541283876
# ---------------------------------
#
# MAE:1.275365683005158, RMSE:1.5812500385745454, R2:-2.614748382152605, Sp:0.2527827280839457, step:1
# number of mol pool: 300
# ---------------------------------
# validation min rmse: 1.1754268358285815
# ---------------------------------
#
# MAE:1.332877701269846, RMSE:1.6531730266181908, R2:-2.951059729588622, Sp:0.2671812278545854, step:2
# number of mol pool: 400
# ---------------------------------
# validation min rmse: 1.1102626077777136
# ---------------------------------
#
# MAE:1.2936124521807306, RMSE:1.6000252659437773, R2:-2.701098599092639, Sp:0.2837995093469065, step:3
# number of mol pool: 500
# ---------------------------------
# validation min rmse: 1.1036973077943288
# ---------------------------------
#
# MAE:1.2428772448995067, RMSE:1.5454978094694016, R2:-2.4531366228220515, Sp:0.3013812309847428, step:4
# number of mol pool: 600
# ---------------------------------
# validation min rmse: 1.079558252874512
# ---------------------------------
#
# MAE:1.2842563236333038, RMSE:1.5832865321023937, R2:-2.624065254108517, Sp:0.30475912305146363, step:5
# number of mol pool: 700
# ---------------------------------
# validation min rmse: 0.9979224840893899
# ---------------------------------
#
# MAE:1.1622453191526647, RMSE:1.4473955003130938, R2:-2.0286661947637827, Sp:0.3651910709571776, step:6
# number of mol pool: 800
# ---------------------------------
# validation min rmse: 0.9716152426180027
# ---------------------------------
#
# MAE:1.1463736210703779, RMSE:1.4271454276410904, R2:-1.9445127193393588, Sp:0.3417569064208979, step:7
# number of mol pool: 900
# ---------------------------------
# validation min rmse: 1.0148346867905707
# ---------------------------------
#
# MAE:1.1661772259541348, RMSE:1.4458930166667219, R2:-2.0223815827563505, Sp:0.37537884559636764, step:8
# number of mol pool: 1000
# ---------------------------------
# validation min rmse: 0.9119449377158693
# ---------------------------------
#
# MAE:1.0272428072014814, RMSE:1.296246110933282, R2:-1.4291364266386632, Sp:0.4247639235882285, step:9
# number of mol pool: 1100
# ---------------------------------
# validation min rmse: 0.9138628717247413
# ---------------------------------
#
# MAE:1.030321676014752, RMSE:1.3032467309440523, R2:-1.4554452911712548, Sp:0.38521695485501173, step:10
# number of mol pool: 1200
# ---------------------------------
# validation min rmse: 1.0158244658365807
# ---------------------------------
#
# MAE:1.029779471347816, RMSE:1.3002734464319028, R2:-1.4442541495869743, Sp:0.371665819348646, step:11
# number of mol pool: 1300
# ---------------------------------
# validation min rmse: 0.9243111271398007
# ---------------------------------
#
# MAE:1.011319023115845, RMSE:1.280814817744282, R2:-1.3716448812002753, Sp:0.42082703228975804, step:12
# number of mol pool: 1400
# ---------------------------------
# validation min rmse: 0.9685203873320766
# ---------------------------------
#
# MAE:1.0568973283206273, RMSE:1.3344055748181243, R2:-1.5742615450111472, Sp:0.40478770643521805, step:13
# number of mol pool: 1500
# ---------------------------------
# validation min rmse: 0.9631491253530858
# ---------------------------------
#
# MAE:1.0705991898557625, RMSE:1.3473566397603987, R2:-1.6244729902972903, Sp:0.4209657417864692, step:14
# number of mol pool: 1600
# ---------------------------------
# validation min rmse: 0.9598391436203196
# ---------------------------------
#
# MAE:1.0347078795432092, RMSE:1.3101543779392557, R2:-1.4815436489389389, Sp:0.4105372434467069, step:15
# number of mol pool: 1700
# ---------------------------------
# validation min rmse: 0.9113194319610004
# ---------------------------------
#
# MAE:0.9514430239090027, RMSE:1.2228963417534169, R2:-1.1620028665478142, Sp:0.38817221469093893, step:16
# number of mol pool: 1800
# ---------------------------------
# validation min rmse: 0.8894849103523697
# ---------------------------------
#
# MAE:0.9648873655467133, RMSE:1.2174617065337017, R2:-1.1428293874983244, Sp:0.4623606366212536, step:17
# number of mol pool: 1900
# ---------------------------------
# validation min rmse: 0.8959288643625326
# ---------------------------------
#
# MAE:0.956780230952626, RMSE:1.2131334337653361, R2:-1.1276202627774472, Sp:0.42593701349934726, step:18
# number of mol pool: 2000
# ---------------------------------
# validation min rmse: 0.9104898925369334
# ---------------------------------
#
# MAE:0.9012563852753179, RMSE:1.1569081623577797, R2:-0.934972263705008, Sp:0.4521503150675407, step:19
# number of mol pool: 2100
# ---------------------------------
# validation min rmse: 0.8908250427744934
# ---------------------------------
#
# MAE:0.943010807158932, RMSE:1.1878621198219892, R2:-1.0399007617632363, Sp:0.456572929822923, step:20
# number of mol pool: 2200
# ---------------------------------
# validation min rmse: 0.8855467972277674
# ---------------------------------
#
# MAE:0.9232065309898589, RMSE:1.1846774347784372, R2:-1.0289773847394468, Sp:0.44758980600065135, step:21
# number of mol pool: 2300
# ---------------------------------
# validation min rmse: 0.9224495108956801
# ---------------------------------
#
# MAE:0.9201297893709954, RMSE:1.1761596029461427, R2:-0.9999055765046707, Sp:0.4316267823530259, step:22
# number of mol pool: 2400
# ---------------------------------
# validation min rmse: 0.8588086883840694
# ---------------------------------
#
# MAE:0.9065055655209967, RMSE:1.1545516006032428, R2:-0.9270974164870702, Sp:0.4534625735000841, step:23
# number of mol pool: 2500
# ---------------------------------
# validation min rmse: 0.86669919319911
# ---------------------------------
#
# MAE:0.8932056916680994, RMSE:1.129475567311046, R2:-0.8442961314328112, Sp:0.48613340676369493, step:24
# number of mol pool: 2600
# ---------------------------------
# validation min rmse: 0.8404187247636072
# ---------------------------------
#
# MAE:0.8912628212441273, RMSE:1.1361214396164483, R2:-0.866063785575051, Sp:0.4973753735341678, step:25
# number of mol pool: 2700
# ---------------------------------
# validation min rmse: 0.8938460424980496
# ---------------------------------
#
# MAE:0.8947700455645962, RMSE:1.1457279910194316, R2:-0.8977544590376125, Sp:0.47562048336402296, step:26
# number of mol pool: 2800
# ---------------------------------
# validation min rmse: 0.8308118748888175
# ---------------------------------
#
# MAE:0.8368613324596313, RMSE:1.0675647476885044, R2:-0.6476517448569308, Sp:0.47840881238624067, step:27
# number of mol pool: 2900
# ---------------------------------
# validation min rmse: 0.8963374483355756
# ---------------------------------
#
# MAE:0.900103447621274, RMSE:1.145836525672957, R2:-0.898114024100451, Sp:0.475143528845835, step:28
# number of mol pool: 3000
# ---------------------------------
# validation min rmse: 0.8761590228020926
# ---------------------------------
#
# MAE:0.8258188994139, RMSE:1.055126845148584, R2:-0.6094827236581244, Sp:0.49464280953932055, step:29
# number of mol pool: 3100
# ---------------------------------
# validation min rmse: 0.8366995551544987
# ---------------------------------
#
# MAE:0.8022229635477943, RMSE:1.0318898493043025, R2:-0.5393722538694798, Sp:0.47624826402655135, step:30
# number of mol pool: 3200
# ---------------------------------
# validation min rmse: 0.8855419393431082
# ---------------------------------
#
# MAE:0.8801873931802895, RMSE:1.1401324479144908, R2:-0.8792630957547387, Sp:0.4595795735521905, step:31
# number of mol pool: 3300
# ---------------------------------
# validation min rmse: 0.8241892216649896
# ---------------------------------
#
# MAE:0.8243448241505593, RMSE:1.060927693042968, R2:-0.627228512456756, Sp:0.49589829809164443, step:32
# number of mol pool: 3400
# ---------------------------------
# validation min rmse: 0.8512703434916037
# ---------------------------------
#
# MAE:0.8187411887763995, RMSE:1.0509631039287677, R2:-0.5968051068932558, Sp:0.5006341146370578, step:33
# number of mol pool: 3500
# ---------------------------------
# validation min rmse: 0.8324018571086856
# ---------------------------------
#
# MAE:0.8018620938737941, RMSE:1.0331584739766864, R2:-0.5431596466413064, Sp:0.5030174777572399, step:34
# number of mol pool: 3600
# ---------------------------------
# validation min rmse: 0.8492960088345534
# ---------------------------------
#
# MAE:0.8224122679194712, RMSE:1.0544385870381208, R2:-0.6073836807712094, Sp:0.48726085525939156, step:35
# number of mol pool: 3700
# ---------------------------------
# validation min rmse: 0.8035620059621129
# ---------------------------------
#
# MAE:0.7689769264372979, RMSE:0.9856236709369494, R2:-0.4044271737777565, Sp:0.5197434590971522, step:36
# number of mol pool: 3800
# ---------------------------------
# validation min rmse: 0.8325801595648565
# ---------------------------------
#
# MAE:0.7855875337401981, RMSE:1.008653705375363, R2:-0.47082549876853297, Sp:0.5090720368695052, step:37
# number of mol pool: 3900
# ---------------------------------
# validation min rmse: 0.8276479520747125
# ---------------------------------
#
# MAE:0.7559995783356102, RMSE:0.9644741548366116, R2:-0.34480143033484456, Sp:0.49565279088949027, step:38
# number of mol pool: 4000
# ---------------------------------
# validation min rmse: 0.8119041257817514
# ---------------------------------
#
# MAE:0.7571916630205656, RMSE:0.9778102861041069, R2:-0.38224865761320803, Sp:0.5211678495420876, step:39
# number of mol pool: 4100
# ---------------------------------
# validation min rmse: 0.8098940971396074
# ---------------------------------
#
# MAE:0.7292222580052042, RMSE:0.9472377205823896, R2:-0.2971641631900126, Sp:0.50986870957348, step:40
# number of mol pool: 4200
# ---------------------------------
# validation min rmse: 0.8244615189768001
# ---------------------------------
#
# MAE:0.7573045998780472, RMSE:0.972484266128361, R2:-0.3672317685513107, Sp:0.5123499171630864, step:41
# number of mol pool: 4300
# ---------------------------------
# validation min rmse: 0.8256481821631626
# ---------------------------------
#
# MAE:0.7538589051341227, RMSE:0.9786810190071804, R2:-0.38471151833044415, Sp:0.5036562191211643, step:42
# number of mol pool: 4400
# ---------------------------------
# validation min rmse: 0.8143179131141578
# ---------------------------------
#
# MAE:0.775911731748074, RMSE:0.9970542653373765, R2:-0.4371912526046917, Sp:0.5206537995490496, step:43
# number of mol pool: 4500
# ---------------------------------
# validation min rmse: 0.8068884509785483
# ---------------------------------
#
# MAE:0.720927682780936, RMSE:0.925588503858341, R2:-0.23854810038974295, Sp:0.5349900818066854, step:44
# number of mol pool: 4600
# ---------------------------------
# validation min rmse: 0.8052637033638297
# ---------------------------------
#
# MAE:0.7167277328510089, RMSE:0.9181059740160793, R2:-0.21860400299642246, Sp:0.5180380990557616, step:45
# number of mol pool: 4700
# ---------------------------------
# validation min rmse: 0.782430005839714
# ---------------------------------
#
# MAE:0.6943761589160781, RMSE:0.8872122293046395, R2:-0.13797314364156588, Sp:0.5502172501412803, step:46
# number of mol pool: 4800
# ---------------------------------
# validation min rmse: 0.797363287037904
# ---------------------------------
#
# MAE:0.7120017353591866, RMSE:0.9132795193741277, R2:-0.20582535307084027, Sp:0.5285952764695714, step:47
# number of mol pool: 4900
# ---------------------------------
# validation min rmse: 0.7891170386610126
# ---------------------------------
#
# MAE:0.6927273846101266, RMSE:0.8863311488605986, R2:-0.13571404938777953, Sp:0.5381068685699191, step:48
# number of mol pool: 5000
# ---------------------------------
# validation min rmse: 0.8034252515693985
# ---------------------------------
#
# MAE:0.7049433943231685, RMSE:0.9026770509602965, R2:-0.1779904688624867, Sp:0.5309087953285673, step:49
# number of mol pool: 5100
# ---------------------------------
# validation min rmse: 0.8020751293381727
# ---------------------------------
#
# MAE:0.7077561651974047, RMSE:0.9045504271986046, R2:-0.18288504177506626, Sp:0.540315879104617, step:50
# number of mol pool: 5200
# ---------------------------------
# validation min rmse: 0.7906836506835031
# ---------------------------------
#
# MAE:0.6787864080316919, RMSE:0.8711953111080565, R2:-0.097256172074629, Sp:0.5332484073614174, step:51
# number of mol pool: 5300
# ---------------------------------
# validation min rmse: 0.7826347483969859
# ---------------------------------
#
# MAE:0.6853377919710283, RMSE:0.8777609677303553, R2:-0.11385716607119778, Sp:0.5440186786674748, step:52
# number of mol pool: 5400
# ---------------------------------
# validation min rmse: 0.7908100353465424
# ---------------------------------
#
# MAE:0.710231866859683, RMSE:0.909011836697479, R2:-0.19458223144179154, Sp:0.5502132219587813, step:53
# number of mol pool: 5500
# ---------------------------------
# validation min rmse: 0.7973321402918824
# ---------------------------------
#
# MAE:0.6706240619378917, RMSE:0.8658349620022198, R2:-0.08379516860086378, Sp:0.5404232677367828, step:54
# number of mol pool: 5600
# ---------------------------------
# validation min rmse: 0.7910627566276695
# ---------------------------------
#
# MAE:0.6876238735047978, RMSE:0.8838650670251488, R2:-0.12940293769757294, Sp:0.5271743991256235, step:55
# number of mol pool: 5700
# ---------------------------------
# validation min rmse: 0.7864823253120603
# ---------------------------------
#
# MAE:0.6904115190437786, RMSE:0.8883285994067952, R2:-0.1408387453945774, Sp:0.5450865454497211, step:56
# number of mol pool: 5800
# ---------------------------------
# validation min rmse: 0.7548265176395373
# ---------------------------------
#
# MAE:0.6522534349768022, RMSE:0.8368748905313239, R2:-0.012507033756088859, Sp:0.556603367963792, step:57
# number of mol pool: 5900
# ---------------------------------
# validation min rmse: 0.7846911803372442
# ---------------------------------
#
# MAE:0.6737817737664241, RMSE:0.8612260850411182, R2:-0.0722877005681608, Sp:0.5345886914150928, step:58
# number of mol pool: 6000
# ---------------------------------
# validation min rmse: 0.8033051778005634
# ---------------------------------
#
# MAE:0.6950166258883655, RMSE:0.8935773532993838, R2:-0.1543600302477106, Sp:0.527843763397289, step:59
# number of mol pool: 6100
# ---------------------------------
# validation min rmse: 0.7584177452473126
# ---------------------------------
#
# MAE:0.6467592958993648, RMSE:0.8311599075238235, R2:0.0012744831992617112, Sp:0.5464009414830421, step:60
# number of mol pool: 6200
# ---------------------------------
# validation min rmse: 0.7570642609547495
# ---------------------------------
#
# MAE:0.6477145888859673, RMSE:0.8248696085764403, R2:0.016334183624712506, Sp:0.5693607151964971, step:61
# number of mol pool: 6300
# ---------------------------------
# validation min rmse: 0.7752908157653728
# ---------------------------------
#
# MAE:0.6433997898437012, RMSE:0.8252705613294805, R2:0.015377670331197413, Sp:0.5442055522760335, step:62
# number of mol pool: 6400
# ---------------------------------
# validation min rmse: 0.7736257511917003
# ---------------------------------
#
# MAE:0.6537250895317889, RMSE:0.8326826599823023, R2:-0.002388361573653519, Sp:0.5623185379626303, step:63
# number of mol pool: 6500
# ---------------------------------
# validation min rmse: 0.7754632433087191
# ---------------------------------
#
# MAE:0.6541220435747493, RMSE:0.831546361782947, R2:0.00034553690596395015, Sp:0.5596439616920124, step:64
# number of mol pool: 6600
# ---------------------------------
# validation min rmse: 0.7655146418038136
# ---------------------------------
#
# MAE:0.6348114496236184, RMSE:0.8108457027649737, R2:0.04949717355252825, Sp:0.5494889615934567, step:65
# number of mol pool: 6700
# ---------------------------------
# validation min rmse: 0.7597123689550166
# ---------------------------------
#
# MAE:0.6253907063154345, RMSE:0.7977545562108282, R2:0.07994124923103307, Sp:0.5617638118146604, step:66
# number of mol pool: 6800
# ---------------------------------
# validation min rmse: 0.7525600877867721
# ---------------------------------
#
# MAE:0.6178717436641121, RMSE:0.7870183129027233, R2:0.10453905378535422, Sp:0.5551641515580104, step:67
# number of mol pool: 6900
# ---------------------------------
# validation min rmse: 0.7771949827079487
# ---------------------------------
#
# MAE:0.6540896691684507, RMSE:0.8336840880001127, R2:-0.0048008614647878645, Sp:0.5434123000088583, step:68
# number of mol pool: 7000
# ---------------------------------
# validation min rmse: 0.7487646802265339
# ---------------------------------
#
# MAE:0.6086283403545732, RMSE:0.7809238970652259, R2:0.11835367907240113, Sp:0.5626146994366448, step:69
# number of mol pool: 7100
# ---------------------------------
# validation min rmse: 0.7776025861902071
# ---------------------------------
#
# MAE:0.638809429281804, RMSE:0.8191879184445183, R2:0.02983846654676725, Sp:0.5449794661072047, step:70
# number of mol pool: 7200
# ---------------------------------
# validation min rmse: 0.7539505065224199
# ---------------------------------
#
# MAE:0.6056330141832502, RMSE:0.7734236068495168, R2:0.13520768577002928, Sp:0.5645130284386669, step:71
# number of mol pool: 7300
# ---------------------------------
# validation min rmse: 0.7822230623863173
# ---------------------------------
#
# MAE:0.650355816311221, RMSE:0.8299590103803697, R2:0.004158405197920323, Sp:0.5410140266367894, step:72
# number of mol pool: 7400
# ---------------------------------
# validation min rmse: 0.7514037324331957
# ---------------------------------
#
# MAE:0.6169262479560657, RMSE:0.7930915921949226, R2:0.09066550636937909, Sp:0.5595648215511682, step:73
# number of mol pool: 7500
# ---------------------------------
# validation min rmse: 0.7380101971779898
# ---------------------------------
#
# MAE:0.605152876791666, RMSE:0.7764180012519235, R2:0.1284984463172526, Sp:0.576329382978915, step:74
# number of mol pool: 7600
# ---------------------------------
# validation min rmse: 0.7459104281096381
# ---------------------------------
#
# MAE:0.5993485168863236, RMSE:0.7665360034620594, R2:0.15054164962330085, Sp:0.5766296112573117, step:75
# number of mol pool: 7700
# ---------------------------------
# validation min rmse: 0.7463425215354593
# ---------------------------------
#
# MAE:0.6089901981122061, RMSE:0.7797063861438267, R2:0.12110062347399264, Sp:0.5756028359036646, step:76
# number of mol pool: 7800
# ---------------------------------
# validation min rmse: 0.7449370494929289
# ---------------------------------
#
# MAE:0.6090571065772754, RMSE:0.7773135606260411, R2:0.12648681982780463, Sp:0.5808223567160166, step:77
# number of mol pool: 7900
# ---------------------------------
# validation min rmse: 0.7335174340101386
# ---------------------------------
#
# MAE:0.5791081883983846, RMSE:0.735335831576835, R2:0.21828502521188042, Sp:0.5731827387542108, step:78
# number of mol pool: 8000
# ---------------------------------
# validation min rmse: 0.7519927118935156
# ---------------------------------
#
# MAE:0.6069222238470972, RMSE:0.7743152632479915, R2:0.13321255119976194, Sp:0.5828722679128667, step:79
# number of mol pool: 8100
# ---------------------------------
# validation min rmse: 0.7500030585749443
# ---------------------------------
#
# MAE:0.6236237967340723, RMSE:0.7918746475688827, R2:0.09345398812315109, Sp:0.5820789357640903, step:80
# number of mol pool: 8200
# ---------------------------------
# validation min rmse: 0.7334622182788731
# ---------------------------------
#
# MAE:0.5885460524514595, RMSE:0.7496369234249624, R2:0.1875831674483096, Sp:0.5722285582518603, step:81
# number of mol pool: 8300
# ---------------------------------
# validation min rmse: 0.7379055954581475
# ---------------------------------
#
# MAE:0.5889978633048247, RMSE:0.7490935900033567, R2:0.1887604126892225, Sp:0.5603773108858117, step:82
# number of mol pool: 8400
# ---------------------------------
# validation min rmse: 0.7311251690649229
# ---------------------------------
#
# MAE:0.5643239661613687, RMSE:0.718345548379688, R2:0.25399148715547293, Sp:0.5792472316472083, step:83
# number of mol pool: 8500
# ---------------------------------
# validation min rmse: 0.7236466392452551
# ---------------------------------
#
# MAE:0.5869643952818565, RMSE:0.7488127022844905, R2:0.18936867984961647, Sp:0.5977726858805761, step:84
# number of mol pool: 8600
# ---------------------------------
# validation min rmse: 0.733375698166496
# ---------------------------------
#
# MAE:0.5870796040811331, RMSE:0.7506947491384847, R2:0.18528871864885954, Sp:0.5877268056011993, step:85
# number of mol pool: 8700
# ---------------------------------
# validation min rmse: 0.7344934321555153
# ---------------------------------
#
# MAE:0.5793546060309627, RMSE:0.7370551105040501, R2:0.21462531708002208, Sp:0.5827741244261202, step:86
# number of mol pool: 8800
# ---------------------------------
# validation min rmse: 0.7499714455052828
# ---------------------------------
#
# MAE:0.5895702172472045, RMSE:0.7507247704655833, R2:0.1852235544713683, Sp:0.5807919672564033, step:87
# number of mol pool: 8900
# ---------------------------------
# validation min rmse: 0.7257470619869479
# ---------------------------------
#
# MAE:0.5653688543982465, RMSE:0.722215503533343, R2:0.24593186699075842, Sp:0.5809919854983288, step:88
# number of mol pool: 9000
# ---------------------------------
# validation min rmse: 0.7422534334239564
# ---------------------------------
#
# MAE:0.5876683129857843, RMSE:0.7517733302552281, R2:0.18294591959270556, Sp:0.5691670289348869, step:89
# number of mol pool: 9100
# ---------------------------------
# validation min rmse: 0.7177379597699999
# ---------------------------------
#
# MAE:0.5533638673759926, RMSE:0.7040267994268082, R2:0.28343538818093916, Sp:0.5861601461815188, step:90
# number of mol pool: 9200
# ---------------------------------
# validation min rmse: 0.7239494464911542
# ---------------------------------
#
# MAE:0.5581096666719509, RMSE:0.7158844086751605, R2:0.2590945630813689, Sp:0.5700768401597697, step:91
# number of mol pool: 9300
# ---------------------------------
# validation min rmse: 0.7126277326473063
# ---------------------------------
#
# MAE:0.5505736437041032, RMSE:0.7028082806242335, R2:0.285913679741294, Sp:0.5895243804419744, step:92
# number of mol pool: 9400
# ---------------------------------
# validation min rmse: 0.7095944225658445
# ---------------------------------
#
# MAE:0.559052859030529, RMSE:0.7142394416578006, R2:0.26249557236774557, Sp:0.5895160300422434, step:93
# number of mol pool: 9500
# ---------------------------------
# validation min rmse: 0.721774924892052
# ---------------------------------
#
# MAE:0.5642833478558873, RMSE:0.71915399524737, R2:0.25231138313152357, Sp:0.6067648634847301, step:94
# number of mol pool: 9600
# ---------------------------------
# validation min rmse: 0.7011141500787433
# ---------------------------------
#
# MAE:0.5440052925148947, RMSE:0.6941514202626508, R2:0.30339689335540454, Sp:0.5891974639679496, step:95
# number of mol pool: 9700
# ---------------------------------
# validation min rmse: 0.6987431130856124
# ---------------------------------
#
# MAE:0.5462119883338653, RMSE:0.6949483949136892, R2:0.3017963960932962, Sp:0.5927616153637493, step:96
# number of mol pool: 9800
# ---------------------------------
# validation min rmse: 0.6971892785607523
# ---------------------------------
#
# MAE:0.5362148595554904, RMSE:0.6825400864309576, R2:0.3265066684176453, Sp:0.5987364025571994, step:97
# number of mol pool: 9900
# ---------------------------------
# validation min rmse: 0.7047153995475595
# ---------------------------------
#
# MAE:0.5492636784956301, RMSE:0.7017704829567653, R2:0.2880210253272587, Sp:0.6095263718625027, step:98
# number of mol pool: 10000
# ---------------------------------
# validation min rmse: 0.684718154281431
# ---------------------------------
#
# MAE:0.5389892584649394, RMSE:0.6842470451634134, R2:0.32313378852207464, Sp:0.5874018509909122, step:99
