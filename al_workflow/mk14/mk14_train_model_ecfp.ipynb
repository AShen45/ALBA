# %%
# !pip install datamol
# !pip install rdkit-pypi
# !pip install pandas
# Out:
# Collecting datamol
#   Downloading datamol-0.11.3-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.7/381.7 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from datamol) (4.66.1)
# Collecting loguru (from datamol)
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from datamol) (1.3.2)
# Requirement already satisfied: fsspec>=2021.9 in /usr/local/lib/python3.10/dist-packages (from datamol) (2023.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datamol) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.11.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from datamol) (3.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from datamol) (9.4.0)
# Collecting selfies (from datamol)
#   Downloading selfies-2.1.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from datamol) (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from datamol) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datamol) (23.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from datamol) (4.5.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from datamol) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datamol) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->datamol) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->datamol) (1.16.0)
# Installing collected packages: selfies, loguru, datamol
# Successfully installed datamol-0.11.3 loguru-0.7.2 selfies-2.1.1
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 58.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (9.4.0)
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import os
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import Linear
from torch.utils.data import DataLoader
import tqdm
from scipy.stats import spearmanr

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Project/ALVS")
# Out:
# Mounted at /content/drive

# %%
def ecfp_from_smiles(smiles,
                     R = 2,
                     L = 2**11,
                     use_features = True,
                     use_chirality = False):
    """
    Inputs:

    - smiles ... SMILES string of input compound
    - R ... maximum radius of circular substructures
    - L ... fingerprint-length
    - use_features ... if false then use standard DAYLIGHT atom features, if true then use pharmacophoric atom features
    - use_chirality ... if true then append tetrahedral chirality flags to atom features

    Outputs:
    - np.array(feature_list) ... ECFP with length L and maximum radius R
    """

    molecule = Chem.MolFromSmiles(smiles)
    if not molecule:
        return np.nan
    feature_list = AllChem.GetMorganFingerprintAsBitVect(molecule,
                                                         radius = R,
                                                         nBits = L,
                                                         useFeatures = use_features,
                                                         useChirality = use_chirality)
    return np.array(feature_list)

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, fps, scores):
        self.fps = fps
        self.scores = scores
        self.dataLen = len(scores)

    def __getitem__(self, index):
        fp = np.array(self.fps[index])
        score = np.array(self.scores[index]).reshape(1,)
        return fp, score

    def __len__(self):
        return self.dataLen

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.fc1 = Linear(2048, 1024)
        self.dropout1 = nn.Dropout(p=0.2)
        self.fc2 = Linear(1024, 516)
        self.dropout2 = nn.Dropout(p=0.2)
        self.fc3 = Linear(516, 256)
        self.dropout3 = nn.Dropout(p=0.2)
        self.fc4 = Linear(256, 128)
        self.dropout4 = nn.Dropout(p=0.2)
        self.fc5 = Linear(128, 1)


    def forward(self, data):
        x = F.relu(self.fc1(data))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = F.relu(self.fc3(x))
        x = self.dropout3(x)
        x = F.relu(self.fc4(x))
        x = self.dropout4(x)
        x = self.fc5(x)
        return x

# %%
def train_epoch(loader, model, optimizer, device):
    model.train()

    loss_all = 0
    i = 0
    for fps, scores in loader:
        fps = fps.float().to(device)
        scores = scores.float().to(device)

        optimizer.zero_grad()
        output = model(fps)
        loss = F.mse_loss(output, scores)
        loss.backward()

        loss_all += loss.item()
        optimizer.step()
        i += 1
    return loss_all / i

# %%
def test_epoch(loader, model,  device):
    model.eval()

    MSE, MAE = 0, 0
    trues, preds = [], []
    with torch.no_grad():
        for fps, scores in loader:
            fps = fps.float().to(device)
            scores = scores.float().to(device)

            output = model(fps)
            pred = output.cpu().squeeze().numpy().tolist()
            true = scores.cpu().squeeze().numpy().tolist()

            trues.extend(true)
            preds.extend(pred)
    MAE = mean_absolute_error(trues, preds)
    RMSE = np.sqrt(mean_squared_error(trues, preds))
    R2 = r2_score(trues, preds)
    Sp = spearmanr(trues, preds)[0]
    return MAE, RMSE, R2, Sp

# %%
def init_model(device):
    model = DNN()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    lr = 0.0001
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    return model, optimizer

# %%
def prepare_dataloader(dff, batch_size, test_size=0.8):
    train_fps, valid_fps, train_scores, valid_scores = train_test_split(
                                                                        dff["ecfp"],
                                                                        dff["score"],
                                                                        test_size=test_size)
    train_dataset = Dataset(fps=list(train_fps),
                            scores = list(train_scores))
    valid_dataset = Dataset(fps=list(valid_fps),
                            scores = list(valid_scores))
    train_loader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=True)
    valid_loader = DataLoader(valid_dataset,
                              batch_size=batch_size,
                              shuffle=False)
    return train_loader, valid_loader

# %%
def train_step(dff, epochs, batch_size, device="cuda"):
    model, optimizer = init_model(device=device)
    train_loader, valid_loader = prepare_dataloader(dff,  batch_size=batch_size)

    model_folder = "models/mk14/ecfp/base_ecfp"
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)

    hist = {"train-loss":[], "test-mae":[], "test-rmse":[], "test-r2":[],  "test-sp":[]}
    for epoch in range(epochs):
        train_loss = train_epoch(train_loader, model, optimizer, device)
        test_mae, test_rmse, test_r2, test_sp = test_epoch(valid_loader, model, device)
        hist["train-loss"].append(train_loss)
        hist["test-mae"].append(test_mae)
        hist["test-rmse"].append(test_rmse)
        hist["test-r2"].append(test_r2)
        hist["test-sp"].append(test_sp)

        if test_rmse <= min(hist["test-rmse"]):
            weight_path = os.path.join(model_folder, "weight_ecfp.pth")
            torch.save(model.state_dict(), weight_path)

        print(f'Epoch: {epoch}, Train loss: {train_loss:.3}, Test mae: {test_mae:.3}, Test rmse: {test_rmse:.3}, Test r2: {test_r2:.3}, Test sp: {test_sp:.3}')
    return weight_path

# %%
def load_model(best_model_path, device="cuda"):
    model= DNN().to(device)
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()
    return model

# %%
def predict(fpnp, model, device):
    fpnp = fpnp.reshape(1, 2048)
    fp = torch.from_numpy(fpnp).float().to(device)

    with torch.no_grad():
        output = model(fp)
        pred = output.cpu().numpy()[0][0]
    return pred

# %%
def eval_model(dff, best_model_path):
    model = load_model(best_model_path)
    dff["pred"] = dff["ecfp"].map(lambda x: predict(x,  model, device="cuda"))
    MAE = mean_absolute_error(dff["score"], dff["pred"])
    RMSE = np.sqrt(mean_squared_error(dff["score"], dff["pred"]))
    R2 = r2_score(dff["score"], dff["pred"])
    Sp = spearmanr(dff["score"], dff["pred"])[0]
    return MAE, RMSE, R2, Sp

# %%
df = pd.read_csv("preprocess_data/mk14/mk14_train.csv", sep="\t")
df["ecfp"] = df["smiles"].map(lambda x: ecfp_from_smiles(x))
df = df[~df["ecfp"].isna()]
# Out:
# [16:13:57] SMILES Parse Error: syntax error while parsing: error
# [16:13:57] SMILES Parse Error: Failed parsing SMILES 'error' for input: 'error'

# %%
df_test = pd.read_csv("preprocess_data/mk14/mk14_test.csv", sep="\t")
df_test["ecfp"] = df_test["smiles"].map(lambda x: ecfp_from_smiles(x))
df_test = df_test[~df_test["ecfp"].isna()]

# %%
best_model_path = train_step(df, epochs=100, batch_size=32, device="cuda")
# Out:
# Epoch: 0, Train loss: 22.0, Test mae: 0.89, Test rmse: 1.13, Test r2: -0.862, Test sp: 0.34
# Epoch: 1, Train loss: 1.73, Test mae: 0.737, Test rmse: 0.936, Test r2: -0.268, Test sp: 0.458
# Epoch: 2, Train loss: 1.34, Test mae: 0.68, Test rmse: 0.865, Test r2: -0.0838, Test sp: 0.514
# Epoch: 3, Train loss: 1.13, Test mae: 0.645, Test rmse: 0.821, Test r2: 0.0238, Test sp: 0.544
# Epoch: 4, Train loss: 1.02, Test mae: 0.624, Test rmse: 0.795, Test r2: 0.0853, Test sp: 0.558
# Epoch: 5, Train loss: 0.919, Test mae: 0.604, Test rmse: 0.77, Test r2: 0.141, Test sp: 0.573
# Epoch: 6, Train loss: 0.858, Test mae: 0.599, Test rmse: 0.763, Test r2: 0.157, Test sp: 0.578
# Epoch: 7, Train loss: 0.771, Test mae: 0.597, Test rmse: 0.758, Test r2: 0.167, Test sp: 0.586
# Epoch: 8, Train loss: 0.768, Test mae: 0.574, Test rmse: 0.73, Test r2: 0.228, Test sp: 0.585
# Epoch: 9, Train loss: 0.719, Test mae: 0.687, Test rmse: 0.859, Test r2: -0.0686, Test sp: 0.59
# Epoch: 10, Train loss: 0.72, Test mae: 0.577, Test rmse: 0.737, Test r2: 0.213, Test sp: 0.6
# Epoch: 11, Train loss: 0.695, Test mae: 0.575, Test rmse: 0.732, Test r2: 0.224, Test sp: 0.598
# Epoch: 12, Train loss: 0.69, Test mae: 0.588, Test rmse: 0.748, Test r2: 0.189, Test sp: 0.6
# Epoch: 13, Train loss: 0.648, Test mae: 0.572, Test rmse: 0.728, Test r2: 0.232, Test sp: 0.599
# Epoch: 14, Train loss: 0.661, Test mae: 0.549, Test rmse: 0.703, Test r2: 0.285, Test sp: 0.617
# Epoch: 15, Train loss: 0.687, Test mae: 0.55, Test rmse: 0.705, Test r2: 0.281, Test sp: 0.608
# Epoch: 16, Train loss: 0.635, Test mae: 0.546, Test rmse: 0.699, Test r2: 0.292, Test sp: 0.606
# Epoch: 17, Train loss: 0.655, Test mae: 0.61, Test rmse: 0.774, Test r2: 0.132, Test sp: 0.6
# Epoch: 18, Train loss: 0.664, Test mae: 0.549, Test rmse: 0.703, Test r2: 0.284, Test sp: 0.599
# Epoch: 19, Train loss: 0.618, Test mae: 0.554, Test rmse: 0.709, Test r2: 0.272, Test sp: 0.607
# Epoch: 20, Train loss: 0.635, Test mae: 0.552, Test rmse: 0.706, Test r2: 0.277, Test sp: 0.615
# Epoch: 21, Train loss: 0.632, Test mae: 0.542, Test rmse: 0.693, Test r2: 0.305, Test sp: 0.622
# Epoch: 22, Train loss: 0.6, Test mae: 0.544, Test rmse: 0.694, Test r2: 0.302, Test sp: 0.61
# Epoch: 23, Train loss: 0.625, Test mae: 0.552, Test rmse: 0.703, Test r2: 0.283, Test sp: 0.608
# Epoch: 24, Train loss: 0.622, Test mae: 0.574, Test rmse: 0.727, Test r2: 0.233, Test sp: 0.61
# Epoch: 25, Train loss: 0.597, Test mae: 0.588, Test rmse: 0.749, Test r2: 0.188, Test sp: 0.617
# Epoch: 26, Train loss: 0.588, Test mae: 0.579, Test rmse: 0.739, Test r2: 0.208, Test sp: 0.614
# Epoch: 27, Train loss: 0.575, Test mae: 0.551, Test rmse: 0.705, Test r2: 0.28, Test sp: 0.617
# Epoch: 28, Train loss: 0.579, Test mae: 0.54, Test rmse: 0.689, Test r2: 0.312, Test sp: 0.612
# Epoch: 29, Train loss: 0.584, Test mae: 0.539, Test rmse: 0.687, Test r2: 0.316, Test sp: 0.616
# Epoch: 30, Train loss: 0.599, Test mae: 0.589, Test rmse: 0.747, Test r2: 0.192, Test sp: 0.62
# Epoch: 31, Train loss: 0.597, Test mae: 0.603, Test rmse: 0.763, Test r2: 0.156, Test sp: 0.621
# Epoch: 32, Train loss: 0.565, Test mae: 0.541, Test rmse: 0.692, Test r2: 0.306, Test sp: 0.612
# Epoch: 33, Train loss: 0.568, Test mae: 0.542, Test rmse: 0.692, Test r2: 0.307, Test sp: 0.616
# Epoch: 34, Train loss: 0.566, Test mae: 0.547, Test rmse: 0.701, Test r2: 0.289, Test sp: 0.621
# Epoch: 35, Train loss: 0.579, Test mae: 0.581, Test rmse: 0.74, Test r2: 0.206, Test sp: 0.609
# Epoch: 36, Train loss: 0.597, Test mae: 0.54, Test rmse: 0.691, Test r2: 0.308, Test sp: 0.623
# Epoch: 37, Train loss: 0.558, Test mae: 0.612, Test rmse: 0.773, Test r2: 0.134, Test sp: 0.622
# Epoch: 38, Train loss: 0.557, Test mae: 0.54, Test rmse: 0.691, Test r2: 0.309, Test sp: 0.609
# Epoch: 39, Train loss: 0.538, Test mae: 0.536, Test rmse: 0.686, Test r2: 0.319, Test sp: 0.621
# Epoch: 40, Train loss: 0.556, Test mae: 0.554, Test rmse: 0.71, Test r2: 0.27, Test sp: 0.62
# Epoch: 41, Train loss: 0.566, Test mae: 0.539, Test rmse: 0.69, Test r2: 0.311, Test sp: 0.625
# Epoch: 42, Train loss: 0.559, Test mae: 0.55, Test rmse: 0.701, Test r2: 0.287, Test sp: 0.619
# Epoch: 43, Train loss: 0.571, Test mae: 0.557, Test rmse: 0.71, Test r2: 0.271, Test sp: 0.619
# Epoch: 44, Train loss: 0.581, Test mae: 0.549, Test rmse: 0.703, Test r2: 0.284, Test sp: 0.616
# Epoch: 45, Train loss: 0.55, Test mae: 0.586, Test rmse: 0.744, Test r2: 0.197, Test sp: 0.625
# Epoch: 46, Train loss: 0.545, Test mae: 0.537, Test rmse: 0.687, Test r2: 0.316, Test sp: 0.615
# Epoch: 47, Train loss: 0.542, Test mae: 0.537, Test rmse: 0.686, Test r2: 0.317, Test sp: 0.621
# Epoch: 48, Train loss: 0.537, Test mae: 0.536, Test rmse: 0.687, Test r2: 0.316, Test sp: 0.622
# Epoch: 49, Train loss: 0.54, Test mae: 0.539, Test rmse: 0.689, Test r2: 0.311, Test sp: 0.624
# Epoch: 50, Train loss: 0.517, Test mae: 0.538, Test rmse: 0.688, Test r2: 0.313, Test sp: 0.618
# Epoch: 51, Train loss: 0.555, Test mae: 0.611, Test rmse: 0.772, Test r2: 0.137, Test sp: 0.615
# Epoch: 52, Train loss: 0.538, Test mae: 0.532, Test rmse: 0.681, Test r2: 0.328, Test sp: 0.621
# Epoch: 53, Train loss: 0.526, Test mae: 0.532, Test rmse: 0.681, Test r2: 0.329, Test sp: 0.617
# Epoch: 54, Train loss: 0.537, Test mae: 0.56, Test rmse: 0.716, Test r2: 0.257, Test sp: 0.62
# Epoch: 55, Train loss: 0.52, Test mae: 0.534, Test rmse: 0.684, Test r2: 0.322, Test sp: 0.619
# Epoch: 56, Train loss: 0.53, Test mae: 0.535, Test rmse: 0.685, Test r2: 0.32, Test sp: 0.617
# Epoch: 57, Train loss: 0.542, Test mae: 0.541, Test rmse: 0.693, Test r2: 0.305, Test sp: 0.622
# Epoch: 58, Train loss: 0.525, Test mae: 0.546, Test rmse: 0.697, Test r2: 0.296, Test sp: 0.613
# Epoch: 59, Train loss: 0.542, Test mae: 0.541, Test rmse: 0.693, Test r2: 0.304, Test sp: 0.623
# Epoch: 60, Train loss: 0.539, Test mae: 0.581, Test rmse: 0.74, Test r2: 0.206, Test sp: 0.623
# Epoch: 61, Train loss: 0.55, Test mae: 0.542, Test rmse: 0.694, Test r2: 0.302, Test sp: 0.623
# Epoch: 62, Train loss: 0.532, Test mae: 0.567, Test rmse: 0.723, Test r2: 0.243, Test sp: 0.617
# Epoch: 63, Train loss: 0.531, Test mae: 0.542, Test rmse: 0.695, Test r2: 0.3, Test sp: 0.622
# Epoch: 64, Train loss: 0.524, Test mae: 0.546, Test rmse: 0.697, Test r2: 0.296, Test sp: 0.618
# Epoch: 65, Train loss: 0.519, Test mae: 0.529, Test rmse: 0.68, Test r2: 0.331, Test sp: 0.624
# Epoch: 66, Train loss: 0.496, Test mae: 0.536, Test rmse: 0.684, Test r2: 0.323, Test sp: 0.611
# Epoch: 67, Train loss: 0.517, Test mae: 0.589, Test rmse: 0.747, Test r2: 0.191, Test sp: 0.62
# Epoch: 68, Train loss: 0.52, Test mae: 0.54, Test rmse: 0.691, Test r2: 0.309, Test sp: 0.618
# Epoch: 69, Train loss: 0.536, Test mae: 0.534, Test rmse: 0.685, Test r2: 0.321, Test sp: 0.623
# Epoch: 70, Train loss: 0.501, Test mae: 0.541, Test rmse: 0.692, Test r2: 0.307, Test sp: 0.627
# Epoch: 71, Train loss: 0.525, Test mae: 0.58, Test rmse: 0.737, Test r2: 0.213, Test sp: 0.633
# Epoch: 72, Train loss: 0.518, Test mae: 0.537, Test rmse: 0.686, Test r2: 0.318, Test sp: 0.623
# Epoch: 73, Train loss: 0.529, Test mae: 0.531, Test rmse: 0.679, Test r2: 0.332, Test sp: 0.616
# Epoch: 74, Train loss: 0.504, Test mae: 0.566, Test rmse: 0.722, Test r2: 0.246, Test sp: 0.617
# Epoch: 75, Train loss: 0.516, Test mae: 0.554, Test rmse: 0.707, Test r2: 0.275, Test sp: 0.624
# Epoch: 76, Train loss: 0.515, Test mae: 0.529, Test rmse: 0.678, Test r2: 0.335, Test sp: 0.619
# Epoch: 77, Train loss: 0.507, Test mae: 0.529, Test rmse: 0.677, Test r2: 0.335, Test sp: 0.618
# Epoch: 78, Train loss: 0.497, Test mae: 0.603, Test rmse: 0.763, Test r2: 0.157, Test sp: 0.621
# Epoch: 79, Train loss: 0.501, Test mae: 0.522, Test rmse: 0.671, Test r2: 0.347, Test sp: 0.634
# Epoch: 80, Train loss: 0.484, Test mae: 0.539, Test rmse: 0.689, Test r2: 0.312, Test sp: 0.621
# Epoch: 81, Train loss: 0.506, Test mae: 0.54, Test rmse: 0.69, Test r2: 0.31, Test sp: 0.627
# Epoch: 82, Train loss: 0.496, Test mae: 0.552, Test rmse: 0.704, Test r2: 0.281, Test sp: 0.626
# Epoch: 83, Train loss: 0.521, Test mae: 0.572, Test rmse: 0.729, Test r2: 0.231, Test sp: 0.625
# Epoch: 84, Train loss: 0.492, Test mae: 0.544, Test rmse: 0.697, Test r2: 0.296, Test sp: 0.621
# Epoch: 85, Train loss: 0.482, Test mae: 0.545, Test rmse: 0.693, Test r2: 0.303, Test sp: 0.624
# Epoch: 86, Train loss: 0.483, Test mae: 0.522, Test rmse: 0.669, Test r2: 0.352, Test sp: 0.628
# Epoch: 87, Train loss: 0.477, Test mae: 0.542, Test rmse: 0.694, Test r2: 0.302, Test sp: 0.62
# Epoch: 88, Train loss: 0.498, Test mae: 0.532, Test rmse: 0.68, Test r2: 0.33, Test sp: 0.626
# Epoch: 89, Train loss: 0.494, Test mae: 0.598, Test rmse: 0.756, Test r2: 0.172, Test sp: 0.628
# Epoch: 90, Train loss: 0.487, Test mae: 0.532, Test rmse: 0.68, Test r2: 0.33, Test sp: 0.63
# Epoch: 91, Train loss: 0.488, Test mae: 0.53, Test rmse: 0.678, Test r2: 0.334, Test sp: 0.627
# Epoch: 92, Train loss: 0.467, Test mae: 0.521, Test rmse: 0.667, Test r2: 0.356, Test sp: 0.626
# Epoch: 93, Train loss: 0.476, Test mae: 0.541, Test rmse: 0.693, Test r2: 0.305, Test sp: 0.629
# Epoch: 94, Train loss: 0.453, Test mae: 0.613, Test rmse: 0.772, Test r2: 0.136, Test sp: 0.631
# Epoch: 95, Train loss: 0.478, Test mae: 0.563, Test rmse: 0.716, Test r2: 0.257, Test sp: 0.626
# Epoch: 96, Train loss: 0.496, Test mae: 0.526, Test rmse: 0.672, Test r2: 0.346, Test sp: 0.629
# Epoch: 97, Train loss: 0.471, Test mae: 0.524, Test rmse: 0.67, Test r2: 0.35, Test sp: 0.631
# Epoch: 98, Train loss: 0.457, Test mae: 0.553, Test rmse: 0.704, Test r2: 0.281, Test sp: 0.632
# Epoch: 99, Train loss: 0.494, Test mae: 0.523, Test rmse: 0.669, Test r2: 0.351, Test sp: 0.63

# %%
MAE, RMSE, R2, Sp = eval_model(df_test, best_model_path)

# %%
print(MAE, RMSE, R2, Sp)
# Out:
# 0.520765491350647 0.6676431019650381 0.35558490293426426 0.6300803196696144
