# %%
# !pip install datamol
# !pip install rdkit-pypi
# !pip install pandas
# Out:
# Collecting datamol
#   Downloading datamol-0.11.3-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.7/381.7 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from datamol) (4.66.1)
# Collecting loguru (from datamol)
#   Downloading loguru-0.7.1-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from datamol) (1.3.2)
# Requirement already satisfied: fsspec>=2021.9 in /usr/local/lib/python3.10/dist-packages (from datamol) (2023.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datamol) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from datamol) (3.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from datamol) (9.4.0)
# Collecting selfies (from datamol)
#   Downloading selfies-2.1.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from datamol) (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from datamol) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datamol) (23.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from datamol) (4.5.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from datamol) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datamol) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->datamol) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->datamol) (1.16.0)
# Installing collected packages: selfies, loguru, datamol
# Successfully installed datamol-0.11.3 loguru-0.7.1 selfies-2.1.1
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 53.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (9.4.0)
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import os
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import Linear
from torch.utils.data import DataLoader
import tqdm
from scipy.stats import spearmanr

# %%
def ecfp_from_smiles(smiles,
                     R = 2,
                     L = 2**11,
                     use_features = True,
                     use_chirality = False):
    """
    Inputs:

    - smiles ... SMILES string of input compound
    - R ... maximum radius of circular substructures
    - L ... fingerprint-length
    - use_features ... if false then use standard DAYLIGHT atom features, if true then use pharmacophoric atom features
    - use_chirality ... if true then append tetrahedral chirality flags to atom features

    Outputs:
    - np.array(feature_list) ... ECFP with length L and maximum radius R
    """

    molecule = Chem.MolFromSmiles(smiles)
    if not molecule:
        return np.nan
    feature_list = AllChem.GetMorganFingerprintAsBitVect(molecule,
                                                         radius = R,
                                                         nBits = L,
                                                         useFeatures = use_features,
                                                         useChirality = use_chirality)
    return np.array(feature_list)

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Project/ALVS")
# Out:
# Mounted at /content/drive

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, fps, scores):
        self.fps = fps
        self.scores = scores
        self.dataLen = len(scores)

    def __getitem__(self, index):
        fp = np.array(self.fps[index])
        score = np.array(self.scores[index]).reshape(1,)
        return fp, score

    def __len__(self):
        return self.dataLen

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.fc1 = Linear(2048, 1024)
        self.dropout1 = nn.Dropout(p=0.5)
        self.fc2 = Linear(1024, 516)
        self.dropout2 = nn.Dropout(p=0.5)
        self.fc3 = Linear(516, 256)
        self.dropout3 = nn.Dropout(p=0.5)
        self.fc4 = Linear(256, 128)
        self.dropout4 = nn.Dropout(p=0.5)
        self.fc5 = Linear(128, 1)


    def forward(self, data):
        x = F.relu(self.fc1(data))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = F.relu(self.fc3(x))
        x = self.dropout3(x)
        x = F.relu(self.fc4(x))
        x = self.dropout4(x)
        x = self.fc5(x)
        return x

# %%
def train_epoch(loader, model, optimizer, device):
    model.train()

    loss_all = 0
    i = 0
    for fps, scores in loader:
        fps = fps.float().to(device)
        scores = scores.float().to(device)

        optimizer.zero_grad()
        output = model(fps)
        loss = F.mse_loss(output, scores)
        loss.backward()

        loss_all += loss.item()
        optimizer.step()
        i += 1
    return loss_all / i

# %%
def test_epoch(loader, model,  device):
    model.eval()

    MSE, MAE = 0, 0
    trues, preds = [], []
    with torch.no_grad():
        for fps, scores in loader:
            fps = fps.float().to(device)
            scores = scores.float().to(device)

            output = model(fps)
            pred = output.cpu().squeeze().numpy().tolist()
            true = scores.cpu().squeeze().numpy().tolist()

            trues.extend(true)
            preds.extend(pred)
    MAE = mean_absolute_error(trues, preds)
    RMSE = np.sqrt(mean_squared_error(trues, preds))
    R2 = r2_score(trues, preds)
    Sp = spearmanr(trues, preds)[0]
    return MAE, RMSE, R2, Sp

# %%
def init_model(device, lr=0.0001):
    model = DNN()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    return model, optimizer

# %%
def prepare_dataloader(dff, batch_size, test_size=0.8):
    train_fps, valid_fps, train_scores, valid_scores = train_test_split(
                                                                        dff["ecfp"],
                                                                        dff["score"],
                                                                        test_size=test_size)
    train_dataset = Dataset(fps=list(train_fps),
                            scores = list(train_scores))
    valid_dataset = Dataset(fps=list(valid_fps),
                            scores = list(valid_scores))
    train_loader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=True)
    valid_loader = DataLoader(valid_dataset,
                              batch_size=batch_size,
                              shuffle=False)
    return train_loader, valid_loader

# %%
def train_step(dff, epochs, batch_size, step_time, device="cuda"):
    model, optimizer = init_model(device=device)
    train_loader, valid_loader = prepare_dataloader(dff,  batch_size=batch_size)

    model_folder = "models/ada17/ecfp/models_dropout/{}".format(step_time)
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)

    hist = {"train-loss":[], "test-mae":[], "test-rmse":[], "test-r2":[], "test-sp":[]}
    for epoch in range(epochs):
        train_loss = train_epoch(train_loader, model, optimizer, device)
        test_mae, test_rmse, test_r2, test_sp = test_epoch(valid_loader, model, device)
        hist["train-loss"].append(train_loss)
        hist["test-mae"].append(test_mae)
        hist["test-rmse"].append(test_rmse)
        hist["test-r2"].append(test_r2)
        hist["test-sp"].append(test_sp)

        if test_rmse <= min(hist["test-rmse"]):
            weight_path = os.path.join(model_folder, "weight_{}.pth".format(epoch))
            torch.save(model.state_dict(), weight_path)

        # print(f'Epoch: {epoch}, Train loss: {train_loss:.3}, Test mae: {test_mae:.3}, Test rmse: {test_rmse:.3}, Test r2: {test_r2:.3}')
    print("---------------------------------\nvalidation min rmse: {}\n---------------------------------\n".format(min(hist["test-rmse"])))
    return weight_path

# %%
def random_select(df, n_samples):
    df_select = df.sample(n=n_samples).copy()
    sample_indexs = df_select["name"].tolist()
    df_remaining = df[~df["name"].isin(sample_indexs)].copy()
    return df_select, df_remaining

# %%
def enable_dropout(model):
    """ Function to enable the dropout layers during test-time """
    for m in model.modules():
        if m.__class__.__name__.startswith('Dropout'):
            m.train()

# %%
def load_model(best_model_path, device="cuda", enable_dp=True):
    model= DNN().to(device)
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()
    if enable_dp:
        enable_dropout(model)
    return model

# %%
def predict_with_uncertainty(fpnp, model, device, times=5):
    fpnp = fpnp.reshape(1, 2048)
    fp = torch.from_numpy(fpnp).float().to(device)
    dropout_predictions = []
    with torch.no_grad():
        for _ in range(times):
            output = model(fp)
            pred = output.cpu().numpy()[0][0]
            dropout_predictions.append(pred)
    mean = np.mean(dropout_predictions)
    variance = np.var(dropout_predictions)
    return [mean, variance]

# %%
def uncertainty_select(dff, best_model_path, n_samples):
    model = load_model(best_model_path, enable_dp=True)
    dff["mean_var"] = dff["ecfp"].map(lambda x: predict_with_uncertainty(x,  model, device="cuda"))
    dff["mean"] = dff["mean_var"].map(lambda x: x[0])
    dff["var"] = dff["mean_var"].map(lambda x: x[1])
    dff_sort = dff.sort_values(by="var", ascending=False)
    dff_select = dff_sort.iloc[:n_samples, :4].copy()
    sample_indexs = dff_select["name"].tolist()
    dff_remaining = dff_sort[~dff_sort["name"].isin(sample_indexs)].copy()
    return dff_select, dff_remaining

# %%
def predict(fpnp, model, device):
    fpnp = fpnp.reshape(1, 2048)
    fp = torch.from_numpy(fpnp).float().to(device)
    with torch.no_grad():
        output = model(fp)
        pred = output.cpu().numpy()[0][0]
    return pred

# %%
def eval_model(dff, best_model_path):
    model = load_model(best_model_path, enable_dp=False)
    dff["pred"] = dff["ecfp"].map(lambda x: predict(x,  model, device="cuda"))
    MAE = mean_absolute_error(dff["score"], dff["pred"])
    RMSE = np.sqrt(mean_squared_error(dff["score"], dff["pred"]))
    R2 = r2_score(dff["score"], dff["pred"])
    Sp = spearmanr(dff["score"], dff["pred"])[0]
    return MAE, RMSE, R2, Sp

# %%
def run_step(dfs, epochs, stime):
    dfs_new = dfs.copy()

    best_model_path = train_step(dfs_new, epochs, batch_size=32, step_time=stime)
    return best_model_path

# %%
def run_iterations(df, df_test, epochs=200, iterations=100, n_samples=100):
    results = {"RMSE": [], "R2": [], "Sp": []}

    print("len(df):", len(df))

    df["ecfp"] = df["smiles"].map(lambda x: ecfp_from_smiles(x))
    df = df[~df["ecfp"].isna()]

    for stime in range(iterations):
        if stime < 1:
            dfs, dfr = random_select(df, n_samples)
        else:
            df_temp = dfs.copy()
            dfs, dfr = uncertainty_select(dfr, best_model_path, n_samples)
            dfs = pd.concat([dfs, df_temp], axis=0)
            dfs = dfs.reset_index(drop=True)
        print("number of mol pool:", len(dfs))
        best_model_path = run_step(dfs, epochs, stime)
        MAE, RMSE, R2, Sp = eval_model(df_test, best_model_path)
        print("MAE:{}, RMSE:{}, R2:{}, Sp:{}, step:{}".format(MAE, RMSE, R2, Sp, stime))

        results["RMSE"].append(RMSE)
        results["R2"].append(R2)
        results["Sp"].append(Sp)

    # Convert results dictionary to DataFrame
    results_df = pd.DataFrame(results)

    results_df.to_csv('ecfp_dropout_results.csv', index=False)

# %%
df = pd.read_csv("preprocess_data/ada17/ada17_train.csv", sep="\t")
df_test = pd.read_csv("preprocess_data/ada17/ada17_test.csv", sep="\t")
df_test["ecfp"] = df_test["smiles"].map(lambda x: ecfp_from_smiles(x))
df_test = df_test[~df_test["ecfp"].isna()]
# Out:
# [15:16:20] SMILES Parse Error: syntax error while parsing: error
# [15:16:20] SMILES Parse Error: Failed parsing SMILES 'error' for input: 'error'
# [15:16:31] SMILES Parse Error: syntax error while parsing: error
# [15:16:31] SMILES Parse Error: Failed parsing SMILES 'error' for input: 'error'

# %%
run_iterations(df, df_test)
# Out:
# len(df): 20479
# number of mol pool: 100
# ---------------------------------
# validation min rmse: 1.647109746390057
# ---------------------------------
#
# MAE:1.3243657625992817, RMSE:1.6487063129433233, R2:-1.9073722093774568, Sp:0.16105646234335527, step:0
# number of mol pool: 200
# ---------------------------------
# validation min rmse: 1.457157880246205
# ---------------------------------
#
# MAE:1.2389659972546425, RMSE:1.5368126760543714, R2:-1.5261311906500237, Sp:0.1477070830798824, step:1
# number of mol pool: 300
# ---------------------------------
# validation min rmse: 1.3953566538291533
# ---------------------------------
#
# MAE:1.2707365483478708, RMSE:1.5732199732890035, R2:-1.6472376816541714, Sp:0.18637943617342356, step:2
# number of mol pool: 400
# ---------------------------------
# validation min rmse: 1.2677861808405888
# ---------------------------------
#
# MAE:1.3264957701483913, RMSE:1.6263336857552388, R2:-1.8290026098856136, Sp:0.2870192174826458, step:3
# number of mol pool: 500
# ---------------------------------
# validation min rmse: 1.2045616196185784
# ---------------------------------
#
# MAE:1.2822236087840857, RMSE:1.585975312286369, R2:-1.690338201770107, Sp:0.27293112338045594, step:4
# number of mol pool: 600
# ---------------------------------
# validation min rmse: 1.12540617457835
# ---------------------------------
#
# MAE:1.1682771500271696, RMSE:1.459213488643142, R2:-1.2774649616210443, Sp:0.32637207706623333, step:5
# number of mol pool: 700
# ---------------------------------
# validation min rmse: 1.136238924369426
# ---------------------------------
#
# MAE:1.2058812720304783, RMSE:1.506285860114503, R2:-1.4267711967029326, Sp:0.3227558653728753, step:6
# number of mol pool: 800
# ---------------------------------
# validation min rmse: 1.0617289108036951
# ---------------------------------
#
# MAE:1.128667968752658, RMSE:1.425374929476567, R2:-1.1730627373773173, Sp:0.37391810127212904, step:7
# number of mol pool: 900
# ---------------------------------
# validation min rmse: 1.0332627414122872
# ---------------------------------
#
# MAE:1.0802206693414667, RMSE:1.358342033500695, R2:-0.9734781082645412, Sp:0.32476873276840973, step:8
# number of mol pool: 1000
# ---------------------------------
# validation min rmse: 0.9961017474050345
# ---------------------------------
#
# MAE:1.033692848548803, RMSE:1.3056826030269584, R2:-0.8234307244105736, Sp:0.3619895367656782, step:9
# number of mol pool: 1100
# ---------------------------------
# validation min rmse: 0.9907409489621403
# ---------------------------------
#
# MAE:1.0096702223363965, RMSE:1.2954348955953643, R2:-0.7949204943504118, Sp:0.3703731061485682, step:10
# number of mol pool: 1200
# ---------------------------------
# validation min rmse: 0.9970415257519863
# ---------------------------------
#
# MAE:1.0569795673355245, RMSE:1.3350296982838887, R2:-0.9063203624872871, Sp:0.373672603437246, step:11
# number of mol pool: 1300
# ---------------------------------
# validation min rmse: 0.935643683035871
# ---------------------------------
#
# MAE:0.9360435841580543, RMSE:1.1902327081839295, R2:-0.515227328231731, Sp:0.4330926685065203, step:12
# number of mol pool: 1400
# ---------------------------------
# validation min rmse: 0.9275453124823777
# ---------------------------------
#
# MAE:0.9672775066687729, RMSE:1.236780345739733, R2:-0.6360598361098906, Sp:0.42209014000518047, step:13
# number of mol pool: 1500
# ---------------------------------
# validation min rmse: 0.9381306763414892
# ---------------------------------
#
# MAE:0.9525081427305865, RMSE:1.2061216670156802, R2:-0.5559522740560832, Sp:0.4309281385136542, step:14
# number of mol pool: 1600
# ---------------------------------
# validation min rmse: 0.9366413526985907
# ---------------------------------
#
# MAE:0.9653243356152772, RMSE:1.2371102049281704, R2:-0.6369326529179797, Sp:0.43356729720114334, step:15
# number of mol pool: 1700
# ---------------------------------
# validation min rmse: 0.9530994143074926
# ---------------------------------
#
# MAE:1.0010570325283268, RMSE:1.2732540480013483, R2:-0.7339803207213331, Sp:0.45704574834971906, step:16
# number of mol pool: 1800
# ---------------------------------
# validation min rmse: 0.9617165855363623
# ---------------------------------
#
# MAE:0.9159938549473411, RMSE:1.164745963121337, R2:-0.45103023176160995, Sp:0.42073079920765905, step:17
# number of mol pool: 1900
# ---------------------------------
# validation min rmse: 0.94786282569446
# ---------------------------------
#
# MAE:0.9527466193652769, RMSE:1.210610995827683, R2:-0.5675567106644779, Sp:0.4545877044187226, step:18
# number of mol pool: 2000
# ---------------------------------
# validation min rmse: 0.9185070063275206
# ---------------------------------
#
# MAE:0.9037690709452242, RMSE:1.1635876362021327, R2:-0.4481455999552282, Sp:0.4668744325689194, step:19
# number of mol pool: 2100
# ---------------------------------
# validation min rmse: 0.9119017282338013
# ---------------------------------
#
# MAE:0.8732736889017972, RMSE:1.1206681319696261, R2:-0.3432847291090906, Sp:0.4620103340748376, step:20
# number of mol pool: 2200
# ---------------------------------
# validation min rmse: 0.9001975887831273
# ---------------------------------
#
# MAE:0.8769100699554115, RMSE:1.1228362480526164, R2:-0.34848736563781135, Sp:0.4829427111671702, step:21
# number of mol pool: 2300
# ---------------------------------
# validation min rmse: 0.9013538600180855
# ---------------------------------
#
# MAE:0.8669317935498705, RMSE:1.1069360389912888, R2:-0.3105665752163931, Sp:0.44353479437435345, step:22
# number of mol pool: 2400
# ---------------------------------
# validation min rmse: 0.8946499320831406
# ---------------------------------
#
# MAE:0.8828106357560718, RMSE:1.1332412596041626, R2:-0.3735952786638128, Sp:0.44415546840262243, step:23
# number of mol pool: 2500
# ---------------------------------
# validation min rmse: 0.9000920460492235
# ---------------------------------
#
# MAE:0.8833051178538137, RMSE:1.1332471011553986, R2:-0.3736094397223002, Sp:0.49748097969536437, step:24
# number of mol pool: 2600
# ---------------------------------
# validation min rmse: 0.8882933952777484
# ---------------------------------
#
# MAE:0.8679365638113549, RMSE:1.1071482417666603, R2:-0.31106910203206084, Sp:0.4515799461024433, step:25
# number of mol pool: 2700
# ---------------------------------
# validation min rmse: 0.8912894858881312
# ---------------------------------
#
# MAE:0.8418317735253265, RMSE:1.0833792788272876, R2:-0.25537964540818114, Sp:0.4834072507404298, step:26
# number of mol pool: 2800
# ---------------------------------
# validation min rmse: 0.8874872650052957
# ---------------------------------
#
# MAE:0.8570775585869742, RMSE:1.10064405584105, R2:-0.2957100223221749, Sp:0.5127138660858933, step:27
# number of mol pool: 2900
# ---------------------------------
# validation min rmse: 0.8816568361022181
# ---------------------------------
#
# MAE:0.8966399870456473, RMSE:1.1495189297086912, R2:-0.4133388203111106, Sp:0.4944108067082903, step:28
# number of mol pool: 3000
# ---------------------------------
# validation min rmse: 0.88597209457862
# ---------------------------------
#
# MAE:0.820907221892703, RMSE:1.0535009161214186, R2:-0.18709060625662177, Sp:0.49891730190046857, step:29
# number of mol pool: 3100
# ---------------------------------
# validation min rmse: 0.8794718791514019
# ---------------------------------
#
# MAE:0.8043137158902456, RMSE:1.044602624078941, R2:-0.16712200683719436, Sp:0.502828644314134, step:30
# number of mol pool: 3200
# ---------------------------------
# validation min rmse: 0.8881788660019057
# ---------------------------------
#
# MAE:0.8283529204386149, RMSE:1.067321243599008, R2:-0.2184405394414417, Sp:0.4966365187223005, step:31
# number of mol pool: 3300
# ---------------------------------
# validation min rmse: 0.8698923992640716
# ---------------------------------
#
# MAE:0.8463188439702024, RMSE:1.0810451432969683, R2:-0.24997605367938913, Sp:0.49479423706562214, step:32
# number of mol pool: 3400
# ---------------------------------
# validation min rmse: 0.8675022429715069
# ---------------------------------
#
# MAE:0.7917776736559782, RMSE:1.0171148151963276, R2:-0.10650656150877413, Sp:0.5225558999226085, step:33
# number of mol pool: 3500
# ---------------------------------
# validation min rmse: 0.8609284207097041
# ---------------------------------
#
# MAE:0.7915152702192061, RMSE:1.0176240788497095, R2:-0.10761488209778758, Sp:0.5525835234379477, step:34
# number of mol pool: 3600
# ---------------------------------
# validation min rmse: 0.8518611057395338
# ---------------------------------
#
# MAE:0.7603038611505459, RMSE:0.9790995406210208, R2:-0.02533959050125323, Sp:0.5337694241650883, step:35
# number of mol pool: 3700
# ---------------------------------
# validation min rmse: 0.8613877785733832
# ---------------------------------
#
# MAE:0.7978730453070956, RMSE:1.0226942530680874, R2:-0.11867945990958573, Sp:0.5079621598635725, step:36
# number of mol pool: 3800
# ---------------------------------
# validation min rmse: 0.8286652602835908
# ---------------------------------
#
# MAE:0.7563979271589789, RMSE:0.973181929741438, R2:-0.012982880068103109, Sp:0.5426237614340476, step:37
# number of mol pool: 3900
# ---------------------------------
# validation min rmse: 0.8336759955495069
# ---------------------------------
#
# MAE:0.7840088588966106, RMSE:1.0086262157022838, R2:-0.08811434794474615, Sp:0.541735144337836, step:38
# number of mol pool: 4000
# ---------------------------------
# validation min rmse: 0.8415914399196526
# ---------------------------------
#
# MAE:0.7646125188053033, RMSE:0.9852399132367098, R2:-0.03824064764403845, Sp:0.5445601344146559, step:39
# number of mol pool: 4100
# ---------------------------------
# validation min rmse: 0.8425792987159837
# ---------------------------------
#
# MAE:0.7736783654603661, RMSE:0.9965184102458701, R2:-0.06214714512832464, Sp:0.5181630777535814, step:40
# number of mol pool: 4200
# ---------------------------------
# validation min rmse: 0.8278899864737118
# ---------------------------------
#
# MAE:0.7490686534088138, RMSE:0.9629267111224099, R2:0.008253900484580745, Sp:0.5544263040063306, step:41
# number of mol pool: 4300
# ---------------------------------
# validation min rmse: 0.8200521757897831
# ---------------------------------
#
# MAE:0.7382465151198427, RMSE:0.9491255459868426, R2:0.03647861403607755, Sp:0.5522399525808126, step:42
# number of mol pool: 4400
# ---------------------------------
# validation min rmse: 0.8411808904002754
# ---------------------------------
#
# MAE:0.7441966928365712, RMSE:0.9517028417017087, R2:0.03123873581138925, Sp:0.5476737976496725, step:43
# number of mol pool: 4500
# ---------------------------------
# validation min rmse: 0.8260370410153415
# ---------------------------------
#
# MAE:0.7468021011161993, RMSE:0.9585352216398486, R2:0.017279117736614835, Sp:0.5356237535997019, step:44
# number of mol pool: 4600
# ---------------------------------
# validation min rmse: 0.8080858613683473
# ---------------------------------
#
# MAE:0.6929944514894746, RMSE:0.8932502339444662, R2:0.146584924541718, Sp:0.5581147419708077, step:45
# number of mol pool: 4700
# ---------------------------------
# validation min rmse: 0.8439040099019421
# ---------------------------------
#
# MAE:0.759909895296544, RMSE:0.9890595092016081, R2:-0.04630639245573143, Sp:0.5424159640499681, step:46
# number of mol pool: 4800
# ---------------------------------
# validation min rmse: 0.8330107338217482
# ---------------------------------
#
# MAE:0.7402442007363993, RMSE:0.9566810604837971, R2:0.02107733092002706, Sp:0.5692160095290831, step:47
# number of mol pool: 4900
# ---------------------------------
# validation min rmse: 0.8074281402514942
# ---------------------------------
#
# MAE:0.729553177063155, RMSE:0.9427410073658812, R2:0.04939776731174661, Sp:0.5673095451662279, step:48
# number of mol pool: 5000
# ---------------------------------
# validation min rmse: 0.8223931485464709
# ---------------------------------
#
# MAE:0.7465933236089526, RMSE:0.9639291557533413, R2:0.0061879321682646315, Sp:0.5523002040562278, step:49
# number of mol pool: 5100
# ---------------------------------
# validation min rmse: 0.8153944640752508
# ---------------------------------
#
# MAE:0.6924728174855904, RMSE:0.8964239678419085, R2:0.14050975333742144, Sp:0.5610281498121872, step:50
# number of mol pool: 5200
# ---------------------------------
# validation min rmse: 0.8253811853396325
# ---------------------------------
#
# MAE:0.7371951541109757, RMSE:0.9520197652053752, R2:0.03059342023384881, Sp:0.5402942677456477, step:51
# number of mol pool: 5300
# ---------------------------------
# validation min rmse: 0.8079864205824413
# ---------------------------------
#
# MAE:0.7297735056883335, RMSE:0.9389597995856849, R2:0.05700795113232804, Sp:0.5397417309168493, step:52
# number of mol pool: 5400
# ---------------------------------
# validation min rmse: 0.8020738983184038
# ---------------------------------
#
# MAE:0.7068195051016939, RMSE:0.9097972892457892, R2:0.11467381350723538, Sp:0.5602311572125249, step:53
# number of mol pool: 5500
# ---------------------------------
# validation min rmse: 0.8071565550579721
# ---------------------------------
#
# MAE:0.69417131619349, RMSE:0.8965811690628758, R2:0.14020827821391313, Sp:0.5667110608598553, step:54
# number of mol pool: 5600
# ---------------------------------
# validation min rmse: 0.8112127972117874
# ---------------------------------
#
# MAE:0.7229898880792409, RMSE:0.937772802259733, R2:0.05939063361619501, Sp:0.5846661935340521, step:55
# number of mol pool: 5700
# ---------------------------------
# validation min rmse: 0.7964607371375929
# ---------------------------------
#
# MAE:0.699108572495199, RMSE:0.8966035200904634, R2:0.14016540988544246, Sp:0.5555756852194724, step:56
# number of mol pool: 5800
# ---------------------------------
# validation min rmse: 0.7940676413758295
# ---------------------------------
#
# MAE:0.7016451592184335, RMSE:0.9059159327830874, R2:0.12221161713695239, Sp:0.567503482620222, step:57
# number of mol pool: 5900
# ---------------------------------
# validation min rmse: 0.8130663386782813
# ---------------------------------
#
# MAE:0.7010209084614086, RMSE:0.9084668674618677, R2:0.11726119434834581, Sp:0.5759788734283664, step:58
# number of mol pool: 6000
# ---------------------------------
# validation min rmse: 0.79702245780053
# ---------------------------------
#
# MAE:0.6941740274783095, RMSE:0.8948467952282295, R2:0.14353147527711785, Sp:0.5624321613007249, step:59
# number of mol pool: 6100
# ---------------------------------
# validation min rmse: 0.7787782423798334
# ---------------------------------
#
# MAE:0.670609489989338, RMSE:0.8716772668983591, R2:0.18730895779947887, Sp:0.5727340419795958, step:60
# number of mol pool: 6200
# ---------------------------------
# validation min rmse: 0.7924088509649007
# ---------------------------------
#
# MAE:0.6731497300288879, RMSE:0.8682667657627084, R2:0.19365594336316194, Sp:0.573001201904291, step:61
# number of mol pool: 6300
# ---------------------------------
# validation min rmse: 0.7892798529187073
# ---------------------------------
#
# MAE:0.6771885235670028, RMSE:0.8707629176866293, R2:0.18901301436243234, Sp:0.5851837599336622, step:62
# number of mol pool: 6400
# ---------------------------------
# validation min rmse: 0.7649972495920963
# ---------------------------------
#
# MAE:0.6563611917836014, RMSE:0.8447629600693056, R2:0.23672021641542795, Sp:0.6020216327736838, step:63
# number of mol pool: 6500
# ---------------------------------
# validation min rmse: 0.7792161428663326
# ---------------------------------
#
# MAE:0.6714064523808347, RMSE:0.8769495750988185, R2:0.1774481620446291, Sp:0.5965827747664719, step:64
# number of mol pool: 6600
# ---------------------------------
# validation min rmse: 0.7806852159368036
# ---------------------------------
#
# MAE:0.6688703967040687, RMSE:0.862109150559809, R2:0.2050523264835422, Sp:0.5907302918918713, step:65
# number of mol pool: 6700
# ---------------------------------
# validation min rmse: 0.7754511304812337
# ---------------------------------
#
# MAE:0.6619560734299664, RMSE:0.8531390878940822, R2:0.2215087892752141, Sp:0.5716615762870136, step:66
# number of mol pool: 6800
# ---------------------------------
# validation min rmse: 0.7615646345544139
# ---------------------------------
#
# MAE:0.6530435138876569, RMSE:0.8374656855320382, R2:0.2498500657529953, Sp:0.604918254251538, step:67
# number of mol pool: 6900
# ---------------------------------
# validation min rmse: 0.78145893628187
# ---------------------------------
#
# MAE:0.6787781547827928, RMSE:0.875548765494376, R2:0.1800738962351155, Sp:0.58712880377597, step:68
# number of mol pool: 7000
# ---------------------------------
# validation min rmse: 0.7605313282747005
# ---------------------------------
#
# MAE:0.6514736689339817, RMSE:0.8371396722098594, R2:0.25043399718994364, Sp:0.5978142004932162, step:69
# number of mol pool: 7100
# ---------------------------------
# validation min rmse: 0.7524889836041582
# ---------------------------------
#
# MAE:0.6344100250226996, RMSE:0.8209195633626857, R2:0.27919922642967054, Sp:0.5955090713186874, step:70
# number of mol pool: 7200
# ---------------------------------
# validation min rmse: 0.7549699084314804
# ---------------------------------
#
# MAE:0.6514233194769891, RMSE:0.8359291238196089, R2:0.2526002542294645, Sp:0.602183263529405, step:71
# number of mol pool: 7300
# ---------------------------------
# validation min rmse: 0.7654328961755033
# ---------------------------------
#
# MAE:0.6331359378431635, RMSE:0.8224091811229532, R2:0.27658096307980107, Sp:0.6084693006166088, step:72
# number of mol pool: 7400
# ---------------------------------
# validation min rmse: 0.7715605705344086
# ---------------------------------
#
# MAE:0.654082377557595, RMSE:0.8416702707462747, R2:0.24229874264509077, Sp:0.588726195359337, step:73
# number of mol pool: 7500
# ---------------------------------
# validation min rmse: 0.7598812949695973
# ---------------------------------
#
# MAE:0.6473638628703574, RMSE:0.8361123009412039, R2:0.25227266297711626, Sp:0.6090082400481259, step:74
# number of mol pool: 7600
# ---------------------------------
# validation min rmse: 0.7385403960970641
# ---------------------------------
#
# MAE:0.6246305617154367, RMSE:0.804052773281222, R2:0.3085143983168809, Sp:0.618527783316254, step:75
# number of mol pool: 7700
# ---------------------------------
# validation min rmse: 0.7585456824521718
# ---------------------------------
#
# MAE:0.6456611610764216, RMSE:0.8327713655644606, R2:0.25823625839709663, Sp:0.6128971715317869, step:76
# number of mol pool: 7800
# ---------------------------------
# validation min rmse: 0.744818342940876
# ---------------------------------
#
# MAE:0.6140631693178157, RMSE:0.791817041779266, R2:0.32939973264962796, Sp:0.6036431113730149, step:77
# number of mol pool: 7900
# ---------------------------------
# validation min rmse: 0.7293382816895516
# ---------------------------------
#
# MAE:0.6143012936229226, RMSE:0.7913743090742801, R2:0.3301494353005985, Sp:0.6300420642309673, step:78
# number of mol pool: 8000
# ---------------------------------
# validation min rmse: 0.7324373228330497
# ---------------------------------
#
# MAE:0.6038681741141607, RMSE:0.780024630158025, R2:0.34922529256740675, Sp:0.6176000180989237, step:79
# number of mol pool: 8100
# ---------------------------------
# validation min rmse: 0.7401950497378216
# ---------------------------------
#
# MAE:0.6258765774329623, RMSE:0.8077813570820092, R2:0.3020863624823199, Sp:0.6151185532693936, step:80
# number of mol pool: 8200
# ---------------------------------
# validation min rmse: 0.7399644396975412
# ---------------------------------
#
# MAE:0.6085072551841609, RMSE:0.7903761736521238, R2:0.3318380924265386, Sp:0.6183319395627082, step:81
# number of mol pool: 8300
# ---------------------------------
# validation min rmse: 0.7348284718683071
# ---------------------------------
#
# MAE:0.6072609381136372, RMSE:0.7883212157054486, R2:0.3353079836676989, Sp:0.6163724607227671, step:82
# number of mol pool: 8400
# ---------------------------------
# validation min rmse: 0.7327187024052263
# ---------------------------------
#
# MAE:0.6170077942954372, RMSE:0.7941200603178866, R2:0.32549314631701687, Sp:0.6215526181934757, step:83
# number of mol pool: 8500
# ---------------------------------
# validation min rmse: 0.7374389439965915
# ---------------------------------
#
# MAE:0.6255407426063406, RMSE:0.8015429199882084, R2:0.31282460964842884, Sp:0.6164787966377117, step:84
# number of mol pool: 8600
# ---------------------------------
# validation min rmse: 0.7469492640684033
# ---------------------------------
#
# MAE:0.61848701589205, RMSE:0.794568539233122, R2:0.32473107635773524, Sp:0.6284976102806421, step:85
# number of mol pool: 8700
# ---------------------------------
# validation min rmse: 0.7325995872121279
# ---------------------------------
#
# MAE:0.6060620908981915, RMSE:0.7784665549710259, R2:0.35182250094247947, Sp:0.6152894246064352, step:86
# number of mol pool: 8800
# ---------------------------------
# validation min rmse: 0.742692231790945
# ---------------------------------
#
# MAE:0.6167318772435444, RMSE:0.7957837831129227, R2:0.3226639319204988, Sp:0.6209591712855623, step:87
# number of mol pool: 8900
# ---------------------------------
# validation min rmse: 0.7383687264206674
# ---------------------------------
#
# MAE:0.6089103122892682, RMSE:0.7869873489584404, R2:0.3375554444034151, Sp:0.616364051532661, step:88
# number of mol pool: 9000
# ---------------------------------
# validation min rmse: 0.7406858187579615
# ---------------------------------
#
# MAE:0.6227312980539762, RMSE:0.8079064192460447, R2:0.30187024126170403, Sp:0.6223984091384842, step:89
# number of mol pool: 9100
# ---------------------------------
# validation min rmse: 0.7196625234748283
# ---------------------------------
#
# MAE:0.608387348571557, RMSE:0.7810678350323206, R2:0.3474834364895053, Sp:0.6258356816910601, step:90
# number of mol pool: 9200
# ---------------------------------
# validation min rmse: 0.7221084412633442
# ---------------------------------
#
# MAE:0.5932795336373984, RMSE:0.7627783886976628, R2:0.37768424929836564, Sp:0.6243765632159851, step:91
# number of mol pool: 9300
# ---------------------------------
# validation min rmse: 0.7365902170769892
# ---------------------------------
#
# MAE:0.6087940761135483, RMSE:0.7878895164881221, R2:0.3360357795173122, Sp:0.6245679473570948, step:92
# number of mol pool: 9400
# ---------------------------------
# validation min rmse: 0.7286898613132875
# ---------------------------------
#
# MAE:0.5906159031192584, RMSE:0.7659452901864775, R2:0.3725060640892629, Sp:0.6358735385929294, step:93
# number of mol pool: 9500
# ---------------------------------
# validation min rmse: 0.7346361415689463
# ---------------------------------
#
# MAE:0.5983445446784752, RMSE:0.7737156264801112, R2:0.3597099255368942, Sp:0.6387617527621745, step:94
# number of mol pool: 9600
# ---------------------------------
# validation min rmse: 0.749174039509207
# ---------------------------------
#
# MAE:0.6147182717856979, RMSE:0.7993741045809568, R2:0.3165382979189395, Sp:0.617881604184414, step:95
# number of mol pool: 9700
# ---------------------------------
# validation min rmse: 0.7181684399042654
# ---------------------------------
#
# MAE:0.6083617170773199, RMSE:0.7858788556625341, R2:0.33942027284847476, Sp:0.6291672271644061, step:96
# number of mol pool: 9800
# ---------------------------------
# validation min rmse: 0.7150148274098803
# ---------------------------------
#
# MAE:0.581620575174733, RMSE:0.7516353603856653, R2:0.39573360945491187, Sp:0.6416819289404809, step:97
# number of mol pool: 9900
# ---------------------------------
# validation min rmse: 0.7025929679650584
# ---------------------------------
#
# MAE:0.5750023773443615, RMSE:0.7394663630518006, R2:0.41514140021123525, Sp:0.6451972360195573, step:98
# number of mol pool: 10000
# ---------------------------------
# validation min rmse: 0.719421485488289
# ---------------------------------
#
# MAE:0.5974056267643587, RMSE:0.7699158624856713, R2:0.3659834888541824, Sp:0.6310263022459495, step:99
