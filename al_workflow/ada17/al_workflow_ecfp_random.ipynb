# %%
# !pip install datamol
# !pip install rdkit-pypi
# !pip install pandas
# Out:
# Collecting datamol
#   Downloading datamol-0.11.3-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.7/381.7 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from datamol) (4.66.1)
# Collecting loguru (from datamol)
#   Downloading loguru-0.7.1-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from datamol) (1.3.2)
# Requirement already satisfied: fsspec>=2021.9 in /usr/local/lib/python3.10/dist-packages (from datamol) (2023.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datamol) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from datamol) (3.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from datamol) (9.4.0)
# Collecting selfies (from datamol)
#   Downloading selfies-2.1.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from datamol) (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from datamol) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datamol) (23.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from datamol) (4.7.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from datamol) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datamol) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->datamol) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->datamol) (1.16.0)
# Installing collected packages: selfies, loguru, datamol
# Successfully installed datamol-0.11.3 loguru-0.7.1 selfies-2.1.1
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 58.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (9.4.0)
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import os
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import Linear
from torch.utils.data import DataLoader
import tqdm
from scipy.stats import spearmanr

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Project/ALVS")
# Out:
# Mounted at /content/drive

# %%
def ecfp_from_smiles(smiles,
                     R = 2,
                     L = 2**11,
                     use_features = True,
                     use_chirality = False):
    """
    Inputs:

    - smiles ... SMILES string of input compound
    - R ... maximum radius of circular substructures
    - L ... fingerprint-length
    - use_features ... if false then use standard DAYLIGHT atom features, if true then use pharmacophoric atom features
    - use_chirality ... if true then append tetrahedral chirality flags to atom features

    Outputs:
    - np.array(feature_list) ... ECFP with length L and maximum radius R
    """

    molecule = Chem.MolFromSmiles(smiles)
    if not molecule:
        return np.nan
    feature_list = AllChem.GetMorganFingerprintAsBitVect(molecule,
                                                         radius = R,
                                                         nBits = L,
                                                         useFeatures = use_features,
                                                         useChirality = use_chirality)
    return np.array(feature_list)

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, fps, scores):
        self.fps = fps
        self.scores = scores
        self.dataLen = len(scores)

    def __getitem__(self, index):
        fp = np.array(self.fps[index])
        score = np.array(self.scores[index]).reshape(1,)
        return fp, score

    def __len__(self):
        return self.dataLen

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.fc1 = Linear(2048, 1024)
        self.dropout1 = nn.Dropout(p=0.2)
        self.fc2 = Linear(1024, 516)
        self.dropout2 = nn.Dropout(p=0.2)
        self.fc3 = Linear(516, 256)
        self.dropout3 = nn.Dropout(p=0.2)
        self.fc4 = Linear(256, 128)
        self.dropout4 = nn.Dropout(p=0.2)
        self.fc5 = Linear(128, 1)


    def forward(self, data):
        x = F.relu(self.fc1(data))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = F.relu(self.fc3(x))
        x = self.dropout3(x)
        x = F.relu(self.fc4(x))
        x = self.dropout4(x)
        x = self.fc5(x)
        return x

# %%
def train_epoch(loader, model, optimizer, device):
    model.train()

    loss_all = 0
    i = 0
    for fps, scores in loader:
        fps = fps.float().to(device)
        scores = scores.float().to(device)

        optimizer.zero_grad()
        output = model(fps)
        loss = F.mse_loss(output, scores)
        loss.backward()

        loss_all += loss.item()
        optimizer.step()
        i += 1
    return loss_all / i

# %%
def test_epoch(loader, model,  device):
    model.eval()

    MSE, MAE = 0, 0
    trues, preds = [], []
    with torch.no_grad():
        for fps, scores in loader:
            fps = fps.float().to(device)
            scores = scores.float().to(device)

            output = model(fps)
            pred = output.cpu().squeeze().numpy().tolist()
            true = scores.cpu().squeeze().numpy().tolist()

            trues.extend(true)
            preds.extend(pred)
    MAE = mean_absolute_error(trues, preds)
    RMSE = np.sqrt(mean_squared_error(trues, preds))
    R2 = r2_score(trues, preds)
    Sp = spearmanr(trues, preds)[0]
    return MAE, RMSE, R2, Sp

# %%
def init_model(device, lr=0.0001):
    model = DNN()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    return model, optimizer

# %%
def prepare_dataloader(dff, batch_size, test_size=0.8):
    train_fps, valid_fps, train_scores, valid_scores = train_test_split(
                                                                        dff["ecfp"],
                                                                        dff["score"],
                                                                        test_size=test_size)
    train_dataset = Dataset(fps=list(train_fps),
                            scores = list(train_scores))
    valid_dataset = Dataset(fps=list(valid_fps),
                            scores = list(valid_scores))
    train_loader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=True)
    valid_loader = DataLoader(valid_dataset,
                              batch_size=batch_size,
                              shuffle=False)
    return train_loader, valid_loader

# %%
def train_step(dff, epochs, batch_size, step_time, device="cuda"):
    model, optimizer = init_model(device=device)
    train_loader, valid_loader = prepare_dataloader(dff,  batch_size=batch_size)

    model_folder = "models/ada17/ecfp/models_random/{}".format(step_time)
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)

    hist = {"train-loss":[], "test-mae":[], "test-rmse":[], "test-r2":[],"test-sp":[]}
    for epoch in range(epochs):
        train_loss = train_epoch(train_loader, model, optimizer, device)
        test_mae, test_rmse, test_r2, test_sp = test_epoch(valid_loader, model, device)
        hist["train-loss"].append(train_loss)
        hist["test-mae"].append(test_mae)
        hist["test-rmse"].append(test_rmse)
        hist["test-r2"].append(test_r2)
        hist["test-sp"].append(test_sp)

        if test_rmse <= min(hist["test-rmse"]):
            weight_path = os.path.join(model_folder, "weight_{}.pth".format(epoch))
            torch.save(model.state_dict(), weight_path)

        # print(f'Epoch: {epoch}, Train loss: {train_loss:.3}, Test mae: {test_mae:.3}, Test rmse: {test_rmse:.3}, Test r2: {test_r2:.3}')
    print("---------------------------------\nvalidation min rmse: {}\n---------------------------------\n".format(min(hist["test-rmse"])))
    return weight_path

# %%
def random_select(df, n_samples):
    df_select = df.sample(n=n_samples).copy()
    sample_indexs = df_select["name"].tolist()
    df_remaining = df[~df["name"].isin(sample_indexs)].copy()
    return df_select, df_remaining

# %%
def predict(fpnp, model, device):
    fpnp = fpnp.reshape(1, 2048)
    fp = torch.from_numpy(fpnp).float().to(device)
    with torch.no_grad():
        output = model(fp)
        pred = output.cpu().numpy()[0][0]
    return pred

# %%
def load_model(best_model_path, device="cuda", enable_dp=True):
    model= DNN().to(device)
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()
    if enable_dp:
        enable_dropout(model)
    return model

# %%
def eval_model(dff, best_model_path):
    model = load_model(best_model_path, enable_dp=False)
    dff["pred"] = dff["ecfp"].map(lambda x: predict(x,  model, device="cuda"))
    MAE = mean_absolute_error(dff["score"], dff["pred"])
    RMSE = np.sqrt(mean_squared_error(dff["score"], dff["pred"]))
    R2 = r2_score(dff["score"], dff["pred"])
    Sp = spearmanr(dff["score"], dff["pred"])[0]
    return MAE, RMSE, R2, Sp

# %%
def run_step(dfs, epochs, stime):
    dfs_new = dfs.copy()

    best_model_path = train_step(dfs_new, epochs, batch_size=32, step_time=stime)
    return best_model_path

# %%
def run_iterations(df, df_test, epochs=200, iterations=100, n_samples=100):
    results = {"RMSE": [], "R2": [], "Sp": []}

    print("len(df):", len(df))

    df["ecfp"] = df["smiles"].map(lambda x: ecfp_from_smiles(x))
    df = df[~df["ecfp"].isna()]

    for stime in range(iterations):
        if stime < 1:
            dfs, dfr = random_select(df, n_samples)
        else:
            df_temp = dfs.copy()
            dfs, dfr = random_select(dfr, n_samples)
            dfs = pd.concat([dfs, df_temp], axis=0)
            dfs = dfs.reset_index(drop=True)
        print("number of mol pool:", len(dfs))
        best_model_path = run_step(dfs, epochs, stime)
        MAE, RMSE, R2 , Sp = eval_model(df_test, best_model_path)
        print("MAE:{}, RMSE:{}, R2:{}, Sp:{}, step:{}".format(MAE, RMSE, R2, Sp, stime))

        results["RMSE"].append(RMSE)
        results["R2"].append(R2)
        results["Sp"].append(Sp)

    # Convert results dictionary to DataFrame
    results_df = pd.DataFrame(results)

    results_df.to_csv('result/ada17/ecfp_random_results.csv', index=False)

# %%
df = pd.read_csv("preprocess_data/ada17/ada17_train.csv", sep="\t")
df_test = pd.read_csv("preprocess_data/ada17/ada17_test.csv", sep="\t")
df_test["ecfp"] = df_test["smiles"].map(lambda x: ecfp_from_smiles(x))
df_test = df_test[~df_test["ecfp"].isna()]
# Out:
# [18:24:25] SMILES Parse Error: syntax error while parsing: error
# [18:24:25] SMILES Parse Error: Failed parsing SMILES 'error' for input: 'error'
# [18:24:36] SMILES Parse Error: syntax error while parsing: error
# [18:24:36] SMILES Parse Error: Failed parsing SMILES 'error' for input: 'error'

# %%
run_iterations(df, df_test)
# Out:
# len(df): 20479
# number of mol pool: 100
# ---------------------------------
# validation min rmse: 1.3525857830519372
# ---------------------------------
#
# MAE:1.2192406259483066, RMSE:1.5163883408330066, R2:-1.4594324918788204, Sp:0.14292973088651606, step:0
# number of mol pool: 200
# ---------------------------------
# validation min rmse: 1.314223105396619
# ---------------------------------
#
# MAE:1.154458610718517, RMSE:1.450085991618018, R2:-1.2490626189683929, Sp:0.1278626164033984, step:1
# number of mol pool: 300
# ---------------------------------
# validation min rmse: 1.392894635475028
# ---------------------------------
#
# MAE:1.154298678867481, RMSE:1.438708077082933, R2:-1.213907118563451, Sp:0.1447045770239753, step:2
# number of mol pool: 400
# ---------------------------------
# validation min rmse: 1.2201867314237589
# ---------------------------------
#
# MAE:1.0332901001568713, RMSE:1.3014029706044203, R2:-0.8114970059263085, Sp:0.2166445678890535, step:3
# number of mol pool: 500
# ---------------------------------
# validation min rmse: 1.3020053030683099
# ---------------------------------
#
# MAE:1.067226400740287, RMSE:1.3461349470671258, R2:-0.9381671631344641, Sp:0.21222970722367782, step:4
# number of mol pool: 600
# ---------------------------------
# validation min rmse: 1.266140978454285
# ---------------------------------
#
# MAE:1.049558945514233, RMSE:1.320916230738887, R2:-0.8662275067587122, Sp:0.20614785442194616, step:5
# number of mol pool: 700
# ---------------------------------
# validation min rmse: 1.1689321741897756
# ---------------------------------
#
# MAE:0.993311756625191, RMSE:1.2555665415827735, R2:-0.6861394954879629, Sp:0.2761685123569956, step:6
# number of mol pool: 800
# ---------------------------------
# validation min rmse: 1.2105208327432166
# ---------------------------------
#
# MAE:0.9678174572264502, RMSE:1.223036283251214, R2:-0.5998995475679587, Sp:0.3682344984206743, step:7
# number of mol pool: 900
# ---------------------------------
# validation min rmse: 1.2270261635124202
# ---------------------------------
#
# MAE:1.0072510976696614, RMSE:1.2763464753602558, R2:-0.7424133902222716, Sp:0.315541557441105, step:8
# number of mol pool: 1000
# ---------------------------------
# validation min rmse: 1.1374409622691233
# ---------------------------------
#
# MAE:0.9067815285636716, RMSE:1.1477083349997954, R2:-0.40889005759804453, Sp:0.38762119488079805, step:9
# number of mol pool: 1100
# ---------------------------------
# validation min rmse: 1.2283280163254182
# ---------------------------------
#
# MAE:0.9677951843027328, RMSE:1.2303876523526993, R2:-0.6191905528360999, Sp:0.3292355779119783, step:10
# number of mol pool: 1200
# ---------------------------------
# validation min rmse: 1.141262314694438
# ---------------------------------
#
# MAE:0.9369063316267692, RMSE:1.1827391106959226, R2:-0.4962079210879651, Sp:0.3473959679350832, step:11
# number of mol pool: 1300
# ---------------------------------
# validation min rmse: 1.1384597630048334
# ---------------------------------
#
# MAE:0.880701825706688, RMSE:1.117350564848466, R2:-0.3353433219730584, Sp:0.3952248005437688, step:12
# number of mol pool: 1400
# ---------------------------------
# validation min rmse: 1.1122158039628514
# ---------------------------------
#
# MAE:0.8920006865859599, RMSE:1.1345620566021293, R2:-0.37679900559699564, Sp:0.3996439824858887, step:13
# number of mol pool: 1500
# ---------------------------------
# validation min rmse: 1.1007946603360172
# ---------------------------------
#
# MAE:0.8755545785517193, RMSE:1.1111871127150301, R2:-0.32065209590620514, Sp:0.4326637320334099, step:14
# number of mol pool: 1600
# ---------------------------------
# validation min rmse: 1.1390041917700464
# ---------------------------------
#
# MAE:0.8940663238671954, RMSE:1.134903793541216, R2:-0.37762853084747516, Sp:0.3919299519326861, step:15
# number of mol pool: 1700
# ---------------------------------
# validation min rmse: 1.1234028623316694
# ---------------------------------
#
# MAE:0.8796845329984047, RMSE:1.1218664011533936, R2:-0.3461588667552935, Sp:0.3949548078586034, step:16
# number of mol pool: 1800
# ---------------------------------
# validation min rmse: 1.0763793395164738
# ---------------------------------
#
# MAE:0.8571408753503648, RMSE:1.0906961953491732, R2:-0.27239404977558435, Sp:0.4042479355930839, step:17
# number of mol pool: 1900
# ---------------------------------
# validation min rmse: 1.0904355808856188
# ---------------------------------
#
# MAE:0.8533206336303089, RMSE:1.0813248294691147, R2:-0.2506229207302024, Sp:0.42668826778810454, step:18
# number of mol pool: 2000
# ---------------------------------
# validation min rmse: 1.1054952752865423
# ---------------------------------
#
# MAE:0.8521530302014352, RMSE:1.0891490729655107, R2:-0.2687868983850157, Sp:0.44916017732498087, step:19
# number of mol pool: 2100
# ---------------------------------
# validation min rmse: 1.0795943121982532
# ---------------------------------
#
# MAE:0.8373875676542457, RMSE:1.063698502944423, R2:-0.21018322635153464, Sp:0.43852951425122066, step:20
# number of mol pool: 2200
# ---------------------------------
# validation min rmse: 1.0810099180535226
# ---------------------------------
#
# MAE:0.843727104992613, RMSE:1.0761655269974766, R2:-0.23871724948552542, Sp:0.4269155938867696, step:21
# number of mol pool: 2300
# ---------------------------------
# validation min rmse: 1.0798730262867189
# ---------------------------------
#
# MAE:0.8549146077959862, RMSE:1.0862122432840133, R2:-0.26195369739348795, Sp:0.4094649061229843, step:22
# number of mol pool: 2400
# ---------------------------------
# validation min rmse: 1.045068982325889
# ---------------------------------
#
# MAE:0.8318571783712037, RMSE:1.0589886282634313, R2:-0.19948998493489278, Sp:0.4497706580173248, step:23
# number of mol pool: 2500
# ---------------------------------
# validation min rmse: 1.0185128655904054
# ---------------------------------
#
# MAE:0.8038204606032957, RMSE:1.0232380792477973, R2:-0.11986951045955485, Sp:0.4915569941038145, step:24
# number of mol pool: 2600
# ---------------------------------
# validation min rmse: 1.0540384043367677
# ---------------------------------
#
# MAE:0.8286969009151831, RMSE:1.0575469023905002, R2:-0.19622619432312582, Sp:0.44600465870106787, step:25
# number of mol pool: 2700
# ---------------------------------
# validation min rmse: 1.0423794623227076
# ---------------------------------
#
# MAE:0.8268947096022303, RMSE:1.052329635262193, R2:-0.18445246223142497, Sp:0.4431051985548912, step:26
# number of mol pool: 2800
# ---------------------------------
# validation min rmse: 1.0482234341559051
# ---------------------------------
#
# MAE:0.8023492404752465, RMSE:1.0228180317778537, R2:-0.11895026827551658, Sp:0.4870301252026763, step:27
# number of mol pool: 2900
# ---------------------------------
# validation min rmse: 1.003139207500889
# ---------------------------------
#
# MAE:0.7973429332920255, RMSE:1.0123255549748822, R2:-0.09611074122393193, Sp:0.5027786101959357, step:28
# number of mol pool: 3000
# ---------------------------------
# validation min rmse: 1.0007702640682659
# ---------------------------------
#
# MAE:0.7953291016481544, RMSE:1.0179924340361968, R2:-0.10841688656524107, Sp:0.45102553617735935, step:29
# number of mol pool: 3100
# ---------------------------------
# validation min rmse: 1.0030126580895438
# ---------------------------------
#
# MAE:0.8002954346774124, RMSE:1.0171989588571915, R2:-0.10668964676654591, Sp:0.4737626354057917, step:30
# number of mol pool: 3200
# ---------------------------------
# validation min rmse: 1.0066253087092156
# ---------------------------------
#
# MAE:0.8086733567167781, RMSE:1.0298172458758175, R2:-0.13431677322015179, Sp:0.46468763786903816, step:31
# number of mol pool: 3300
# ---------------------------------
# validation min rmse: 0.9821594241277326
# ---------------------------------
#
# MAE:0.8017944639585961, RMSE:1.0244922229745204, R2:-0.12261635512224967, Sp:0.45274325381798275, step:32
# number of mol pool: 3400
# ---------------------------------
# validation min rmse: 0.9770269973573629
# ---------------------------------
#
# MAE:0.7573535496736525, RMSE:0.9712982216413206, R2:-0.009065180283075458, Sp:0.5079556267570786, step:33
# number of mol pool: 3500
# ---------------------------------
# validation min rmse: 0.9731405644203807
# ---------------------------------
#
# MAE:0.7746971362262568, RMSE:0.9858231939612245, R2:-0.03947032786338389, Sp:0.4824329565629368, step:34
# number of mol pool: 3600
# ---------------------------------
# validation min rmse: 0.9627831154432239
# ---------------------------------
#
# MAE:0.7606123980739167, RMSE:0.9764740983738662, R2:-0.01984809443463531, Sp:0.49582160399147424, step:35
# number of mol pool: 3700
# ---------------------------------
# validation min rmse: 0.9735361729036812
# ---------------------------------
#
# MAE:0.7726035730657603, RMSE:0.9851120296693104, R2:-0.03797113907243577, Sp:0.491585373667339, step:36
# number of mol pool: 3800
# ---------------------------------
# validation min rmse: 0.9849103882328937
# ---------------------------------
#
# MAE:0.7729490684333127, RMSE:0.9825778431696999, R2:-0.032637676441900965, Sp:0.4962158679639089, step:37
# number of mol pool: 3900
# ---------------------------------
# validation min rmse: 0.9320845604279681
# ---------------------------------
#
# MAE:0.731749474731241, RMSE:0.9395019832645128, R2:0.0559186126725737, Sp:0.5292826920471456, step:38
# number of mol pool: 4000
# ---------------------------------
# validation min rmse: 0.9768555573267893
# ---------------------------------
#
# MAE:0.7540611889209962, RMSE:0.9660095785229176, R2:0.0018934663132913476, Sp:0.5075707131269902, step:39
# number of mol pool: 4100
# ---------------------------------
# validation min rmse: 0.9622461303763054
# ---------------------------------
#
# MAE:0.7611931480433988, RMSE:0.9718134100317446, R2:-0.010135905059784678, Sp:0.5208226256078198, step:40
# number of mol pool: 4200
# ---------------------------------
# validation min rmse: 0.9430671770406118
# ---------------------------------
#
# MAE:0.7499121818063832, RMSE:0.9581087257409423, R2:0.018153437578794396, Sp:0.5198434670265928, step:41
# number of mol pool: 4300
# ---------------------------------
# validation min rmse: 0.9312385812674681
# ---------------------------------
#
# MAE:0.7422869837146244, RMSE:0.9491432529306473, R2:0.03644266267378682, Sp:0.5341436489290189, step:42
# number of mol pool: 4400
# ---------------------------------
# validation min rmse: 0.9380868646875251
# ---------------------------------
#
# MAE:0.7341386600402695, RMSE:0.9413589110387609, R2:0.05218296660767596, Sp:0.533368985440672, step:43
# number of mol pool: 4500
# ---------------------------------
# validation min rmse: 0.9451695555569677
# ---------------------------------
#
# MAE:0.7519598115341628, RMSE:0.9650534885048188, R2:0.003868203365120726, Sp:0.5113030366782442, step:44
# number of mol pool: 4600
# ---------------------------------
# validation min rmse: 0.9242781547078892
# ---------------------------------
#
# MAE:0.7261127511138306, RMSE:0.932003388792411, R2:0.07092876081553234, Sp:0.532137240477825, step:45
# number of mol pool: 4700
# ---------------------------------
# validation min rmse: 0.908064166443188
# ---------------------------------
#
# MAE:0.7368446075298942, RMSE:0.9444029117629116, R2:0.04604328819921555, Sp:0.5198976495491354, step:46
# number of mol pool: 4800
# ---------------------------------
# validation min rmse: 0.906416887279614
# ---------------------------------
#
# MAE:0.7139412837311863, RMSE:0.9212968806102886, R2:0.09215180485236552, Sp:0.5512442406904472, step:47
# number of mol pool: 4900
# ---------------------------------
# validation min rmse: 0.8964211740174131
# ---------------------------------
#
# MAE:0.7034238947435485, RMSE:0.9037444447262292, R2:0.126414705842546, Sp:0.5512259999396466, step:48
# number of mol pool: 5000
# ---------------------------------
# validation min rmse: 0.8946412079526105
# ---------------------------------
#
# MAE:0.7063958818557112, RMSE:0.903769777146379, R2:0.12636573106876903, Sp:0.5580511949020149, step:49
# number of mol pool: 5100
# ---------------------------------
# validation min rmse: 0.906040405695714
# ---------------------------------
#
# MAE:0.7180491000838886, RMSE:0.9232716148830483, R2:0.08825581799128956, Sp:0.5325800306867992, step:50
# number of mol pool: 5200
# ---------------------------------
# validation min rmse: 0.8991054833293629
# ---------------------------------
#
# MAE:0.7005048351808302, RMSE:0.8993334932045556, R2:0.13492139997015062, Sp:0.5494457419182358, step:51
# number of mol pool: 5300
# ---------------------------------
# validation min rmse: 0.8912671764377637
# ---------------------------------
#
# MAE:0.689850016236109, RMSE:0.8871543547601496, R2:0.15819323699151566, Sp:0.5689120001128852, step:52
# number of mol pool: 5400
# ---------------------------------
# validation min rmse: 0.8850340669715756
# ---------------------------------
#
# MAE:0.6931434609063075, RMSE:0.8914638543308141, R2:0.1499949407157879, Sp:0.5640456447786055, step:53
# number of mol pool: 5500
# ---------------------------------
# validation min rmse: 0.8870618519033171
# ---------------------------------
#
# MAE:0.6851748593631122, RMSE:0.8842832983248147, R2:0.16363302072607444, Sp:0.5693212623944459, step:54
# number of mol pool: 5600
# ---------------------------------
# validation min rmse: 0.9026857541270842
# ---------------------------------
#
# MAE:0.7095830515305016, RMSE:0.9108429503228237, R2:0.11263757281201348, Sp:0.5322653135663985, step:55
# number of mol pool: 5700
# ---------------------------------
# validation min rmse: 0.905697876371924
# ---------------------------------
#
# MAE:0.7003718726978964, RMSE:0.9007602122058685, R2:0.13217446997503757, Sp:0.5498223105561776, step:56
# number of mol pool: 5800
# ---------------------------------
# validation min rmse: 0.875930932345828
# ---------------------------------
#
# MAE:0.6877614719847772, RMSE:0.8897214763389214, R2:0.15331438604059233, Sp:0.5647438483210372, step:57
# number of mol pool: 5900
# ---------------------------------
# validation min rmse: 0.8508248787117447
# ---------------------------------
#
# MAE:0.6626135163309907, RMSE:0.8535492283248295, R2:0.22076010134523694, Sp:0.5841487666957286, step:58
# number of mol pool: 6000
# ---------------------------------
# validation min rmse: 0.8851976386904133
# ---------------------------------
#
# MAE:0.6779163646383187, RMSE:0.874045636362258, R2:0.1828867535680545, Sp:0.5818464333193675, step:59
# number of mol pool: 6100
# ---------------------------------
# validation min rmse: 0.8716397429675207
# ---------------------------------
#
# MAE:0.6740675064596839, RMSE:0.8706346661817508, R2:0.1892518914197413, Sp:0.5750765449323783, step:60
# number of mol pool: 6200
# ---------------------------------
# validation min rmse: 0.874433197472313
# ---------------------------------
#
# MAE:0.6770494931931206, RMSE:0.8686981445872528, R2:0.19285451649015406, Sp:0.5746995514093353, step:61
# number of mol pool: 6300
# ---------------------------------
# validation min rmse: 0.8816265247052073
# ---------------------------------
#
# MAE:0.6890013273958057, RMSE:0.8820082546477146, R2:0.16793101827923684, Sp:0.5654057330728544, step:62
# number of mol pool: 6400
# ---------------------------------
# validation min rmse: 0.8471834317491226
# ---------------------------------
#
# MAE:0.6673801914782501, RMSE:0.8583855498533565, R2:0.21190453351747052, Sp:0.580675769401733, step:63
# number of mol pool: 6500
# ---------------------------------
# validation min rmse: 0.8803924736512264
# ---------------------------------
#
# MAE:0.6827563385057589, RMSE:0.8832354057625602, R2:0.1656140678627379, Sp:0.5481415363823768, step:64
# number of mol pool: 6600
# ---------------------------------
# validation min rmse: 0.8434773220852807
# ---------------------------------
#
# MAE:0.6646162843427424, RMSE:0.8540687393254759, R2:0.21981124711722966, Sp:0.5777763210678154, step:65
# number of mol pool: 6700
# ---------------------------------
# validation min rmse: 0.8437643384923584
# ---------------------------------
#
# MAE:0.6549943501845804, RMSE:0.8451104793250968, R2:0.23609208995823294, Sp:0.593699512575218, step:66
# number of mol pool: 6800
# ---------------------------------
# validation min rmse: 0.8379970767998599
# ---------------------------------
#
# MAE:0.6539449657062109, RMSE:0.8418946428691761, R2:0.24189471340525248, Sp:0.5908250002627013, step:67
# number of mol pool: 6900
# ---------------------------------
# validation min rmse: 0.8511787475927727
# ---------------------------------
#
# MAE:0.66159777644454, RMSE:0.8501644923404319, R2:0.22692797476957582, Sp:0.5864422915152594, step:68
# number of mol pool: 7000
# ---------------------------------
# validation min rmse: 0.8625616138971769
# ---------------------------------
#
# MAE:0.667061111915708, RMSE:0.8563865778410114, R2:0.21557082645707715, Sp:0.5953677056436146, step:69
# number of mol pool: 7100
# ---------------------------------
# validation min rmse: 0.8737416055607398
# ---------------------------------
#
# MAE:0.6769173857409833, RMSE:0.8771953951671296, R2:0.17698695402466358, Sp:0.5747137314084643, step:70
# number of mol pool: 7200
# ---------------------------------
# validation min rmse: 0.8584969728115812
# ---------------------------------
#
# MAE:0.6680358713023233, RMSE:0.8678466983546327, R2:0.19443597303874205, Sp:0.5735248523415526, step:71
# number of mol pool: 7300
# ---------------------------------
# validation min rmse: 0.8277870109835839
# ---------------------------------
#
# MAE:0.6407232529253968, RMSE:0.8275861165069139, R2:0.26744468133319954, Sp:0.6035025524555544, step:72
# number of mol pool: 7400
# ---------------------------------
# validation min rmse: 0.8172315689669062
# ---------------------------------
#
# MAE:0.6458593078470249, RMSE:0.8263247802148576, R2:0.26967597654455044, Sp:0.5938597163916269, step:73
# number of mol pool: 7500
# ---------------------------------
# validation min rmse: 0.8318881132928773
# ---------------------------------
#
# MAE:0.6443111882225313, RMSE:0.8267514623197737, R2:0.26892155975268706, Sp:0.6027884111190388, step:74
# number of mol pool: 7600
# ---------------------------------
# validation min rmse: 0.848037114943001
# ---------------------------------
#
# MAE:0.6505267427294573, RMSE:0.8448216610260367, R2:0.23661413503548234, Sp:0.5998881849864213, step:75
# number of mol pool: 7700
# ---------------------------------
# validation min rmse: 0.8237857899159257
# ---------------------------------
#
# MAE:0.6402171443477416, RMSE:0.8232584398231653, R2:0.2750861180832779, Sp:0.6069445117452629, step:76
# number of mol pool: 7800
# ---------------------------------
# validation min rmse: 0.8384575167738443
# ---------------------------------
#
# MAE:0.6467028140902761, RMSE:0.8365057053000583, R2:0.2515688618331384, Sp:0.5869036719771245, step:77
# number of mol pool: 7900
# ---------------------------------
# validation min rmse: 0.8344818103273012
# ---------------------------------
#
# MAE:0.6431178624440783, RMSE:0.8292363224539061, R2:0.2645203394207175, Sp:0.6119016364594889, step:78
# number of mol pool: 8000
# ---------------------------------
# validation min rmse: 0.8266590981912313
# ---------------------------------
#
# MAE:0.6454335811254003, RMSE:0.8371169935980993, R2:0.25047460901774854, Sp:0.5751042203506157, step:79
# number of mol pool: 8100
# ---------------------------------
# validation min rmse: 0.8166605140132028
# ---------------------------------
#
# MAE:0.628290725396564, RMSE:0.8138928480307827, R2:0.29148589996476826, Sp:0.6073079510007733, step:80
# number of mol pool: 8200
# ---------------------------------
# validation min rmse: 0.8068276755111417
# ---------------------------------
#
# MAE:0.6304013791773339, RMSE:0.8168321629083132, R2:0.28635916486184054, Sp:0.6133299559193787, step:81
# number of mol pool: 8300
# ---------------------------------
# validation min rmse: 0.8248031278780121
# ---------------------------------
#
# MAE:0.6406040844936819, RMSE:0.8254401726265121, R2:0.27123881086753066, Sp:0.6110884035158931, step:82
# number of mol pool: 8400
# ---------------------------------
# validation min rmse: 0.7913129610874489
# ---------------------------------
#
# MAE:0.6220642966945229, RMSE:0.8020655655530922, R2:0.3119281729072326, Sp:0.5989984593476528, step:83
# number of mol pool: 8500
# ---------------------------------
# validation min rmse: 0.796330356074108
# ---------------------------------
#
# MAE:0.612415783981201, RMSE:0.7933246068788525, R2:0.32684374833142693, Sp:0.6244929309502694, step:84
# number of mol pool: 8600
# ---------------------------------
# validation min rmse: 0.7990351553933501
# ---------------------------------
#
# MAE:0.6209180948131351, RMSE:0.8038514477431953, R2:0.3088606349985231, Sp:0.6143580523453936, step:85
# number of mol pool: 8700
# ---------------------------------
# validation min rmse: 0.8106844004971288
# ---------------------------------
#
# MAE:0.6313676319292347, RMSE:0.8095162231985523, R2:0.29908533526060277, Sp:0.6138348302441275, step:86
# number of mol pool: 8800
# ---------------------------------
# validation min rmse: 0.8238345292191048
# ---------------------------------
#
# MAE:0.633127773698818, RMSE:0.8151616152484702, R2:0.28927519093046816, Sp:0.6222902333379183, step:87
# number of mol pool: 8900
# ---------------------------------
# validation min rmse: 0.7971011071723986
# ---------------------------------
#
# MAE:0.6131472271364847, RMSE:0.791503060029171, R2:0.32993145775322574, Sp:0.6229218634715609, step:88
# number of mol pool: 9000
# ---------------------------------
# validation min rmse: 0.7945937332569493
# ---------------------------------
#
# MAE:0.6122328850536051, RMSE:0.7870278427199979, R2:0.33748727161247916, Sp:0.6205944102872682, step:89
# number of mol pool: 9100
# ---------------------------------
# validation min rmse: 0.7889176564719487
# ---------------------------------
#
# MAE:0.6147113587431793, RMSE:0.7900213924046785, R2:0.33243780208274787, Sp:0.6271639144896751, step:90
# number of mol pool: 9200
# ---------------------------------
# validation min rmse: 0.781657432158402
# ---------------------------------
#
# MAE:0.608574750733388, RMSE:0.7867257140462997, R2:0.3379958322021166, Sp:0.629934280096687, step:91
# number of mol pool: 9300
# ---------------------------------
# validation min rmse: 0.7913175782630257
# ---------------------------------
#
# MAE:0.6016844224483111, RMSE:0.7796443653916186, R2:0.349859647848242, Sp:0.6366071197666384, step:92
# number of mol pool: 9400
# ---------------------------------
# validation min rmse: 0.8008669735164266
# ---------------------------------
#
# MAE:0.6276436457719881, RMSE:0.8109669166743259, R2:0.2965709361879959, Sp:0.6205188995545093, step:93
# number of mol pool: 9500
# ---------------------------------
# validation min rmse: 0.7935229180027931
# ---------------------------------
#
# MAE:0.6231219535966347, RMSE:0.8009857689845098, R2:0.3137795863218129, Sp:0.6167354046149601, step:94
# number of mol pool: 9600
# ---------------------------------
# validation min rmse: 0.7818542626932199
# ---------------------------------
#
# MAE:0.6079359173394049, RMSE:0.7877630828372092, R2:0.33624885681594086, Sp:0.61855409104558, step:95
# number of mol pool: 9700
# ---------------------------------
# validation min rmse: 0.7891638624012958
# ---------------------------------
#
# MAE:0.6076547535158356, RMSE:0.7818266828522268, R2:0.34621491335589405, Sp:0.629621423735705, step:96
# number of mol pool: 9800
# ---------------------------------
# validation min rmse: 0.7845496819568198
# ---------------------------------
#
# MAE:0.6051181076899663, RMSE:0.7801263000323518, R2:0.34905563511777415, Sp:0.6233671182059037, step:97
# number of mol pool: 9900
# ---------------------------------
# validation min rmse: 0.781359065350995
# ---------------------------------
#
# MAE:0.6083037909437874, RMSE:0.7842617892126936, R2:0.3421359644907612, Sp:0.6164948838021337, step:98
# number of mol pool: 10000
# ---------------------------------
# validation min rmse: 0.777113089236506
# ---------------------------------
#
# MAE:0.6081688786047917, RMSE:0.7825385997181074, R2:0.34502372213447496, Sp:0.6287568451778626, step:99
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-d7f2db78b0b6> in <cell line: 1>()
# ----> 1 run_iterations(df, df_test)
#
# <ipython-input-17-aac8acaf7dc6> in run_iterations(df, df_test, epochs, iterations, n_samples)
#      27     results_df = pd.DataFrame(results)
#      28
# ---> 29     results_df.to_csv('result/ada17/ecfp_random_results.csv', index=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3718         )
#    3719
# -> 3720         return DataFrameRenderer(formatter).to_csv(
#    3721             path_or_buf,
#    3722             lineterminator=lineterminator,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1187             formatter=self.fmt,
#    1188         )
# -> 1189         csv_formatter.save()
#    1190
#    1191         if created_buffer:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in save(self)
#     239         """
#     240         # apply compression and byte/text conversion
# --> 241         with get_handle(
#     242             self.filepath_or_buffer,
#     243             self.mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732     # Only for write methods
#     733     if "r" not in mode and is_path:
# --> 734         check_parent_directory(str(handle))
#     735
#     736     if compression:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in check_parent_directory(path)
#     595     parent = Path(path).parent
#     596     if not parent.is_dir():
# --> 597         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     598
#     599
#
# OSError: Cannot save file into a non-existent directory: 'result/ada17'
