# %%
# !pip install datamol
# !pip install rdkit-pypi
# !pip install pandas
# Out:
# Collecting datamol
#   Downloading datamol-0.11.3-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.7/381.7 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from datamol) (4.66.1)
# Collecting loguru (from datamol)
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from datamol) (1.3.2)
# Requirement already satisfied: fsspec>=2021.9 in /usr/local/lib/python3.10/dist-packages (from datamol) (2023.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datamol) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.11.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from datamol) (3.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from datamol) (9.4.0)
# Collecting selfies (from datamol)
#   Downloading selfies-2.1.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from datamol) (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from datamol) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datamol) (23.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from datamol) (4.5.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from datamol) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datamol) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->datamol) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->datamol) (1.16.0)
# Installing collected packages: selfies, loguru, datamol
# Successfully installed datamol-0.11.3 loguru-0.7.2 selfies-2.1.1
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 61.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (9.4.0)
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import os
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import Linear
from torch.utils.data import DataLoader
import tqdm
from scipy.stats import spearmanr

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Project/ALVS")
# Out:
# Mounted at /content/drive

# %%
def ecfp_from_smiles(smiles,
                     R = 2,
                     L = 2**11,
                     use_features = True,
                     use_chirality = False):
    """
    Inputs:

    - smiles ... SMILES string of input compound
    - R ... maximum radius of circular substructures
    - L ... fingerprint-length
    - use_features ... if false then use standard DAYLIGHT atom features, if true then use pharmacophoric atom features
    - use_chirality ... if true then append tetrahedral chirality flags to atom features

    Outputs:
    - np.array(feature_list) ... ECFP with length L and maximum radius R
    """

    molecule = Chem.MolFromSmiles(smiles)
    if not molecule:
        return np.nan
    feature_list = AllChem.GetMorganFingerprintAsBitVect(molecule,
                                                         radius = R,
                                                         nBits = L,
                                                         useFeatures = use_features,
                                                         useChirality = use_chirality)
    return np.array(feature_list)

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, fps, scores):
        self.fps = fps
        self.scores = scores
        self.dataLen = len(scores)

    def __getitem__(self, index):
        fp = np.array(self.fps[index])
        score = np.array(self.scores[index]).reshape(1,)
        return fp, score

    def __len__(self):
        return self.dataLen

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.fc1 = Linear(2048, 1024)
        self.dropout1 = nn.Dropout(p=0.2)
        self.fc2 = Linear(1024, 516)
        self.dropout2 = nn.Dropout(p=0.2)
        self.fc3 = Linear(516, 256)
        self.dropout3 = nn.Dropout(p=0.2)
        self.fc4 = Linear(256, 128)
        self.dropout4 = nn.Dropout(p=0.2)
        self.fc5 = Linear(128, 1)


    def forward(self, data):
        x = F.relu(self.fc1(data))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = F.relu(self.fc3(x))
        x = self.dropout3(x)
        x = F.relu(self.fc4(x))
        x = self.dropout4(x)
        x = self.fc5(x)
        return x

# %%
def train_epoch(loader, model, optimizer, device):
    model.train()

    loss_all = 0
    i = 0
    for fps, scores in loader:
        fps = fps.float().to(device)
        scores = scores.float().to(device)

        optimizer.zero_grad()
        output = model(fps)
        loss = F.mse_loss(output, scores)
        loss.backward()

        loss_all += loss.item()
        optimizer.step()
        i += 1
    return loss_all / i

# %%
def test_epoch(loader, model,  device):
    model.eval()

    MSE, MAE = 0, 0
    trues, preds = [], []
    with torch.no_grad():
        for fps, scores in loader:
            fps = fps.float().to(device)
            scores = scores.float().to(device)

            output = model(fps)
            pred = output.cpu().squeeze().numpy().tolist()
            true = scores.cpu().squeeze().numpy().tolist()

            trues.extend(true)
            preds.extend(pred)
    MAE = mean_absolute_error(trues, preds)
    RMSE = np.sqrt(mean_squared_error(trues, preds))
    R2 = r2_score(trues, preds)
    Sp = spearmanr(trues, preds)[0]
    return MAE, RMSE, R2, Sp

# %%
def init_model(device, lr=0.0001):
    model = DNN()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    return model, optimizer

# %%
def prepare_dataloader(dff, batch_size, test_size=0.8):
    train_fps, valid_fps, train_scores, valid_scores = train_test_split(
                                                                        dff["ecfp"],
                                                                        dff["score"],
                                                                        test_size=test_size)
    train_dataset = Dataset(fps=list(train_fps),
                            scores = list(train_scores))
    valid_dataset = Dataset(fps=list(valid_fps),
                            scores = list(valid_scores))
    train_loader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=True)
    valid_loader = DataLoader(valid_dataset,
                              batch_size=batch_size,
                              shuffle=False)
    return train_loader, valid_loader

# %%
def train_step(dff, epochs, batch_size, step_time, device="cuda"):
    model, optimizer = init_model(device=device)
    train_loader, valid_loader = prepare_dataloader(dff,  batch_size=batch_size)

    model_folder = "models/src/ecfp/models_random/{}".format(step_time)
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)

    hist = {"train-loss":[], "test-mae":[], "test-rmse":[], "test-r2":[],"test-sp":[]}
    for epoch in range(epochs):
        train_loss = train_epoch(train_loader, model, optimizer, device)
        test_mae, test_rmse, test_r2, test_sp = test_epoch(valid_loader, model, device)
        hist["train-loss"].append(train_loss)
        hist["test-mae"].append(test_mae)
        hist["test-rmse"].append(test_rmse)
        hist["test-r2"].append(test_r2)
        hist["test-sp"].append(test_sp)

        if test_rmse <= min(hist["test-rmse"]):
            weight_path = os.path.join(model_folder, "weight_{}.pth".format(epoch))
            torch.save(model.state_dict(), weight_path)

        # print(f'Epoch: {epoch}, Train loss: {train_loss:.3}, Test mae: {test_mae:.3}, Test rmse: {test_rmse:.3}, Test r2: {test_r2:.3}')
    print("---------------------------------\nvalidation min rmse: {}\n---------------------------------\n".format(min(hist["test-rmse"])))
    return weight_path

# %%
def random_select(df, n_samples):
    df_select = df.sample(n=n_samples).copy()
    sample_indexs = df_select["name"].tolist()
    df_remaining = df[~df["name"].isin(sample_indexs)].copy()
    return df_select, df_remaining

# %%
def predict(fpnp, model, device):
    fpnp = fpnp.reshape(1, 2048)
    fp = torch.from_numpy(fpnp).float().to(device)
    with torch.no_grad():
        output = model(fp)
        pred = output.cpu().numpy()[0][0]
    return pred

# %%
def load_model(best_model_path, device="cuda", enable_dp=True):
    model= DNN().to(device)
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()
    if enable_dp:
        enable_dropout(model)
    return model

# %%
def eval_model(dff, best_model_path):
    model = load_model(best_model_path, enable_dp=False)
    dff["pred"] = dff["ecfp"].map(lambda x: predict(x,  model, device="cuda"))
    MAE = mean_absolute_error(dff["score"], dff["pred"])
    RMSE = np.sqrt(mean_squared_error(dff["score"], dff["pred"]))
    R2 = r2_score(dff["score"], dff["pred"])
    Sp = spearmanr(dff["score"], dff["pred"])[0]
    return MAE, RMSE, R2, Sp

# %%
def run_step(dfs, epochs, stime):
    dfs_new = dfs.copy()

    best_model_path = train_step(dfs_new, epochs, batch_size=32, step_time=stime)
    return best_model_path

# %%
def run_iterations(df, df_test, epochs=200, iterations=100, n_samples=100):
    results = {"RMSE": [], "R2": [], "Sp": []}

    print("len(df):", len(df))

    df["ecfp"] = df["smiles"].map(lambda x: ecfp_from_smiles(x))
    df = df[~df["ecfp"].isna()]

    for stime in range(iterations):
        if stime < 1:
            dfs, dfr = random_select(df, n_samples)
        else:
            df_temp = dfs.copy()
            dfs, dfr = random_select(dfr, n_samples)
            dfs = pd.concat([dfs, df_temp], axis=0)
            dfs = dfs.reset_index(drop=True)
        print("number of mol pool:", len(dfs))
        best_model_path = run_step(dfs, epochs, stime)
        MAE, RMSE, R2 , Sp = eval_model(df_test, best_model_path)
        print("MAE:{}, RMSE:{}, R2:{}, Sp:{}, step:{}".format(MAE, RMSE, R2, Sp, stime))

        results["RMSE"].append(RMSE)
        results["R2"].append(R2)
        results["Sp"].append(Sp)

    # Convert results dictionary to DataFrame
    results_df = pd.DataFrame(results)

    results_df.to_csv('ecfp_random_results.csv', index=False)

# %%
df = pd.read_csv("preprocess_data/src/src_train.csv", sep="\t")
df_test = pd.read_csv("preprocess_data/src/src_test.csv", sep="\t")
df_test["ecfp"] = df_test["smiles"].map(lambda x: ecfp_from_smiles(x))
df_test = df_test[~df_test["ecfp"].isna()]

# %%
run_iterations(df, df_test)
# Out:
# len(df): 20979
# number of mol pool: 100
# ---------------------------------
# validation min rmse: 1.6680684163415576
# ---------------------------------
#
# MAE:1.1719933096182191, RMSE:1.4698730144387195, R2:-1.9068792133344479, Sp:0.15865463280412653, step:0
# number of mol pool: 200
# ---------------------------------
# validation min rmse: 1.3502085328750537
# ---------------------------------
#
# MAE:1.0726484504906384, RMSE:1.3563843963955233, R2:-1.4753289612204545, Sp:0.20184785753527512, step:1
# number of mol pool: 300
# ---------------------------------
# validation min rmse: 1.3873731923109014
# ---------------------------------
#
# MAE:1.1076410781957111, RMSE:1.3900266238873047, R2:-1.5996422709245928, Sp:0.18872230312413557, step:2
# number of mol pool: 400
# ---------------------------------
# validation min rmse: 1.4030887274738812
# ---------------------------------
#
# MAE:1.0948061783333736, RMSE:1.3769487757506198, R2:-1.5509557276613375, Sp:0.17814749949828967, step:3
# number of mol pool: 500
# ---------------------------------
# validation min rmse: 1.250816758792911
# ---------------------------------
#
# MAE:0.9443064459445732, RMSE:1.199445322628054, R2:-0.9356563798675597, Sp:0.27279688330254453, step:4
# number of mol pool: 600
# ---------------------------------
# validation min rmse: 1.2768552271875808
# ---------------------------------
#
# MAE:0.9787327918383051, RMSE:1.239479859775108, R2:-1.067027723762751, Sp:0.26908072915579245, step:5
# number of mol pool: 700
# ---------------------------------
# validation min rmse: 1.2135527078395
# ---------------------------------
#
# MAE:0.9388809166626209, RMSE:1.1892327980351882, R2:-0.9028349044517838, Sp:0.30752351608699374, step:6
# number of mol pool: 800
# ---------------------------------
# validation min rmse: 1.1759164006351415
# ---------------------------------
#
# MAE:0.9486598824543955, RMSE:1.2015977736134422, R2:-0.9426098337539093, Sp:0.29296279598566943, step:7
# number of mol pool: 900
# ---------------------------------
# validation min rmse: 1.160420433316831
# ---------------------------------
#
# MAE:0.9175536200936945, RMSE:1.1655463763776952, R2:-0.827790728101075, Sp:0.3241123878447395, step:8
# number of mol pool: 1000
# ---------------------------------
# validation min rmse: 1.14147912462715
# ---------------------------------
#
# MAE:0.8766635556424885, RMSE:1.1284133021519214, R2:-0.713182964356281, Sp:0.3571918993860241, step:9
# number of mol pool: 1100
# ---------------------------------
# validation min rmse: 1.1157835308348845
# ---------------------------------
#
# MAE:0.8578085764991847, RMSE:1.089785359309641, R2:-0.5978988753880392, Sp:0.37412319899293317, step:10
# number of mol pool: 1200
# ---------------------------------
# validation min rmse: 1.117796753019327
# ---------------------------------
#
# MAE:0.8682099535422044, RMSE:1.1041642511241863, R2:-0.6403431795149988, Sp:0.4057726074850476, step:11
# number of mol pool: 1300
# ---------------------------------
# validation min rmse: 1.0965986087226474
# ---------------------------------
#
# MAE:0.8640763576932355, RMSE:1.0987604388892498, R2:-0.6243266929547191, Sp:0.3713926731266593, step:12
# number of mol pool: 1400
# ---------------------------------
# validation min rmse: 1.1685926072059027
# ---------------------------------
#
# MAE:0.8810726810852506, RMSE:1.1233080563113964, R2:-0.6977162287945469, Sp:0.32069652772961404, step:13
# number of mol pool: 1500
# ---------------------------------
# validation min rmse: 1.0754128904807032
# ---------------------------------
#
# MAE:0.8620810188454175, RMSE:1.101358553678245, R2:-0.6320174989825789, Sp:0.38403836131133773, step:14
# number of mol pool: 1600
# ---------------------------------
# validation min rmse: 1.0127716067625505
# ---------------------------------
#
# MAE:0.8477134809583086, RMSE:1.0792608123938763, R2:-0.5671846506205951, Sp:0.3765438583226875, step:15
# number of mol pool: 1700
# ---------------------------------
# validation min rmse: 1.036102877823657
# ---------------------------------
#
# MAE:0.8303283228354765, RMSE:1.0623229985864853, R2:-0.5183801601965352, Sp:0.41842751150026375, step:16
# number of mol pool: 1800
# ---------------------------------
# validation min rmse: 1.0416278065265139
# ---------------------------------
#
# MAE:0.8202985410267107, RMSE:1.048287102014846, R2:-0.47852215821663413, Sp:0.4047082406675646, step:17
# number of mol pool: 1900
# ---------------------------------
# validation min rmse: 1.0700462778169775
# ---------------------------------
#
# MAE:0.85545448007892, RMSE:1.088967900793624, R2:-0.5955025757320835, Sp:0.40849676342092944, step:18
# number of mol pool: 2000
# ---------------------------------
# validation min rmse: 0.9853112284003992
# ---------------------------------
#
# MAE:0.8034565073705527, RMSE:1.0308596433098038, R2:-0.42977081815112506, Sp:0.4280400242403988, step:19
# number of mol pool: 2100
# ---------------------------------
# validation min rmse: 1.0018638492131653
# ---------------------------------
#
# MAE:0.8017418830198468, RMSE:1.0298625288588596, R2:-0.4270062213115058, Sp:0.41780565766863953, step:20
# number of mol pool: 2200
# ---------------------------------
# validation min rmse: 1.0089920506592802
# ---------------------------------
#
# MAE:0.798571112565968, RMSE:1.0182167859713451, R2:-0.39491536382683834, Sp:0.44592696387546604, step:21
# number of mol pool: 2300
# ---------------------------------
# validation min rmse: 0.9566352322126048
# ---------------------------------
#
# MAE:0.7667800804094959, RMSE:0.9842897113655431, R2:-0.30350662845238774, Sp:0.44468192883501223, step:22
# number of mol pool: 2400
# ---------------------------------
# validation min rmse: 0.9864476182100897
# ---------------------------------
#
# MAE:0.8025624008659198, RMSE:1.0238741419787407, R2:-0.4104591186672586, Sp:0.4322209080521062, step:23
# number of mol pool: 2500
# ---------------------------------
# validation min rmse: 0.9600400916130418
# ---------------------------------
#
# MAE:0.7619814886575985, RMSE:0.9869187267527587, R2:-0.3104792008198076, Sp:0.47266481036917496, step:24
# number of mol pool: 2600
# ---------------------------------
# validation min rmse: 0.9420496149291152
# ---------------------------------
#
# MAE:0.7628802589084117, RMSE:0.9753672443262787, R2:-0.2799814807644905, Sp:0.4608441710862066, step:25
# number of mol pool: 2700
# ---------------------------------
# validation min rmse: 0.9235020267349008
# ---------------------------------
#
# MAE:0.744582303835167, RMSE:0.9588755984039817, R2:-0.23706319636569928, Sp:0.4919859373810848, step:26
# number of mol pool: 2800
# ---------------------------------
# validation min rmse: 0.9393651739820341
# ---------------------------------
#
# MAE:0.7531148960485866, RMSE:0.9638000415270883, R2:-0.24980205454110282, Sp:0.46792435705635077, step:27
# number of mol pool: 2900
# ---------------------------------
# validation min rmse: 0.9668061156745642
# ---------------------------------
#
# MAE:0.7641567851057357, RMSE:0.979273204542991, R2:-0.29025364726436265, Sp:0.4695149354993577, step:28
# number of mol pool: 3000
# ---------------------------------
# validation min rmse: 0.9751391803105685
# ---------------------------------
#
# MAE:0.7769405356576803, RMSE:0.9908603286413149, R2:-0.32096780952589254, Sp:0.4628665121107237, step:29
# number of mol pool: 3100
# ---------------------------------
# validation min rmse: 0.9372657682667745
# ---------------------------------
#
# MAE:0.7433613569755684, RMSE:0.9500651231122574, R2:-0.21443452095364157, Sp:0.48414918037659915, step:30
# number of mol pool: 3200
# ---------------------------------
# validation min rmse: 0.9845524067780309
# ---------------------------------
#
# MAE:0.7570704837336297, RMSE:0.9732830566886334, R2:-0.27451713619261553, Sp:0.47249203046588784, step:31
# number of mol pool: 3300
# ---------------------------------
# validation min rmse: 0.9677801861351945
# ---------------------------------
#
# MAE:0.7448996578060727, RMSE:0.9552088691558637, R2:-0.2276202549626729, Sp:0.48059533382304265, step:32
# number of mol pool: 3400
# ---------------------------------
# validation min rmse: 0.9043660205090638
# ---------------------------------
#
# MAE:0.7240954136231682, RMSE:0.9290276315368446, R2:-0.16124702725302353, Sp:0.49177128210545684, step:33
# number of mol pool: 3500
# ---------------------------------
# validation min rmse: 0.9581724575135788
# ---------------------------------
#
# MAE:0.7370728400556071, RMSE:0.9522653710501441, R2:-0.22006603206320108, Sp:0.4803019287975718, step:34
# number of mol pool: 3600
# ---------------------------------
# validation min rmse: 0.9189905715206389
# ---------------------------------
#
# MAE:0.7215830337305195, RMSE:0.924984749758784, R2:-0.15116214051962173, Sp:0.5039392494101183, step:35
# number of mol pool: 3700
# ---------------------------------
# validation min rmse: 0.9247467442907984
# ---------------------------------
#
# MAE:0.7228553945680386, RMSE:0.9258732164636849, R2:-0.15337463197833712, Sp:0.5073108614140731, step:36
# number of mol pool: 3800
# ---------------------------------
# validation min rmse: 0.9121954822550475
# ---------------------------------
#
# MAE:0.7219288936280059, RMSE:0.9258472973379273, R2:-0.1533100571679551, Sp:0.5049841888328727, step:37
# number of mol pool: 3900
# ---------------------------------
# validation min rmse: 0.926573685841348
# ---------------------------------
#
# MAE:0.7259321263887124, RMSE:0.9332146761638695, R2:-0.1717378882262346, Sp:0.49561654273361794, step:38
# number of mol pool: 4000
# ---------------------------------
# validation min rmse: 0.9226033070490541
# ---------------------------------
#
# MAE:0.7188304880193822, RMSE:0.9272018791839995, R2:-0.15668727869365884, Sp:0.5043267121442407, step:39
# number of mol pool: 4100
# ---------------------------------
# validation min rmse: 0.8608637601190242
# ---------------------------------
#
# MAE:0.6911921162998296, RMSE:0.8870436237948429, R2:-0.05866196393555323, Sp:0.5302843137960981, step:40
# number of mol pool: 4200
# ---------------------------------
# validation min rmse: 0.8636713912435656
# ---------------------------------
#
# MAE:0.6867928213485135, RMSE:0.8780983365931393, R2:-0.03741771994364229, Sp:0.5147794396561516, step:41
# number of mol pool: 4300
# ---------------------------------
# validation min rmse: 0.8692235689253135
# ---------------------------------
#
# MAE:0.6816114197954971, RMSE:0.8724795534784746, R2:-0.024183722069843316, Sp:0.5300115147178707, step:42
# number of mol pool: 4400
# ---------------------------------
# validation min rmse: 0.8907694334010462
# ---------------------------------
#
# MAE:0.6995823113653216, RMSE:0.8977064646327201, R2:-0.08426654601830874, Sp:0.5419705328346327, step:43
# number of mol pool: 4500
# ---------------------------------
# validation min rmse: 0.9010298084799927
# ---------------------------------
#
# MAE:0.7053653357113616, RMSE:0.9126269362043129, R2:-0.12060851611548862, Sp:0.5124594348760332, step:44
# number of mol pool: 4600
# ---------------------------------
# validation min rmse: 0.8390064541048652
# ---------------------------------
#
# MAE:0.6646943640392117, RMSE:0.8527346351670306, R2:0.021647951439662916, Sp:0.5356665433072302, step:45
# number of mol pool: 4700
# ---------------------------------
# validation min rmse: 0.881501982016288
# ---------------------------------
#
# MAE:0.7025815849797804, RMSE:0.8987283106233932, R2:-0.08673636003890883, Sp:0.5301420156704572, step:46
# number of mol pool: 4800
# ---------------------------------
# validation min rmse: 0.8751958044789392
# ---------------------------------
#
# MAE:0.6950479265006491, RMSE:0.8893764402337526, R2:-0.06423758935877832, Sp:0.5058640178798773, step:47
# number of mol pool: 4900
# ---------------------------------
# validation min rmse: 0.8482835245925568
# ---------------------------------
#
# MAE:0.6854688700602452, RMSE:0.8800946410175106, R2:-0.04214009703377286, Sp:0.5285047451224502, step:48
# number of mol pool: 5000
# ---------------------------------
# validation min rmse: 0.8592760355081459
# ---------------------------------
#
# MAE:0.67445682988275, RMSE:0.8637258830165312, R2:-0.0037353538062536717, Sp:0.5159332600739752, step:49
# number of mol pool: 5100
# ---------------------------------
# validation min rmse: 0.8419850191984334
# ---------------------------------
#
# MAE:0.6625345231320394, RMSE:0.852255069555717, R2:0.02274806406030838, Sp:0.5461431391574187, step:50
# number of mol pool: 5200
# ---------------------------------
# validation min rmse: 0.8071358930754811
# ---------------------------------
#
# MAE:0.6430462455686724, RMSE:0.8253432938460927, R2:0.08349126883312674, Sp:0.5475250692360053, step:51
# number of mol pool: 5300
# ---------------------------------
# validation min rmse: 0.8178229001538534
# ---------------------------------
#
# MAE:0.6506688900932242, RMSE:0.8368885239580058, R2:0.057670953758800936, Sp:0.5602424785538755, step:52
# number of mol pool: 5400
# ---------------------------------
# validation min rmse: 0.8403941466607545
# ---------------------------------
#
# MAE:0.6620030660900863, RMSE:0.8507364739558518, R2:0.02622760524672374, Sp:0.5307927582534105, step:53
# number of mol pool: 5500
# ---------------------------------
# validation min rmse: 0.8146360676430605
# ---------------------------------
#
# MAE:0.6373362081142826, RMSE:0.8248450246043064, R2:0.0845975485256546, Sp:0.5524457549400277, step:54
# number of mol pool: 5600
# ---------------------------------
# validation min rmse: 0.8233287637973803
# ---------------------------------
#
# MAE:0.6561363062724046, RMSE:0.8387492590748478, R2:0.05347595292645657, Sp:0.5411354932749985, step:55
# number of mol pool: 5700
# ---------------------------------
# validation min rmse: 0.7970303132971289
# ---------------------------------
#
# MAE:0.6407952642666572, RMSE:0.8244603456720625, R2:0.08545117294024407, Sp:0.5746127690215405, step:56
# number of mol pool: 5800
# ---------------------------------
# validation min rmse: 0.8033024006978906
# ---------------------------------
#
# MAE:0.6281546551783417, RMSE:0.8087402480004899, R2:0.11999433754395272, Sp:0.5614908421555757, step:57
# number of mol pool: 5900
# ---------------------------------
# validation min rmse: 0.7798733158328955
# ---------------------------------
#
# MAE:0.6309826053761978, RMSE:0.813774848814659, R2:0.10900374415121405, Sp:0.5586376820416667, step:58
# number of mol pool: 6000
# ---------------------------------
# validation min rmse: 0.8140173003693624
# ---------------------------------
#
# MAE:0.6461858804976708, RMSE:0.8311743313813867, R2:0.07049528234718405, Sp:0.5510740909756484, step:59
# number of mol pool: 6100
# ---------------------------------
# validation min rmse: 0.8095084945886319
# ---------------------------------
#
# MAE:0.6294031157442369, RMSE:0.8105967103591492, R2:0.11594959643681069, Sp:0.5558340671087781, step:60
# number of mol pool: 6200
# ---------------------------------
# validation min rmse: 0.815954529026164
# ---------------------------------
#
# MAE:0.6446041764594089, RMSE:0.8292423945867905, R2:0.07481124190315447, Sp:0.556801725918281, step:61
# number of mol pool: 6300
# ---------------------------------
# validation min rmse: 0.7810277836614512
# ---------------------------------
#
# MAE:0.623383198644039, RMSE:0.8057300363079811, R2:0.12653308323915058, Sp:0.5659052994197502, step:62
# number of mol pool: 6400
# ---------------------------------
# validation min rmse: 0.7795413467803923
# ---------------------------------
#
# MAE:0.6257647989771357, RMSE:0.8073157488946308, R2:0.1230916565609993, Sp:0.5512597920943932, step:63
# number of mol pool: 6500
# ---------------------------------
# validation min rmse: 0.7911514857735756
# ---------------------------------
#
# MAE:0.6254060111303156, RMSE:0.806515635892754, R2:0.12482896463411697, Sp:0.5667384748178491, step:64
# number of mol pool: 6600
# ---------------------------------
# validation min rmse: 0.7949780563572415
# ---------------------------------
#
# MAE:0.6323519980908893, RMSE:0.8111264901030982, R2:0.1147936454187648, Sp:0.5580573715702729, step:65
# number of mol pool: 6700
# ---------------------------------
# validation min rmse: 0.7765694481749311
# ---------------------------------
#
# MAE:0.60647539494188, RMSE:0.7834593092168074, R2:0.17415176775508745, Sp:0.5761841739749018, step:66
# number of mol pool: 6800
# ---------------------------------
# validation min rmse: 0.7933107985196778
# ---------------------------------
#
# MAE:0.6239545185103396, RMSE:0.804204885621428, R2:0.12983669062561543, Sp:0.574645107120633, step:67
# number of mol pool: 6900
# ---------------------------------
# validation min rmse: 0.7779505127572475
# ---------------------------------
#
# MAE:0.617511827868678, RMSE:0.7925844193498311, R2:0.1548020902650198, Sp:0.5757920627868572, step:68
# number of mol pool: 7000
# ---------------------------------
# validation min rmse: 0.7794046919750567
# ---------------------------------
#
# MAE:0.6169260694041367, RMSE:0.7928271098479773, R2:0.15428440936948906, Sp:0.5707544598385492, step:69
# number of mol pool: 7100
# ---------------------------------
# validation min rmse: 0.7844771985781178
# ---------------------------------
#
# MAE:0.6301794917282564, RMSE:0.8057694572659987, R2:0.12644761107494706, Sp:0.5683317687746298, step:70
# number of mol pool: 7200
# ---------------------------------
# validation min rmse: 0.7826981505061494
# ---------------------------------
#
# MAE:0.6198128154892437, RMSE:0.7982508142099716, R2:0.14267380540285401, Sp:0.5771889751411257, step:71
# number of mol pool: 7300
# ---------------------------------
# validation min rmse: 0.7677704039365442
# ---------------------------------
#
# MAE:0.6019841872916806, RMSE:0.772963837721452, R2:0.19613021401974062, Sp:0.5873556762056935, step:72
# number of mol pool: 7400
# ---------------------------------
# validation min rmse: 0.7799121687697648
# ---------------------------------
#
# MAE:0.618352399602968, RMSE:0.7962082114466024, R2:0.1470557272877414, Sp:0.5914991135697467, step:73
# number of mol pool: 7500
# ---------------------------------
# validation min rmse: 0.7740227214356431
# ---------------------------------
#
# MAE:0.6069218859195287, RMSE:0.7810041784722166, R2:0.17931958812594118, Sp:0.5803338292902933, step:74
# number of mol pool: 7600
# ---------------------------------
# validation min rmse: 0.7378918629600855
# ---------------------------------
#
# MAE:0.5834789267180044, RMSE:0.7482544033614001, R2:0.24670355921161602, Sp:0.6104273988862233, step:75
# number of mol pool: 7700
# ---------------------------------
# validation min rmse: 0.7440578053694241
# ---------------------------------
#
# MAE:0.5967410265062211, RMSE:0.7628184260558348, R2:0.2170938531234401, Sp:0.6002299545776545, step:76
# number of mol pool: 7800
# ---------------------------------
# validation min rmse: 0.7534552483459109
# ---------------------------------
#
# MAE:0.5875799430511983, RMSE:0.7602677937582565, R2:0.2223206990257096, Sp:0.6032210431630468, step:77
# number of mol pool: 7900
# ---------------------------------
# validation min rmse: 0.7528542096240677
# ---------------------------------
#
# MAE:0.5915615760008446, RMSE:0.7583564002814277, R2:0.2262261192147641, Sp:0.5944416465692636, step:78
# number of mol pool: 8000
# ---------------------------------
# validation min rmse: 0.7624170339170241
# ---------------------------------
#
# MAE:0.6020408553556683, RMSE:0.7726650947780825, R2:0.19675146952055433, Sp:0.5827919243250838, step:79
# number of mol pool: 8100
# ---------------------------------
# validation min rmse: 0.7649423514090321
# ---------------------------------
#
# MAE:0.5907617642827095, RMSE:0.759996691120992, R2:0.2228752228954507, Sp:0.5995768688868978, step:80
# number of mol pool: 8200
# ---------------------------------
# validation min rmse: 0.7641360615356906
# ---------------------------------
#
# MAE:0.5979784143477167, RMSE:0.76969201208763, R2:0.20292110180227618, Sp:0.5811452633883435, step:81
# number of mol pool: 8300
# ---------------------------------
# validation min rmse: 0.749056952829429
# ---------------------------------
#
# MAE:0.5850477571738573, RMSE:0.7531156141567684, R2:0.23688382924389384, Sp:0.5962132079726727, step:82
# number of mol pool: 8400
# ---------------------------------
# validation min rmse: 0.7486744524250599
# ---------------------------------
#
# MAE:0.5879642665117071, RMSE:0.7567065792639948, R2:0.22958918119383587, Sp:0.6033219657720458, step:83
# number of mol pool: 8500
# ---------------------------------
# validation min rmse: 0.7419884284201392
# ---------------------------------
#
# MAE:0.5809912049641385, RMSE:0.749588262938968, R2:0.24401547009946467, Sp:0.610023881976384, step:84
# number of mol pool: 8600
# ---------------------------------
# validation min rmse: 0.7459235292685202
# ---------------------------------
#
# MAE:0.5747962638511648, RMSE:0.7391300301486062, R2:0.26496325869796034, Sp:0.6122698703525062, step:85
# number of mol pool: 8700
# ---------------------------------
# validation min rmse: 0.7324164478499655
# ---------------------------------
#
# MAE:0.5713618290961756, RMSE:0.7359378820232079, R2:0.2712984889578913, Sp:0.612353378188991, step:86
# number of mol pool: 8800
# ---------------------------------
# validation min rmse: 0.7407755220724541
# ---------------------------------
#
# MAE:0.5817326228153047, RMSE:0.7478266541096341, R2:0.24756457623012285, Sp:0.6100563161191005, step:87
# number of mol pool: 8900
# ---------------------------------
# validation min rmse: 0.7368601109438819
# ---------------------------------
#
# MAE:0.5769983980694245, RMSE:0.7415908857292766, R2:0.2600606560988562, Sp:0.6022588235116986, step:88
# number of mol pool: 9000
# ---------------------------------
# validation min rmse: 0.7516523496638529
# ---------------------------------
#
# MAE:0.5883215179325471, RMSE:0.7538354412282886, R2:0.2354243609130242, Sp:0.6023436769694925, step:89
# number of mol pool: 9100
# ---------------------------------
# validation min rmse: 0.7333496163641977
# ---------------------------------
#
# MAE:0.5768275596072218, RMSE:0.741869943566498, R2:0.2595036785877145, Sp:0.599230730523013, step:90
# number of mol pool: 9200
# ---------------------------------
# validation min rmse: 0.7316433888375055
# ---------------------------------
#
# MAE:0.5769390949536916, RMSE:0.7385158480792284, R2:0.2661843126482685, Sp:0.61489451120129, step:91
# number of mol pool: 9300
# ---------------------------------
# validation min rmse: 0.7215009577332204
# ---------------------------------
#
# MAE:0.5695402746339038, RMSE:0.7253713518380601, R2:0.29207352947662313, Sp:0.6164709226259939, step:92
# number of mol pool: 9400
# ---------------------------------
# validation min rmse: 0.7366095300350994
# ---------------------------------
#
# MAE:0.5699577905209497, RMSE:0.7330605195982706, R2:0.27698548916506394, Sp:0.6370589544193566, step:93
# number of mol pool: 9500
# ---------------------------------
# validation min rmse: 0.723476058593666
# ---------------------------------
#
# MAE:0.5704564936518163, RMSE:0.7313340156252303, R2:0.28038716585902046, Sp:0.6272581069942876, step:94
# number of mol pool: 9600
# ---------------------------------
# validation min rmse: 0.7127514047628558
# ---------------------------------
#
# MAE:0.5595675340314903, RMSE:0.7230021999790385, R2:0.296690327101485, Sp:0.6234104937382787, step:95
# number of mol pool: 9700
# ---------------------------------
# validation min rmse: 0.7224509558582033
# ---------------------------------
#
# MAE:0.5601225380094618, RMSE:0.7221888324983559, R2:0.2982718643169212, Sp:0.61491654809115, step:96
# number of mol pool: 9800
# ---------------------------------
# validation min rmse: 0.7186997414253966
# ---------------------------------
#
# MAE:0.5708814745588935, RMSE:0.7347292610233611, R2:0.27368999718092213, Sp:0.6136724364945102, step:97
# number of mol pool: 9900
# ---------------------------------
# validation min rmse: 0.7100785053867311
# ---------------------------------
#
# MAE:0.5584979780330018, RMSE:0.7158084575086343, R2:0.3106163108928086, Sp:0.6268683888496066, step:98
# number of mol pool: 10000
# ---------------------------------
# validation min rmse: 0.7064050956886084
# ---------------------------------
#
# MAE:0.5513539913453197, RMSE:0.7059945131510428, R2:0.3293900319827341, Sp:0.621547261513843, step:99
