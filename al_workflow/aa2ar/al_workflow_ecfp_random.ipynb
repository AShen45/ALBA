# %%
# !pip install datamol
# !pip install rdkit-pypi
# !pip install pandas
# Out:
# Collecting datamol
#   Downloading datamol-0.11.3-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.7/381.7 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from datamol) (4.66.1)
# Collecting loguru (from datamol)
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from datamol) (1.3.2)
# Requirement already satisfied: fsspec>=2021.9 in /usr/local/lib/python3.10/dist-packages (from datamol) (2023.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datamol) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datamol) (1.11.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from datamol) (3.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from datamol) (9.4.0)
# Collecting selfies (from datamol)
#   Downloading selfies-2.1.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from datamol) (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from datamol) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datamol) (23.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from datamol) (4.5.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from datamol) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->datamol) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datamol) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->datamol) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->datamol) (1.16.0)
# Installing collected packages: selfies, loguru, datamol
# Successfully installed datamol-0.11.3 loguru-0.7.2 selfies-2.1.1
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 54.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (9.4.0)
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import os
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import Linear
from torch.utils.data import DataLoader
import tqdm
from scipy.stats import spearmanr

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Project/ALVS")
# Out:
# Mounted at /content/drive

# %%
def ecfp_from_smiles(smiles,
                     R = 2,
                     L = 2**11,
                     use_features = True,
                     use_chirality = False):
    """
    Inputs:

    - smiles ... SMILES string of input compound
    - R ... maximum radius of circular substructures
    - L ... fingerprint-length
    - use_features ... if false then use standard DAYLIGHT atom features, if true then use pharmacophoric atom features
    - use_chirality ... if true then append tetrahedral chirality flags to atom features

    Outputs:
    - np.array(feature_list) ... ECFP with length L and maximum radius R
    """

    molecule = Chem.MolFromSmiles(smiles)
    if not molecule:
        return np.nan
    feature_list = AllChem.GetMorganFingerprintAsBitVect(molecule,
                                                         radius = R,
                                                         nBits = L,
                                                         useFeatures = use_features,
                                                         useChirality = use_chirality)
    return np.array(feature_list)

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, fps, scores):
        self.fps = fps
        self.scores = scores
        self.dataLen = len(scores)

    def __getitem__(self, index):
        fp = np.array(self.fps[index])
        score = np.array(self.scores[index]).reshape(1,)
        return fp, score

    def __len__(self):
        return self.dataLen

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        self.fc1 = Linear(2048, 1024)
        self.dropout1 = nn.Dropout(p=0.2)
        self.fc2 = Linear(1024, 516)
        self.dropout2 = nn.Dropout(p=0.2)
        self.fc3 = Linear(516, 256)
        self.dropout3 = nn.Dropout(p=0.2)
        self.fc4 = Linear(256, 128)
        self.dropout4 = nn.Dropout(p=0.2)
        self.fc5 = Linear(128, 1)


    def forward(self, data):
        x = F.relu(self.fc1(data))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = F.relu(self.fc3(x))
        x = self.dropout3(x)
        x = F.relu(self.fc4(x))
        x = self.dropout4(x)
        x = self.fc5(x)
        return x

# %%
def train_epoch(loader, model, optimizer, device):
    model.train()

    loss_all = 0
    i = 0
    for fps, scores in loader:
        fps = fps.float().to(device)
        scores = scores.float().to(device)

        optimizer.zero_grad()
        output = model(fps)
        loss = F.mse_loss(output, scores)
        loss.backward()

        loss_all += loss.item()
        optimizer.step()
        i += 1
    return loss_all / i

# %%
def test_epoch(loader, model,  device):
    model.eval()

    MSE, MAE = 0, 0
    trues, preds = [], []
    with torch.no_grad():
        for fps, scores in loader:
            fps = fps.float().to(device)
            scores = scores.float().to(device)

            output = model(fps)
            pred = output.cpu().squeeze().numpy().tolist()
            true = scores.cpu().squeeze().numpy().tolist()

            trues.extend(true)
            preds.extend(pred)
    MAE = mean_absolute_error(trues, preds)
    RMSE = np.sqrt(mean_squared_error(trues, preds))
    R2 = r2_score(trues, preds)
    Sp = spearmanr(trues, preds)[0]
    return MAE, RMSE, R2, Sp

# %%
def init_model(device, lr=0.0001):
    model = DNN()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    return model, optimizer

# %%
def prepare_dataloader(dff, batch_size, test_size=0.8):
    train_fps, valid_fps, train_scores, valid_scores = train_test_split(
                                                                        dff["ecfp"],
                                                                        dff["score"],
                                                                        test_size=test_size)
    train_dataset = Dataset(fps=list(train_fps),
                            scores = list(train_scores))
    valid_dataset = Dataset(fps=list(valid_fps),
                            scores = list(valid_scores))
    train_loader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=True)
    valid_loader = DataLoader(valid_dataset,
                              batch_size=batch_size,
                              shuffle=False)
    return train_loader, valid_loader

# %%
def train_step(dff, epochs, batch_size, step_time, device="cuda"):
    model, optimizer = init_model(device=device)
    train_loader, valid_loader = prepare_dataloader(dff,  batch_size=batch_size)

    model_folder = "models/aa2ar/ecfp/models_random/{}".format(step_time)
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)

    hist = {"train-loss":[], "test-mae":[], "test-rmse":[], "test-r2":[],"test-sp":[]}
    for epoch in range(epochs):
        train_loss = train_epoch(train_loader, model, optimizer, device)
        test_mae, test_rmse, test_r2, test_sp = test_epoch(valid_loader, model, device)
        hist["train-loss"].append(train_loss)
        hist["test-mae"].append(test_mae)
        hist["test-rmse"].append(test_rmse)
        hist["test-r2"].append(test_r2)
        hist["test-sp"].append(test_sp)

        if test_rmse <= min(hist["test-rmse"]):
            weight_path = os.path.join(model_folder, "weight_{}.pth".format(epoch))
            torch.save(model.state_dict(), weight_path)

        # print(f'Epoch: {epoch}, Train loss: {train_loss:.3}, Test mae: {test_mae:.3}, Test rmse: {test_rmse:.3}, Test r2: {test_r2:.3}')
    print("---------------------------------\nvalidation min rmse: {}\n---------------------------------\n".format(min(hist["test-rmse"])))
    return weight_path

# %%
def random_select(df, n_samples):
    df_select = df.sample(n=n_samples).copy()
    sample_indexs = df_select["name"].tolist()
    df_remaining = df[~df["name"].isin(sample_indexs)].copy()
    return df_select, df_remaining

# %%
def predict(fpnp, model, device):
    fpnp = fpnp.reshape(1, 2048)
    fp = torch.from_numpy(fpnp).float().to(device)
    with torch.no_grad():
        output = model(fp)
        pred = output.cpu().numpy()[0][0]
    return pred

# %%
def load_model(best_model_path, device="cuda", enable_dp=True):
    model= DNN().to(device)
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()
    if enable_dp:
        enable_dropout(model)
    return model

# %%
def eval_model(dff, best_model_path):
    model = load_model(best_model_path, enable_dp=False)
    dff["pred"] = dff["ecfp"].map(lambda x: predict(x,  model, device="cuda"))
    MAE = mean_absolute_error(dff["score"], dff["pred"])
    RMSE = np.sqrt(mean_squared_error(dff["score"], dff["pred"]))
    R2 = r2_score(dff["score"], dff["pred"])
    Sp = spearmanr(dff["score"], dff["pred"])[0]
    return MAE, RMSE, R2, Sp

# %%
def run_step(dfs, epochs, stime):
    dfs_new = dfs.copy()

    best_model_path = train_step(dfs_new, epochs, batch_size=32, step_time=stime)
    return best_model_path

# %%
def run_iterations(df, df_test, epochs=200, iterations=100, n_samples=100):

    results = {"RMSE": [], "R2": [], "Sp": []}

    print("len(df):", len(df))

    df["ecfp"] = df["smiles"].map(lambda x: ecfp_from_smiles(x))
    df = df[~df["ecfp"].isna()]

    for stime in range(iterations):
        if stime < 1:
            dfs, dfr = random_select(df, n_samples)
        else:
            df_temp = dfs.copy()
            dfs, dfr = random_select(dfr, n_samples)
            dfs = pd.concat([dfs, df_temp], axis=0)
            dfs = dfs.reset_index(drop=True)
        print("number of mol pool:", len(dfs))
        best_model_path = run_step(dfs, epochs, stime)
        MAE, RMSE, R2 , Sp = eval_model(df_test, best_model_path)
        print("MAE:{}, RMSE:{}, R2:{}, Sp:{}, step:{}".format(MAE, RMSE, R2, Sp, stime))

        results["RMSE"].append(RMSE)
        results["R2"].append(R2)
        results["Sp"].append(Sp)

    # Convert results dictionary to DataFrame
    results_df = pd.DataFrame(results)

    results_df.to_csv('result/aa2ar/ecfp_random_results.csv', index=False)

# %%
df = pd.read_csv("preprocess_data/aa2ar/aa2ar_train.csv", sep="\t")
df_test = pd.read_csv("preprocess_data/aa2ar/aa2ar_test.csv", sep="\t")
df_test["ecfp"] = df_test["smiles"].map(lambda x: ecfp_from_smiles(x))
df_test = df_test[~df_test["ecfp"].isna()]
# Out:
# [20:48:48] SMILES Parse Error: syntax error while parsing: error
# [20:48:48] SMILES Parse Error: Failed parsing SMILES 'error' for input: 'error'

# %%
run_iterations(df, df_test)
# Out:
# len(df): 19182
# number of mol pool: 100
# ---------------------------------
# validation min rmse: 1.6517937855544156
# ---------------------------------
#
# MAE:1.390497877575722, RMSE:1.7269525148847369, R2:-1.872517489121524, Sp:0.23214996922395026, step:0
# number of mol pool: 200
# ---------------------------------
# validation min rmse: 1.4422365417144805
# ---------------------------------
#
# MAE:1.225861538419505, RMSE:1.5446805435468058, R2:-1.298154604796692, Sp:0.2996904621760268, step:1
# number of mol pool: 300
# ---------------------------------
# validation min rmse: 1.5003675073505771
# ---------------------------------
#
# MAE:1.218077524421385, RMSE:1.532434682803228, R2:-1.2618605939308352, Sp:0.3061318455042802, step:2
# number of mol pool: 400
# ---------------------------------
# validation min rmse: 1.385430070228459
# ---------------------------------
#
# MAE:1.1148893371104094, RMSE:1.420202020359727, R2:-0.9426839022863553, Sp:0.3582272177846195, step:3
# number of mol pool: 500
# ---------------------------------
# validation min rmse: 1.4275600230841656
# ---------------------------------
#
# MAE:1.1467542931009629, RMSE:1.4558041261811683, R2:-1.0413044444714914, Sp:0.35600157601946864, step:4
# number of mol pool: 600
# ---------------------------------
# validation min rmse: 1.3323317355462552
# ---------------------------------
#
# MAE:1.0724433683608536, RMSE:1.3655622178782032, R2:-0.7960766788346509, Sp:0.40527617937019794, step:5
# number of mol pool: 700
# ---------------------------------
# validation min rmse: 1.4035698351396
# ---------------------------------
#
# MAE:1.0986652420569636, RMSE:1.3968489701210867, R2:-0.8793202487126415, Sp:0.3909725337655459, step:6
# number of mol pool: 800
# ---------------------------------
# validation min rmse: 1.3460878529781117
# ---------------------------------
#
# MAE:1.0804873182927281, RMSE:1.3743193827876268, R2:-0.8191865334477175, Sp:0.42362664937311484, step:7
# number of mol pool: 900
# ---------------------------------
# validation min rmse: 1.2925932757669016
# ---------------------------------
#
# MAE:0.9955278585900812, RMSE:1.2739496090615474, R2:-0.5631706384390911, Sp:0.42406022011975636, step:8
# number of mol pool: 1000
# ---------------------------------
# validation min rmse: 1.2751950086694799
# ---------------------------------
#
# MAE:0.9682396529014758, RMSE:1.2430295603485293, R2:-0.48821200161441625, Sp:0.43089255278151817, step:9
# number of mol pool: 1100
# ---------------------------------
# validation min rmse: 1.341999677715611
# ---------------------------------
#
# MAE:1.009119888187583, RMSE:1.2966086744242133, R2:-0.619271733263582, Sp:0.3923107250076385, step:10
# number of mol pool: 1200
# ---------------------------------
# validation min rmse: 1.28922423620389
# ---------------------------------
#
# MAE:1.0164033401437014, RMSE:1.2946710806567545, R2:-0.6144358153534928, Sp:0.4122378701913895, step:11
# number of mol pool: 1300
# ---------------------------------
# validation min rmse: 1.2628554821493887
# ---------------------------------
#
# MAE:0.9530406919262601, RMSE:1.229452909818509, R2:-0.45588036049135283, Sp:0.41715769140594244, step:12
# number of mol pool: 1400
# ---------------------------------
# validation min rmse: 1.2776932975904078
# ---------------------------------
#
# MAE:0.9988163705126769, RMSE:1.2795019336607698, R2:-0.5768260362837192, Sp:0.4444875330774515, step:13
# number of mol pool: 1500
# ---------------------------------
# validation min rmse: 1.2013598707771909
# ---------------------------------
#
# MAE:0.9500755327498848, RMSE:1.221844115611258, R2:-0.43791592124262224, Sp:0.4622456426977832, step:14
# number of mol pool: 1600
# ---------------------------------
# validation min rmse: 1.2476449029762706
# ---------------------------------
#
# MAE:0.978275293354997, RMSE:1.2514924646905232, R2:-0.5085453388683958, Sp:0.4316953001229772, step:15
# number of mol pool: 1700
# ---------------------------------
# validation min rmse: 1.197089891927277
# ---------------------------------
#
# MAE:0.9416703905117322, RMSE:1.211794458440439, R2:-0.4143595051797093, Sp:0.4506862720697475, step:16
# number of mol pool: 1800
# ---------------------------------
# validation min rmse: 1.1874642440266254
# ---------------------------------
#
# MAE:0.9181442925909442, RMSE:1.1772682331522468, R2:-0.33491231619805517, Sp:0.4555634573548912, step:17
# number of mol pool: 1900
# ---------------------------------
# validation min rmse: 1.1794820944047433
# ---------------------------------
#
# MAE:0.9195148296902825, RMSE:1.1831195670387322, R2:-0.3482150264226471, Sp:0.44973108669992085, step:18
# number of mol pool: 2000
# ---------------------------------
# validation min rmse: 1.16484877251192
# ---------------------------------
#
# MAE:0.9107108077629967, RMSE:1.1675132835811262, R2:-0.3128815653039212, Sp:0.4543585350317321, step:19
# number of mol pool: 2100
# ---------------------------------
# validation min rmse: 1.2006164030934978
# ---------------------------------
#
# MAE:0.9379776945985003, RMSE:1.2048141522716678, R2:-0.3981121498050959, Sp:0.47081014137434707, step:20
# number of mol pool: 2200
# ---------------------------------
# validation min rmse: 1.1159439438527226
# ---------------------------------
#
# MAE:0.8945772903220383, RMSE:1.1509752483264297, R2:-0.2759505919000529, Sp:0.4899599580398264, step:21
# number of mol pool: 2300
# ---------------------------------
# validation min rmse: 1.1640451874463213
# ---------------------------------
#
# MAE:0.9216663002767631, RMSE:1.1813990598934567, R2:-0.34429669551935693, Sp:0.47319844586819965, step:22
# number of mol pool: 2400
# ---------------------------------
# validation min rmse: 1.1748596278549222
# ---------------------------------
#
# MAE:0.9172924177273737, RMSE:1.1783584365698547, R2:-0.33738583884485474, Sp:0.4731604599191175, step:23
# number of mol pool: 2500
# ---------------------------------
# validation min rmse: 1.164527038258631
# ---------------------------------
#
# MAE:0.8968418322610104, RMSE:1.1607768887599934, R2:-0.2977749723430838, Sp:0.48425283978683553, step:24
# number of mol pool: 2600
# ---------------------------------
# validation min rmse: 1.135495479936853
# ---------------------------------
#
# MAE:0.8793383095305205, RMSE:1.1471040935866994, R2:-0.2673820398447433, Sp:0.46390424267000485, step:25
# number of mol pool: 2700
# ---------------------------------
# validation min rmse: 1.1280407374717665
# ---------------------------------
#
# MAE:0.8778690687441343, RMSE:1.126002916926133, R2:-0.22118347929671178, Sp:0.4948511385657868, step:26
# number of mol pool: 2800
# ---------------------------------
# validation min rmse: 1.123741644902683
# ---------------------------------
#
# MAE:0.8840293629407024, RMSE:1.1315946403548651, R2:-0.2333423740269127, Sp:0.509728875240867, step:27
# number of mol pool: 2900
# ---------------------------------
# validation min rmse: 1.1261554336775053
# ---------------------------------
#
# MAE:0.8628525091379093, RMSE:1.11483736698623, R2:-0.19708481838519454, Sp:0.5073942433502976, step:28
# number of mol pool: 3000
# ---------------------------------
# validation min rmse: 1.1060296985560418
# ---------------------------------
#
# MAE:0.8414914342563834, RMSE:1.0884081466303874, R2:-0.1409995069761909, Sp:0.5166907091228563, step:29
# number of mol pool: 3100
# ---------------------------------
# validation min rmse: 1.0707358730195973
# ---------------------------------
#
# MAE:0.8265516847935314, RMSE:1.0631382915336356, R2:-0.08863278790069051, Sp:0.5292153681596282, step:30
# number of mol pool: 3200
# ---------------------------------
# validation min rmse: 1.0743555938505258
# ---------------------------------
#
# MAE:0.8298245617783147, RMSE:1.0734671837208474, R2:-0.10988871101430098, Sp:0.5155734231374112, step:31
# number of mol pool: 3300
# ---------------------------------
# validation min rmse: 1.0621247337436066
# ---------------------------------
#
# MAE:0.8345862528759911, RMSE:1.081770397918597, R2:-0.12712498076102574, Sp:0.5115102439732567, step:32
# number of mol pool: 3400
# ---------------------------------
# validation min rmse: 1.0821255900046958
# ---------------------------------
#
# MAE:0.8382137230361306, RMSE:1.0852352795026243, R2:-0.1343568461721849, Sp:0.5162868191670591, step:33
# number of mol pool: 3500
# ---------------------------------
# validation min rmse: 1.0905588778228799
# ---------------------------------
#
# MAE:0.8413651929914648, RMSE:1.094785535879772, R2:-0.1544097633448851, Sp:0.4910793054429911, step:34
# number of mol pool: 3600
# ---------------------------------
# validation min rmse: 1.069847201183939
# ---------------------------------
#
# MAE:0.8201766413309047, RMSE:1.0658387356125747, R2:-0.09417021539463422, Sp:0.4978660183972562, step:35
# number of mol pool: 3700
# ---------------------------------
# validation min rmse: 1.0269306449602436
# ---------------------------------
#
# MAE:0.824255851053851, RMSE:1.0738453320286334, R2:-0.11067080564781517, Sp:0.5087207646837808, step:36
# number of mol pool: 3800
# ---------------------------------
# validation min rmse: 1.049338597885007
# ---------------------------------
#
# MAE:0.7975471442343599, RMSE:1.0294328881872064, R2:-0.020699652828151338, Sp:0.5451139323552583, step:37
# number of mol pool: 3900
# ---------------------------------
# validation min rmse: 1.046440550586114
# ---------------------------------
#
# MAE:0.8114180104995355, RMSE:1.0460664223007834, R2:-0.053950982430175376, Sp:0.5317962308200007, step:38
# number of mol pool: 4000
# ---------------------------------
# validation min rmse: 1.0530181307871052
# ---------------------------------
#
# MAE:0.812335204848452, RMSE:1.0548476942689684, R2:-0.07172017183039303, Sp:0.5616920209945692, step:39
# number of mol pool: 4100
# ---------------------------------
# validation min rmse: 1.058033455972919
# ---------------------------------
#
# MAE:0.8208882871053111, RMSE:1.0637214011625045, R2:-0.08982730107226145, Sp:0.5121428286298411, step:40
# number of mol pool: 4200
# ---------------------------------
# validation min rmse: 1.0148847596227557
# ---------------------------------
#
# MAE:0.7835861161106842, RMSE:1.0141265419264698, R2:0.009427680685850204, Sp:0.5484617844398244, step:41
# number of mol pool: 4300
# ---------------------------------
# validation min rmse: 1.0382340948264217
# ---------------------------------
#
# MAE:0.7894404024845062, RMSE:1.0227511865737415, R2:-0.007492619321933791, Sp:0.54811497583222, step:42
# number of mol pool: 4400
# ---------------------------------
# validation min rmse: 1.0316235489119372
# ---------------------------------
#
# MAE:0.7986437136253919, RMSE:1.0297799635390512, R2:-0.021388030700822735, Sp:0.5259170082678656, step:43
# number of mol pool: 4500
# ---------------------------------
# validation min rmse: 1.0403466910785326
# ---------------------------------
#
# MAE:0.8015264418914965, RMSE:1.0345212077978636, R2:-0.030814895491166894, Sp:0.5390117816088775, step:44
# number of mol pool: 4600
# ---------------------------------
# validation min rmse: 0.9967736323673025
# ---------------------------------
#
# MAE:0.7862977521433482, RMSE:1.0144763474232734, R2:0.008744201082717118, Sp:0.5657275601159792, step:45
# number of mol pool: 4700
# ---------------------------------
# validation min rmse: 1.0007535879411953
# ---------------------------------
#
# MAE:0.7708613615512131, RMSE:1.005354762318241, R2:0.02648966104270989, Sp:0.5484027130266423, step:46
# number of mol pool: 4800
# ---------------------------------
# validation min rmse: 0.9952554344253337
# ---------------------------------
#
# MAE:0.7608399259225013, RMSE:0.9823312693149844, R2:0.07056756031714928, Sp:0.5586067880239906, step:47
# number of mol pool: 4900
# ---------------------------------
# validation min rmse: 0.9971192085678782
# ---------------------------------
#
# MAE:0.7768055622119099, RMSE:1.0112312980329559, R2:0.015075604228554806, Sp:0.5671566724589969, step:48
# number of mol pool: 5000
# ---------------------------------
# validation min rmse: 0.9778252955516192
# ---------------------------------
#
# MAE:0.7525834062374029, RMSE:0.9810103713365831, R2:0.07306541427223834, Sp:0.559906963607183, step:49
# number of mol pool: 5100
# ---------------------------------
# validation min rmse: 1.0190486340031517
# ---------------------------------
#
# MAE:0.7915098218925039, RMSE:1.0176272888467852, R2:0.002577000526364004, Sp:0.5441995309520506, step:50
# number of mol pool: 5200
# ---------------------------------
# validation min rmse: 0.9670135424928519
# ---------------------------------
#
# MAE:0.7516436736068726, RMSE:0.9790693143141651, R2:0.07672990739270191, Sp:0.5741327327192258, step:51
# number of mol pool: 5300
# ---------------------------------
# validation min rmse: 0.9825285502761262
# ---------------------------------
#
# MAE:0.7551995649711795, RMSE:0.983600488036315, R2:0.06816426689983668, Sp:0.5597742488295975, step:52
# number of mol pool: 5400
# ---------------------------------
# validation min rmse: 1.0010736151030437
# ---------------------------------
#
# MAE:0.7797579546757787, RMSE:1.0076028825216325, R2:0.02213097031459721, Sp:0.5381337734637672, step:53
# number of mol pool: 5500
# ---------------------------------
# validation min rmse: 0.9353061791388604
# ---------------------------------
#
# MAE:0.7270310070083821, RMSE:0.9429534746299627, R2:0.14358863980348546, Sp:0.5980241552160978, step:54
# number of mol pool: 5600
# ---------------------------------
# validation min rmse: 0.9418139229240049
# ---------------------------------
#
# MAE:0.7169132627593079, RMSE:0.935150314737726, R2:0.15770400062377, Sp:0.5916886282818977, step:55
# number of mol pool: 5700
# ---------------------------------
# validation min rmse: 0.9569667979011723
# ---------------------------------
#
# MAE:0.7369116092075496, RMSE:0.9589164513238592, R2:0.11434734630827692, Sp:0.5874387477188279, step:56
# number of mol pool: 5800
# ---------------------------------
# validation min rmse: 0.9380170533081773
# ---------------------------------
#
# MAE:0.728541112252416, RMSE:0.9480596638819319, R2:0.13428841722177598, Sp:0.5905840210177796, step:57
# number of mol pool: 5900
# ---------------------------------
# validation min rmse: 0.984163827236767
# ---------------------------------
#
# MAE:0.7485475380831017, RMSE:0.9795225477122593, R2:0.07587490419345011, Sp:0.5736032188536919, step:58
# number of mol pool: 6000
# ---------------------------------
# validation min rmse: 0.95082290075688
# ---------------------------------
#
# MAE:0.7351353836778155, RMSE:0.9586178360677017, R2:0.11489886091542112, Sp:0.5738833393155957, step:59
# number of mol pool: 6100
# ---------------------------------
# validation min rmse: 0.9542563827629764
# ---------------------------------
#
# MAE:0.734095825098517, RMSE:0.9612016379792571, R2:0.11012113208209906, Sp:0.5861997458700235, step:60
# number of mol pool: 6200
# ---------------------------------
# validation min rmse: 0.947223297060046
# ---------------------------------
#
# MAE:0.7189983475602425, RMSE:0.9426540740150713, R2:0.1441323980861301, Sp:0.5887654962604487, step:61
# number of mol pool: 6300
# ---------------------------------
# validation min rmse: 0.9609113774358236
# ---------------------------------
#
# MAE:0.734002001058564, RMSE:0.960582010696712, R2:0.11126806208799522, Sp:0.6034067494156442, step:62
# number of mol pool: 6400
# ---------------------------------
# validation min rmse: 0.9114497551267519
# ---------------------------------
#
# MAE:0.7093442074786721, RMSE:0.923653528565744, R2:0.17828715375251658, Sp:0.59328664154106, step:63
# number of mol pool: 6500
# ---------------------------------
# validation min rmse: 0.9455512586586806
# ---------------------------------
#
# MAE:0.7326287997028842, RMSE:0.9514230385518021, R2:0.1281350549932273, Sp:0.5990943601180737, step:64
# number of mol pool: 6600
# ---------------------------------
# validation min rmse: 0.9360494761234402
# ---------------------------------
#
# MAE:0.7149449302999462, RMSE:0.9324190285809651, R2:0.16261699004506225, Sp:0.5946947847075168, step:65
# number of mol pool: 6700
# ---------------------------------
# validation min rmse: 0.9241286278868046
# ---------------------------------
#
# MAE:0.7219918667346973, RMSE:0.9369761886895744, R2:0.15441163640053435, Sp:0.5937087461463744, step:66
# number of mol pool: 6800
# ---------------------------------
# validation min rmse: 0.9329094869405065
# ---------------------------------
#
# MAE:0.7182581334500219, RMSE:0.93907909595047, R2:0.1506117759979103, Sp:0.5980347949989252, step:67
# number of mol pool: 6900
# ---------------------------------
# validation min rmse: 0.9359060068761946
# ---------------------------------
#
# MAE:0.7203033090193243, RMSE:0.9422197802263361, R2:0.14492083653991694, Sp:0.5847033931614376, step:68
# number of mol pool: 7000
# ---------------------------------
# validation min rmse: 0.9471078969090755
# ---------------------------------
#
# MAE:0.7197406211404133, RMSE:0.9362870995968268, R2:0.15565493683945597, Sp:0.5967995183971095, step:69
# number of mol pool: 7100
# ---------------------------------
# validation min rmse: 0.9467494314610642
# ---------------------------------
#
# MAE:0.7192115430297021, RMSE:0.9435890222850165, R2:0.14243381367191177, Sp:0.5658531975373028, step:70
# number of mol pool: 7200
# ---------------------------------
# validation min rmse: 0.9040965948181298
# ---------------------------------
#
# MAE:0.7001981254679988, RMSE:0.9137451282693224, R2:0.19582227718985523, Sp:0.5962374786600328, step:71
# number of mol pool: 7300
# ---------------------------------
# validation min rmse: 0.9203170883099765
# ---------------------------------
#
# MAE:0.7032377327553606, RMSE:0.9211990652290005, R2:0.18264849541007333, Sp:0.5898108031873921, step:72
# number of mol pool: 7400
# ---------------------------------
# validation min rmse: 0.8988444959435066
# ---------------------------------
#
# MAE:0.6837619144904006, RMSE:0.8961937060020206, R2:0.22641922478073429, Sp:0.611241348340911, step:73
# number of mol pool: 7500
# ---------------------------------
# validation min rmse: 0.9086316426978964
# ---------------------------------
#
# MAE:0.7022853998839318, RMSE:0.9196609288129697, R2:0.1853756986442543, Sp:0.5951245121357617, step:74
# number of mol pool: 7600
# ---------------------------------
# validation min rmse: 0.9136048677846567
# ---------------------------------
#
# MAE:0.7010797333838115, RMSE:0.916976998039704, R2:0.1901235459950955, Sp:0.5956255104927866, step:75
# number of mol pool: 7700
# ---------------------------------
# validation min rmse: 0.9117786507784256
# ---------------------------------
#
# MAE:0.6921617512188327, RMSE:0.9076039079582195, R2:0.20659560183383208, Sp:0.609345540374076, step:76
# number of mol pool: 7800
# ---------------------------------
# validation min rmse: 0.873419448903121
# ---------------------------------
#
# MAE:0.6936422072745378, RMSE:0.9019586735465802, R2:0.21643474945780417, Sp:0.6187012136652794, step:77
# number of mol pool: 7900
# ---------------------------------
# validation min rmse: 0.8710655531110089
# ---------------------------------
#
# MAE:0.677941934675986, RMSE:0.8837022175823734, R2:0.2478338603142256, Sp:0.6125209473851319, step:78
# number of mol pool: 8000
# ---------------------------------
# validation min rmse: 0.8814587396579274
# ---------------------------------
#
# MAE:0.6840363605910621, RMSE:0.8921886846951291, R2:0.23331792232835846, Sp:0.6066002169960684, step:79
# number of mol pool: 8100
# ---------------------------------
# validation min rmse: 0.892695295931893
# ---------------------------------
#
# MAE:0.690917775455197, RMSE:0.9012284392989895, R2:0.21770299948805205, Sp:0.6095643169442825, step:80
# number of mol pool: 8200
# ---------------------------------
# validation min rmse: 0.8850524938713459
# ---------------------------------
#
# MAE:0.6794131873167898, RMSE:0.8962605014665012, R2:0.22630390682557533, Sp:0.6199765112629524, step:81
# number of mol pool: 8300
# ---------------------------------
# validation min rmse: 0.8970522579263275
# ---------------------------------
#
# MAE:0.6823854548064653, RMSE:0.8905497031542468, R2:0.23613217811550602, Sp:0.6069189770852624, step:82
# number of mol pool: 8400
# ---------------------------------
# validation min rmse: 0.8702127171793487
# ---------------------------------
#
# MAE:0.6788803058396506, RMSE:0.8860309960667564, R2:0.24386434144384295, Sp:0.6129331479212785, step:83
# number of mol pool: 8500
# ---------------------------------
# validation min rmse: 0.8998135378360639
# ---------------------------------
#
# MAE:0.6909147578351933, RMSE:0.9066417808211505, R2:0.2082768446946308, Sp:0.6070584095493481, step:84
# number of mol pool: 8600
# ---------------------------------
# validation min rmse: 0.8945752605410526
# ---------------------------------
#
# MAE:0.6731509104662202, RMSE:0.8823393822766892, R2:0.25015203518894236, Sp:0.6306477953328595, step:85
# number of mol pool: 8700
# ---------------------------------
# validation min rmse: 0.8598396356189533
# ---------------------------------
#
# MAE:0.6609171467485161, RMSE:0.8696236915421126, R2:0.27160892614669907, Sp:0.6319633082740789, step:86
# number of mol pool: 8800
# ---------------------------------
# validation min rmse: 0.8854227180609582
# ---------------------------------
#
# MAE:0.6749544309048, RMSE:0.8873025043326365, R2:0.24169258311614417, Sp:0.6262737391520666, step:87
# number of mol pool: 8900
# ---------------------------------
# validation min rmse: 0.8576972251151972
# ---------------------------------
#
# MAE:0.6599111382965768, RMSE:0.8688277179180061, R2:0.2729417204340444, Sp:0.6271884428647868, step:88
# number of mol pool: 9000
# ---------------------------------
# validation min rmse: 0.8404258171193101
# ---------------------------------
#
# MAE:0.656252438537511, RMSE:0.8565148524642416, R2:0.29340316828428015, Sp:0.6350116198235433, step:89
# number of mol pool: 9100
# ---------------------------------
# validation min rmse: 0.8494174249692725
# ---------------------------------
#
# MAE:0.6494248307499689, RMSE:0.8519081288958046, R2:0.30098352157301733, Sp:0.6439333472432912, step:90
# number of mol pool: 9200
# ---------------------------------
# validation min rmse: 0.8707330049140821
# ---------------------------------
#
# MAE:0.674787322727593, RMSE:0.8856611460659615, R2:0.24449546700836533, Sp:0.6248181237896712, step:91
# number of mol pool: 9300
# ---------------------------------
# validation min rmse: 0.878762598420955
# ---------------------------------
#
# MAE:0.6729112804260725, RMSE:0.8795591502420969, R2:0.25487009917157, Sp:0.6263791165611146, step:92
# number of mol pool: 9400
# ---------------------------------
# validation min rmse: 0.8843612959634086
# ---------------------------------
#
# MAE:0.6706382887571857, RMSE:0.8792072698442662, R2:0.2554661799652017, Sp:0.6265516811508884, step:93
# number of mol pool: 9500
# ---------------------------------
# validation min rmse: 0.8481460125109578
# ---------------------------------
#
# MAE:0.6421903451226642, RMSE:0.8485289013818417, R2:0.3065180404849207, Sp:0.6455100112010602, step:94
# number of mol pool: 9600
# ---------------------------------
# validation min rmse: 0.8474182062457868
# ---------------------------------
#
# MAE:0.6489355296363469, RMSE:0.8558089889741894, R2:0.29456731713011497, Sp:0.6337690388996918, step:95
# number of mol pool: 9700
# ---------------------------------
# validation min rmse: 0.8339263676203599
# ---------------------------------
#
# MAE:0.6440137972965211, RMSE:0.8338714906313318, R2:0.3302694019175846, Sp:0.6460269755726644, step:96
# number of mol pool: 9800
# ---------------------------------
# validation min rmse: 0.8412684906153092
# ---------------------------------
#
# MAE:0.6436754096198491, RMSE:0.8441611398462435, R2:0.3136389955896388, Sp:0.6472066000123102, step:97
# number of mol pool: 9900
# ---------------------------------
# validation min rmse: 0.8512343459792353
# ---------------------------------
#
# MAE:0.6482698927425878, RMSE:0.8471078030644483, R2:0.30883895328313005, Sp:0.6408867843003088, step:98
# number of mol pool: 10000
# ---------------------------------
# validation min rmse: 0.8497665487335153
# ---------------------------------
#
# MAE:0.6498658934426421, RMSE:0.8568248606060737, R2:0.29289158249692315, Sp:0.6305125279856801, step:99
